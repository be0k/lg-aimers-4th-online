# %%
# !pip3 install scikit-learn tqdm catboost optuna xgboost ipywidgets imblearn
# Out:
# Requirement already satisfied: scikit-learn in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (1.4.0)
# Requirement already satisfied: tqdm in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (4.65.0)
# Requirement already satisfied: catboost in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: optuna in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (3.5.0)
# Requirement already satisfied: xgboost in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: ipywidgets in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (8.0.4)
# Requirement already satisfied: imblearn in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (0.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from scikit-learn) (1.26.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: graphviz in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (3.7.2)
# Requirement already satisfied: pandas>=0.24 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (2.0.3)
# Requirement already satisfied: plotly in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (5.18.0)
# Requirement already satisfied: six in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: alembic>=1.5.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (1.13.1)
# Requirement already satisfied: colorlog in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (6.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (2.0.25)
# Requirement already satisfied: PyYAML in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (6.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (6.25.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: imbalanced-learn in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from imblearn) (0.12.0)
# Requirement already satisfied: Mako in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (1.3.2)
# Requirement already satisfied: typing-extensions>=4 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (4.9.0)
# Requirement already satisfied: comm>=0.1.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: psutil in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.3)
# Requirement already satisfied: backcall in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pickleshare in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: greenlet!=0.4.17 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from plotly->catboost) (8.2.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: entrypoints in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# Requirement already satisfied: executing in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# WARNING: There was an error checking the latest version of pip.

# %%
import pandas as pd
import sklearn
import numpy as np
import random
import os
from imblearn.over_sampling import BorderlineSMOTE
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
import optuna
from optuna.samplers import TPESampler
from optuna.pruners import SuccessiveHalvingPruner
from catboost import CatBoostClassifier, Pool

import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import StratifiedKFold

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed=42
seed_everything(seed) # Seed 고정

# %%
df_train = pd.read_csv("train.csv") # 학습용 데이터
df_test = pd.read_csv("submission.csv") # 테스트 데이터(제출파일의 데이터)

# %%
def category_all(df_train, df_test):
    label_columns = [
    "customer_country",
    "business_subarea",
    "business_area",
    "business_unit",
    "customer_type",
    "enterprise",
    "customer_job",
    "inquiry_type",
    "product_category",
    "product_subcategory",
    "product_modelname",
    "customer_position",
    "response_corporate",
    "expected_timeline",
    'customer_idx',
    'lead_owner',

    ]
    for i in label_columns:
        df_train[i] = df_train[i].astype('category')
        df_test[i] = df_test[i].astype('category')
    return df_train, df_test    


def preprocessing(df_train, df_test):
    df_train.drop_duplicates(keep='first', inplace=True)
    df_train.reset_index(inplace=True)
    df_train.drop('index',inplace=True, axis=1)
    df_test_id_temp = df_test['id'].copy()
    df_all = pd.concat([df_train,df_test.drop('id',axis=1)])
    df_all.drop('customer_country.1',axis=1,inplace=True)
    df_all.id_strategic_ver.fillna(0., inplace=True)
    df_all.it_strategic_ver.fillna(0., inplace=True)
    df_all.idit_strategic_ver.fillna(0., inplace=True)
    df_all.business_subarea.fillna('NAN', inplace=True)
    df_all.com_reg_ver_win_rate.fillna(0,inplace=True)
    df_all['customer_type'] = df_all['customer_type'].replace({
        'End-Customer':'End Customer'
    })
    df_all.customer_type.fillna('NAN',inplace=True)
    df_all.historical_existing_cnt.fillna(0, inplace=True)
    
    df_all.product_subcategory.fillna('NAN', inplace=True)
    
    df_all.product_modelname.fillna('NAN', inplace=True)

    df_all['expected_timeline'] = df_all['expected_timeline'].replace({
        'less_than_3_months': 'less than 3 months',
        'being followed up': 'being followed up.',
        'less than 6 months': '3 months ~ 6 months',
        '3_months_~_6_months' : '3 months ~ 6 months'
    })

    df_all.expected_timeline.fillna('NAN',inplace=True)
    df_all.ver_win_rate_x.fillna(0,inplace=True)
    df_all.ver_win_ratio_per_bu.fillna(0,inplace=True)
    df_all.business_area.fillna('NAN',inplace=True)
    df_all.customer_job.fillna('NAN', inplace=True)
    df_all.product_category.fillna('NAN', inplace=True)
    
    #처리못한부분
    #customer_country
    df_all.customer_country.fillna('NAN', inplace=True)
    #inquiry_type
    df_all.inquiry_type.fillna('NAN', inplace=True)

    label_columns = [
    "customer_country",
    "business_subarea",
    "business_area",
    "business_unit",
    "customer_type",
    "enterprise",
    "customer_job",
    "inquiry_type",
    "product_category",
    "product_subcategory",
    "product_modelname",
    "customer_position",
    "response_corporate",
    "expected_timeline",
    ]
    
    ###############################
    #detect special char and to lower
    for i in label_columns:
        df_all[i] = df_all[i].str.lower()
        df_all[i] = df_all[i].str.replace(pat=r'[^\w]', repl=r'', regex=True)
        
    #to int
    df_all['id_strategic_ver'] = df_all['id_strategic_ver'].astype('int64')
    df_all['it_strategic_ver'] = df_all['it_strategic_ver'].astype('int64')
    df_all['idit_strategic_ver'] = df_all['idit_strategic_ver'].astype('int64')
    df_all['lead_desc_length'] = df_all['lead_desc_length'].astype('int64')
    df_all['historical_existing_cnt'] = df_all['historical_existing_cnt'].astype('int64')
    
    #seperate
    tmp_len = len(df_train)
    df_train = df_all.iloc[: tmp_len ]
    df_test = df_all.iloc[tmp_len :]
    df_test = pd.concat([df_test,df_test_id_temp],axis=1)
    
    #RobustScaler
    robustScaler = RobustScaler()
    df_train['ver_win_rate_x'] = robustScaler.fit_transform(df_train[['ver_win_rate_x']])
    df_test['ver_win_rate_x'] = robustScaler.transform(df_test[['ver_win_rate_x']])
    robustScaler = RobustScaler()
    df_train['ver_win_ratio_per_bu'] = robustScaler.fit_transform(df_train[['ver_win_ratio_per_bu']])
    df_test['ver_win_ratio_per_bu'] = robustScaler.transform(df_test[['ver_win_ratio_per_bu']])
    ##############################
    
    return df_train, df_test


df_train, df_test = preprocessing(df_train, df_test)
df_train, df_test = category_all(df_train, df_test)
rate = ((len(df_train)-sum(df_train['is_converted']))/sum(df_train['is_converted']))
x_train, y_train = df_train.drop("is_converted",axis=1), df_train["is_converted"]

# %%
categorical_features = [
    "customer_country",
    "business_subarea",
    "business_area",
    "business_unit",
    "customer_type",
    "enterprise",
    "customer_job",
    "inquiry_type",
    "product_category",
    "product_subcategory",
    "product_modelname",
    "customer_position",
    "response_corporate",
    "expected_timeline",
   'customer_idx',
   'lead_owner',
    ]

S_kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)

all_train_pool = []
all_val_pool = []
all_y_val = []
for train_idx, val_idx in S_kfold.split(x_train, list(y_train)):
    tmp_x_train, tmp_x_val = x_train.iloc[train_idx], x_train.iloc[val_idx]
    tmp_y_train, tmp_y_val = y_train[train_idx], y_train[val_idx]
    train_pool = Pool(data=tmp_x_train, label=tmp_y_train, cat_features=categorical_features)
    val_pool = Pool(data=tmp_x_val, label=tmp_y_val, cat_features=categorical_features)
    all_train_pool.append(train_pool)
    all_val_pool.append(val_pool)
    all_y_val.append(list(tmp_y_val))

# %%
def objective(trial):
    params = {'iterations':trial.suggest_int("iterations", 10000, 50000),
        'learning_rate' : trial.suggest_float('learning_rate',0.001, 1),
        'reg_lambda': trial.suggest_float('reg_lambda',10,100),
        'random_strength': trial.suggest_float('random_strength',40,100),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf',1,50),
        'leaf_estimation_iterations': trial.suggest_int('leaf_estimation_iterations',1,15),
        'bagging_temperature' :trial.suggest_float('bagging_temperature', 0, 1),
              'one_hot_max_size':trial.suggest_int('one_hot_max_size',1,10),
             }
    
    #score = []
    tmp_score = []
    for train_pool, val_pool, y_true in zip(all_train_pool, all_val_pool, all_y_val):
        clf = CatBoostClassifier(**params,
                                 scale_pos_weight=rate, 
                                 loss_function='Logloss',
                                 eval_metric='F1',
                                 early_stopping_rounds=100,
                                 verbose=False,
                                random_state=seed,
                                 task_type="GPU",
                                 devices='0',
                                 
                                )
        clf.fit(train_pool, eval_set=val_pool)
        
        y_pred = clf.predict(val_pool)
        y_pred = [False if i=='False' else True for i in y_pred]
        tmp_score.append(f1_score(y_true,y_pred,labels=[True, False]))
    tmp_score = np.mean(tmp_score)
    return tmp_score

# Hyperparameter Tuning
study = optuna.create_study(direction='maximize', sampler=TPESampler(seed=seed), pruner=SuccessiveHalvingPruner())
study.optimize(objective, n_trials=None)
# Out:
# [I 2024-02-16 19:44:46,090] A new study created in memory with name: no-name-bf567ebd-17d8-4c34-8f9b-54fbaa098b17
# [I 2024-02-16 19:45:07,732] Trial 0 finished with value: 0.7706675109463528 and parameters: {'iterations': 24981, 'learning_rate': 0.9507635921035062, 'reg_lambda': 75.87945476302646, 'random_strength': 75.91950905182219, 'min_data_in_leaf': 8, 'leaf_estimation_iterations': 3, 'bagging_temperature': 0.05808361216819946, 'one_hot_max_size': 9}. Best is trial 0 with value: 0.7706675109463528.
# [I 2024-02-16 19:45:26,031] Trial 1 finished with value: 0.7636447433088056 and parameters: {'iterations': 34045, 'learning_rate': 0.7083645052182495, 'reg_lambda': 11.85260448662222, 'random_strength': 98.19459112971967, 'min_data_in_leaf': 42, 'leaf_estimation_iterations': 4, 'bagging_temperature': 0.18182496720710062, 'one_hot_max_size': 2}. Best is trial 0 with value: 0.7706675109463528.
# [I 2024-02-16 19:45:47,722] Trial 2 finished with value: 0.7665065827936256 and parameters: {'iterations': 22169, 'learning_rate': 0.5252316752006057, 'reg_lambda': 48.87505167779042, 'random_strength': 57.47374841188251, 'min_data_in_leaf': 31, 'leaf_estimation_iterations': 3, 'bagging_temperature': 0.29214464853521815, 'one_hot_max_size': 4}. Best is trial 0 with value: 0.7706675109463528.
# [I 2024-02-16 19:46:12,157] Trial 3 finished with value: 0.7748723563633064 and parameters: {'iterations': 28243, 'learning_rate': 0.7853907854316206, 'reg_lambda': 27.970640394252378, 'random_strength': 70.8540663048167, 'min_data_in_leaf': 30, 'leaf_estimation_iterations': 1, 'bagging_temperature': 0.6075448519014384, 'one_hot_max_size': 2}. Best is trial 3 with value: 0.7748723563633064.
# [I 2024-02-16 19:46:31,594] Trial 4 finished with value: 0.7564070411234326 and parameters: {'iterations': 12602, 'learning_rate': 0.9489366517160799, 'reg_lambda': 96.90688297671034, 'random_strength': 88.50384088698766, 'min_data_in_leaf': 16, 'leaf_estimation_iterations': 2, 'bagging_temperature': 0.6842330265121569, 'one_hot_max_size': 5}. Best is trial 3 with value: 0.7748723563633064.
# [I 2024-02-16 19:46:56,655] Trial 5 finished with value: 0.7765823172124836 and parameters: {'iterations': 14881, 'learning_rate': 0.49568173320115894, 'reg_lambda': 13.094966900369656, 'random_strength': 94.55922412472692, 'min_data_in_leaf': 13, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.31171107608941095, 'one_hot_max_size': 6}. Best is trial 5 with value: 0.7765823172124836.
# [I 2024-02-16 19:47:36,512] Trial 6 finished with value: 0.7698397952429026 and parameters: {'iterations': 31868, 'learning_rate': 0.18566960107000152, 'reg_lambda': 97.26261649881027, 'random_strength': 86.50796940166687, 'min_data_in_leaf': 47, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.5978999788110851, 'one_hot_max_size': 10}. Best is trial 5 with value: 0.7765823172124836.
# [I 2024-02-16 19:48:06,813] Trial 7 finished with value: 0.7711392866802891 and parameters: {'iterations': 13539, 'learning_rate': 0.19678687955672605, 'reg_lambda': 14.070456001948425, 'random_strength': 59.519819845795865, 'min_data_in_leaf': 20, 'leaf_estimation_iterations': 5, 'bagging_temperature': 0.8287375091519293, 'one_hot_max_size': 4}. Best is trial 5 with value: 0.7765823172124836.
# [I 2024-02-16 19:48:34,735] Trial 8 finished with value: 0.7685951836270881 and parameters: {'iterations': 21237, 'learning_rate': 0.5431533870750902, 'reg_lambda': 22.683180247728636, 'random_strength': 88.13181884524238, 'min_data_in_leaf': 4, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.7722447692966574, 'one_hot_max_size': 2}. Best is trial 5 with value: 0.7765823172124836.
# [I 2024-02-16 19:48:55,950] Trial 9 finished with value: 0.7644934726508983 and parameters: {'iterations': 10220, 'learning_rate': 0.8156459670263794, 'reg_lambda': 73.61716094628554, 'random_strength': 83.74043008245924, 'min_data_in_leaf': 39, 'leaf_estimation_iterations': 2, 'bagging_temperature': 0.3584657285442726, 'one_hot_max_size': 2}. Best is trial 5 with value: 0.7765823172124836.
# [I 2024-02-16 19:50:28,120] Trial 10 finished with value: 0.7077362791804556 and parameters: {'iterations': 47806, 'learning_rate': 0.006991185772861341, 'reg_lambda': 43.185589544898754, 'random_strength': 41.077712536889166, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.9597707459454197, 'one_hot_max_size': 7}. Best is trial 5 with value: 0.7765823172124836.
# [I 2024-02-16 19:50:56,195] Trial 11 finished with value: 0.7764837926786848 and parameters: {'iterations': 39787, 'learning_rate': 0.3802246391768034, 'reg_lambda': 32.141334787017726, 'random_strength': 66.39695227169695, 'min_data_in_leaf': 29, 'leaf_estimation_iterations': 8, 'bagging_temperature': 0.4597438080938134, 'one_hot_max_size': 7}. Best is trial 5 with value: 0.7765823172124836.
# [I 2024-02-16 19:51:23,324] Trial 12 finished with value: 0.7735010937656088 and parameters: {'iterations': 40141, 'learning_rate': 0.3638896322192889, 'reg_lambda': 34.02919656508325, 'random_strength': 63.255652243837645, 'min_data_in_leaf': 24, 'leaf_estimation_iterations': 8, 'bagging_temperature': 0.43210514375940035, 'one_hot_max_size': 7}. Best is trial 5 with value: 0.7765823172124836.
# [I 2024-02-16 19:51:50,790] Trial 13 finished with value: 0.7708671772805201 and parameters: {'iterations': 40877, 'learning_rate': 0.35420746126689523, 'reg_lambda': 36.84473238520276, 'random_strength': 47.81274626759499, 'min_data_in_leaf': 11, 'leaf_estimation_iterations': 8, 'bagging_temperature': 0.28606500146797464, 'one_hot_max_size': 7}. Best is trial 5 with value: 0.7765823172124836.
# [I 2024-02-16 19:52:18,630] Trial 14 finished with value: 0.7737647783328029 and parameters: {'iterations': 41437, 'learning_rate': 0.369485947661933, 'reg_lambda': 22.155266033628013, 'random_strength': 98.687486165329, 'min_data_in_leaf': 1, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.4826583456299786, 'one_hot_max_size': 8}. Best is trial 5 with value: 0.7765823172124836.
# [I 2024-02-16 19:52:45,063] Trial 15 finished with value: 0.7794830800652497 and parameters: {'iterations': 49942, 'learning_rate': 0.651576703111257, 'reg_lambda': 60.291872473898295, 'random_strength': 77.77242273310715, 'min_data_in_leaf': 30, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.09208715045520904, 'one_hot_max_size': 6}. Best is trial 15 with value: 0.7794830800652497.
# [I 2024-02-16 19:53:07,542] Trial 16 finished with value: 0.7657049701175708 and parameters: {'iterations': 17347, 'learning_rate': 0.6407874306181476, 'reg_lambda': 62.432475457075775, 'random_strength': 79.42296676751583, 'min_data_in_leaf': 37, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.00474011965308907, 'one_hot_max_size': 5}. Best is trial 15 with value: 0.7794830800652497.
# [I 2024-02-16 19:53:35,450] Trial 17 finished with value: 0.7785448197268232 and parameters: {'iterations': 49383, 'learning_rate': 0.6263719269016417, 'reg_lambda': 60.62615713228074, 'random_strength': 93.26646825016853, 'min_data_in_leaf': 21, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.1662549872981561, 'one_hot_max_size': 6}. Best is trial 15 with value: 0.7794830800652497.
# [I 2024-02-16 19:54:03,504] Trial 18 finished with value: 0.7759627741184683 and parameters: {'iterations': 49711, 'learning_rate': 0.6441775570286266, 'reg_lambda': 59.85734832768788, 'random_strength': 73.87474680559755, 'min_data_in_leaf': 22, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.13248851823938035, 'one_hot_max_size': 4}. Best is trial 15 with value: 0.7794830800652497.
# [I 2024-02-16 19:54:25,671] Trial 19 finished with value: 0.7619167333563739 and parameters: {'iterations': 45572, 'learning_rate': 0.8571822294589448, 'reg_lambda': 73.14924220653928, 'random_strength': 81.00336761935009, 'min_data_in_leaf': 27, 'leaf_estimation_iterations': 6, 'bagging_temperature': 0.1641468244771359, 'one_hot_max_size': 6}. Best is trial 15 with value: 0.7794830800652497.
# [I 2024-02-16 19:54:49,225] Trial 20 finished with value: 0.765167430344389 and parameters: {'iterations': 44902, 'learning_rate': 0.6818055091450831, 'reg_lambda': 84.21690029697825, 'random_strength': 92.47414473406278, 'min_data_in_leaf': 34, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.09895101585699186, 'one_hot_max_size': 9}. Best is trial 15 with value: 0.7794830800652497.
# [I 2024-02-16 19:55:14,696] Trial 21 finished with value: 0.7690790517817783 and parameters: {'iterations': 35711, 'learning_rate': 0.4844323020870215, 'reg_lambda': 49.999097286613036, 'random_strength': 93.40912739671238, 'min_data_in_leaf': 16, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.24828688471803845, 'one_hot_max_size': 6}. Best is trial 15 with value: 0.7794830800652497.
# [I 2024-02-16 19:55:41,271] Trial 22 finished with value: 0.7763385433996177 and parameters: {'iterations': 44644, 'learning_rate': 0.5661587419145809, 'reg_lambda': 62.354042351975686, 'random_strength': 92.1411634518281, 'min_data_in_leaf': 19, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.3595176417317194, 'one_hot_max_size': 5}. Best is trial 15 with value: 0.7794830800652497.
# [I 2024-02-16 19:56:08,138] Trial 23 finished with value: 0.7757814838171191 and parameters: {'iterations': 49295, 'learning_rate': 0.4834067841825069, 'reg_lambda': 52.88153230507832, 'random_strength': 99.65695490874621, 'min_data_in_leaf': 8, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.21904737194116958, 'one_hot_max_size': 6}. Best is trial 15 with value: 0.7794830800652497.
# [I 2024-02-16 19:56:28,429] Trial 24 finished with value: 0.7588148526892879 and parameters: {'iterations': 37061, 'learning_rate': 0.7337224065172883, 'reg_lambda': 66.5529368396361, 'random_strength': 78.58441968019048, 'min_data_in_leaf': 25, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.07258771759943658, 'one_hot_max_size': 8}. Best is trial 15 with value: 0.7794830800652497.
# [I 2024-02-16 19:56:55,611] Trial 25 finished with value: 0.7698141336482041 and parameters: {'iterations': 27088, 'learning_rate': 0.598157305530624, 'reg_lambda': 42.60748691948914, 'random_strength': 93.32623066233025, 'min_data_in_leaf': 11, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.3569905551576711, 'one_hot_max_size': 3}. Best is trial 15 with value: 0.7794830800652497.
# [I 2024-02-16 19:57:19,962] Trial 26 finished with value: 0.7687471818762829 and parameters: {'iterations': 17546, 'learning_rate': 0.42874391535626183, 'reg_lambda': 85.14498146631307, 'random_strength': 83.90425501221166, 'min_data_in_leaf': 20, 'leaf_estimation_iterations': 7, 'bagging_temperature': 0.18167668860820096, 'one_hot_max_size': 8}. Best is trial 15 with value: 0.7794830800652497.
# [I 2024-02-16 19:57:59,362] Trial 27 finished with value: 0.782860316614663 and parameters: {'iterations': 43046, 'learning_rate': 0.25938167636995857, 'reg_lambda': 57.76634553758225, 'random_strength': 95.5075880644565, 'min_data_in_leaf': 34, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.0209928166776997, 'one_hot_max_size': 6}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 19:58:36,742] Trial 28 finished with value: 0.7759273386114391 and parameters: {'iterations': 46656, 'learning_rate': 0.23812273877491785, 'reg_lambda': 57.21707163013048, 'random_strength': 69.2655825529456, 'min_data_in_leaf': 34, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.006009591566264266, 'one_hot_max_size': 5}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 19:59:24,310] Trial 29 finished with value: 0.760660800786759 and parameters: {'iterations': 42909, 'learning_rate': 0.07573866450850411, 'reg_lambda': 67.80713874978565, 'random_strength': 74.26028463392723, 'min_data_in_leaf': 42, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.057609761891619836, 'one_hot_max_size': 3}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 19:59:58,544] Trial 30 finished with value: 0.7776907756083771 and parameters: {'iterations': 49623, 'learning_rate': 0.26329507095281696, 'reg_lambda': 80.60335249162182, 'random_strength': 89.89390874540176, 'min_data_in_leaf': 34, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.09055304247260983, 'one_hot_max_size': 9}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:00:33,784] Trial 31 finished with value: 0.7783739268633106 and parameters: {'iterations': 49694, 'learning_rate': 0.2873929145834557, 'reg_lambda': 82.78950651303751, 'random_strength': 88.293231582865, 'min_data_in_leaf': 33, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.07771845570324562, 'one_hot_max_size': 10}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:01:14,503] Trial 32 finished with value: 0.7821386478145401 and parameters: {'iterations': 46916, 'learning_rate': 0.29200124569905456, 'reg_lambda': 68.68757556350653, 'random_strength': 83.56714734580592, 'min_data_in_leaf': 38, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.012598265601507341, 'one_hot_max_size': 10}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:02:02,077] Trial 33 finished with value: 0.7743327934852422 and parameters: {'iterations': 44151, 'learning_rate': 0.1394362687792858, 'reg_lambda': 66.76329823569797, 'random_strength': 83.54234428940553, 'min_data_in_leaf': 46, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.02796929013570261, 'one_hot_max_size': 1}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:02:25,589] Trial 34 finished with value: 0.7678757663651155 and parameters: {'iterations': 37906, 'learning_rate': 0.7478674388158482, 'reg_lambda': 54.703196185294175, 'random_strength': 77.32033489225599, 'min_data_in_leaf': 38, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.1447689280267767, 'one_hot_max_size': 9}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:02:58,623] Trial 35 finished with value: 0.7813043403894617 and parameters: {'iterations': 47165, 'learning_rate': 0.29336289513641567, 'reg_lambda': 43.96263593048784, 'random_strength': 95.67305382434704, 'min_data_in_leaf': 50, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.1922729720807858, 'one_hot_max_size': 8}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:03:28,751] Trial 36 finished with value: 0.7738673053754349 and parameters: {'iterations': 47154, 'learning_rate': 0.31116243405953736, 'reg_lambda': 46.05795099852094, 'random_strength': 70.75685262998562, 'min_data_in_leaf': 49, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.24351455447877157, 'one_hot_max_size': 10}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:04:02,800] Trial 37 finished with value: 0.7698602444919774 and parameters: {'iterations': 33483, 'learning_rate': 0.19115741371331216, 'reg_lambda': 41.404020352547825, 'random_strength': 96.97471859311798, 'min_data_in_leaf': 44, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.11081717536012332, 'one_hot_max_size': 8}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:04:45,320] Trial 38 finished with value: 0.7635717262627739 and parameters: {'iterations': 42971, 'learning_rate': 0.10353499483576192, 'reg_lambda': 89.26993930231762, 'random_strength': 97.10451202229699, 'min_data_in_leaf': 41, 'leaf_estimation_iterations': 7, 'bagging_temperature': 0.5576267343225451, 'one_hot_max_size': 10}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:05:14,355] Trial 39 finished with value: 0.7741278159547116 and parameters: {'iterations': 47584, 'learning_rate': 0.42221780345709226, 'reg_lambda': 77.81924634359993, 'random_strength': 85.51103248006578, 'min_data_in_leaf': 31, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.04729513670588531, 'one_hot_max_size': 7}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:05:40,255] Trial 40 finished with value: 0.7680678314330677 and parameters: {'iterations': 42515, 'learning_rate': 0.4352188192269072, 'reg_lambda': 49.83919040075106, 'random_strength': 81.5133471830026, 'min_data_in_leaf': 49, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.0027282579237936123, 'one_hot_max_size': 9}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:06:19,606] Trial 41 finished with value: 0.7805873409586704 and parameters: {'iterations': 46357, 'learning_rate': 0.22592331042135422, 'reg_lambda': 69.22965190292643, 'random_strength': 89.50358312919043, 'min_data_in_leaf': 36, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.15376409121703766, 'one_hot_max_size': 6}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:06:51,168] Trial 42 finished with value: 0.7714970949178253 and parameters: {'iterations': 46258, 'learning_rate': 0.2352944240272729, 'reg_lambda': 69.8533867015491, 'random_strength': 89.20801401324123, 'min_data_in_leaf': 37, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.21248679433109266, 'one_hot_max_size': 5}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:07:20,437] Trial 43 finished with value: 0.7738022830561302 and parameters: {'iterations': 38448, 'learning_rate': 0.3216563317821338, 'reg_lambda': 72.21087477625362, 'random_strength': 95.55065457059318, 'min_data_in_leaf': 40, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.1294790466413386, 'one_hot_max_size': 7}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:07:55,983] Trial 44 finished with value: 0.7661521828945969 and parameters: {'iterations': 44267, 'learning_rate': 0.16357185289429152, 'reg_lambda': 57.27462910639068, 'random_strength': 90.81627596679985, 'min_data_in_leaf': 28, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.272621866798451, 'one_hot_max_size': 8}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:09:08,414] Trial 45 finished with value: 0.7644918485604592 and parameters: {'iterations': 30572, 'learning_rate': 0.050761957292750404, 'reg_lambda': 64.39483538160755, 'random_strength': 86.33484478047153, 'min_data_in_leaf': 44, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.1962019696946863, 'one_hot_max_size': 6}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:09:49,857] Trial 46 finished with value: 0.7799854189135674 and parameters: {'iterations': 47475, 'learning_rate': 0.22728826243724257, 'reg_lambda': 76.76414088909317, 'random_strength': 96.04933039382179, 'min_data_in_leaf': 31, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.32186948955870587, 'one_hot_max_size': 4}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:10:29,928] Trial 47 finished with value: 0.7752283209820015 and parameters: {'iterations': 47602, 'learning_rate': 0.22595325917777037, 'reg_lambda': 78.26874194932394, 'random_strength': 95.8694720564402, 'min_data_in_leaf': 32, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.32804536316687744, 'one_hot_max_size': 3}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:11:10,929] Trial 48 finished with value: 0.7643076108333589 and parameters: {'iterations': 42001, 'learning_rate': 0.1175827532706415, 'reg_lambda': 91.90360338317032, 'random_strength': 99.6905154074294, 'min_data_in_leaf': 36, 'leaf_estimation_iterations': 4, 'bagging_temperature': 0.42861685252862985, 'one_hot_max_size': 4}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:11:46,217] Trial 49 finished with value: 0.7714108781582738 and parameters: {'iterations': 40503, 'learning_rate': 0.27697508020398554, 'reg_lambda': 71.2396654883532, 'random_strength': 55.310985381541876, 'min_data_in_leaf': 45, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.6919198144499179, 'one_hot_max_size': 4}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:12:18,201] Trial 50 finished with value: 0.7742470786367117 and parameters: {'iterations': 38885, 'learning_rate': 0.32959433184044357, 'reg_lambda': 75.33878917015785, 'random_strength': 94.82246188586366, 'min_data_in_leaf': 36, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.41001057970048976, 'one_hot_max_size': 4}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:12:55,456] Trial 51 finished with value: 0.7687959341024417 and parameters: {'iterations': 47786, 'learning_rate': 0.17013894339082433, 'reg_lambda': 53.40844686994859, 'random_strength': 86.39292789199327, 'min_data_in_leaf': 30, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.04814185556825937, 'one_hot_max_size': 7}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:13:17,277] Trial 52 finished with value: 0.7617279791748371 and parameters: {'iterations': 45873, 'learning_rate': 0.9790210452510617, 'reg_lambda': 58.567878482879244, 'random_strength': 90.8516673025599, 'min_data_in_leaf': 27, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.13383423747409634, 'one_hot_max_size': 5}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:13:52,796] Trial 53 finished with value: 0.7691166980595152 and parameters: {'iterations': 48436, 'learning_rate': 0.20331675560454102, 'reg_lambda': 64.11393036999169, 'random_strength': 80.6061320147162, 'min_data_in_leaf': 23, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.17449977927914462, 'one_hot_max_size': 6}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:14:22,087] Trial 54 finished with value: 0.7783090524397964 and parameters: {'iterations': 45481, 'learning_rate': 0.39205881796182607, 'reg_lambda': 38.70999759193997, 'random_strength': 75.25844796476125, 'min_data_in_leaf': 29, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.1036518413833738, 'one_hot_max_size': 7}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:16:07,081] Trial 55 finished with value: 0.723522804974043 and parameters: {'iterations': 43848, 'learning_rate': 0.011131352146107193, 'reg_lambda': 69.6359182838604, 'random_strength': 83.49178466273356, 'min_data_in_leaf': 39, 'leaf_estimation_iterations': 8, 'bagging_temperature': 0.27293301935079156, 'one_hot_max_size': 5}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:16:47,378] Trial 56 finished with value: 0.7826624313247948 and parameters: {'iterations': 46646, 'learning_rate': 0.2657444730943023, 'reg_lambda': 75.57873172110408, 'random_strength': 97.92588371770603, 'min_data_in_leaf': 35, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.23908541738362926, 'one_hot_max_size': 9}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:17:21,775] Trial 57 finished with value: 0.7743769635103839 and parameters: {'iterations': 23374, 'learning_rate': 0.2608906504347734, 'reg_lambda': 88.16226898927528, 'random_strength': 97.61893706813875, 'min_data_in_leaf': 35, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.9881136084991532, 'one_hot_max_size': 9}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:17:57,366] Trial 58 finished with value: 0.7802870806148248 and parameters: {'iterations': 46111, 'learning_rate': 0.30148009105789375, 'reg_lambda': 76.21889384514361, 'random_strength': 94.61581827438684, 'min_data_in_leaf': 32, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.3227625191483746, 'one_hot_max_size': 10}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:18:27,550] Trial 59 finished with value: 0.7732953594838599 and parameters: {'iterations': 40977, 'learning_rate': 0.3478797623442892, 'reg_lambda': 94.42052031742386, 'random_strength': 91.51509946188965, 'min_data_in_leaf': 43, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.23761801106884908, 'one_hot_max_size': 10}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:19:00,099] Trial 60 finished with value: 0.7754429931047998 and parameters: {'iterations': 35973, 'learning_rate': 0.30503693882120725, 'reg_lambda': 28.826990464527224, 'random_strength': 94.10487158361482, 'min_data_in_leaf': 40, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.5299750241904642, 'one_hot_max_size': 10}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:19:35,493] Trial 61 finished with value: 0.7736263613097496 and parameters: {'iterations': 46239, 'learning_rate': 0.22218664148174133, 'reg_lambda': 75.26996447523746, 'random_strength': 99.87490283165504, 'min_data_in_leaf': 32, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.30114285259468676, 'one_hot_max_size': 9}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:20:06,507] Trial 62 finished with value: 0.7772955353862353 and parameters: {'iterations': 48567, 'learning_rate': 0.4004476584801975, 'reg_lambda': 78.68064649394593, 'random_strength': 96.1302236795942, 'min_data_in_leaf': 26, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.3831235316366729, 'one_hot_max_size': 10}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:20:48,920] Trial 63 finished with value: 0.7689850937031164 and parameters: {'iterations': 43135, 'learning_rate': 0.14556040783511237, 'reg_lambda': 81.88372929436893, 'random_strength': 97.72004254357631, 'min_data_in_leaf': 38, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.3285412125995003, 'one_hot_max_size': 9}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:21:25,940] Trial 64 finished with value: 0.7648929485572323 and parameters: {'iterations': 44951, 'learning_rate': 0.25805227081558396, 'reg_lambda': 74.06842549576646, 'random_strength': 94.38407536867626, 'min_data_in_leaf': 32, 'leaf_estimation_iterations': 1, 'bagging_temperature': 0.21366782765066203, 'one_hot_max_size': 8}. Best is trial 27 with value: 0.782860316614663.
# [I 2024-02-16 20:21:57,847] Trial 65 finished with value: 0.7830489349135604 and parameters: {'iterations': 46955, 'learning_rate': 0.34890567536531836, 'reg_lambda': 45.51401491880683, 'random_strength': 88.69247333624718, 'min_data_in_leaf': 34, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.16008618507128053, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:22:28,995] Trial 66 finished with value: 0.7826525407463201 and parameters: {'iterations': 46534, 'learning_rate': 0.34932322065576016, 'reg_lambda': 35.506388575465266, 'random_strength': 92.33806090929015, 'min_data_in_leaf': 35, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.14561570045382044, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:22:55,872] Trial 67 finished with value: 0.7739662355853477 and parameters: {'iterations': 48870, 'learning_rate': 0.4519608517509271, 'reg_lambda': 45.6380992503549, 'random_strength': 87.65161963385033, 'min_data_in_leaf': 47, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.16053436773410434, 'one_hot_max_size': 9}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:23:27,471] Trial 68 finished with value: 0.7799011028122663 and parameters: {'iterations': 41757, 'learning_rate': 0.34649221586165296, 'reg_lambda': 31.845154920061074, 'random_strength': 89.59850911034705, 'min_data_in_leaf': 34, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.04262195202699426, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:23:55,390] Trial 69 finished with value: 0.7800373002847139 and parameters: {'iterations': 39607, 'learning_rate': 0.3761690372132749, 'reg_lambda': 20.468524275743395, 'random_strength': 92.07762736530293, 'min_data_in_leaf': 36, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.07331104599997679, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:24:23,701] Trial 70 finished with value: 0.7761252586664265 and parameters: {'iterations': 44245, 'learning_rate': 0.5169612019535504, 'reg_lambda': 34.64960041432075, 'random_strength': 84.75240227388576, 'min_data_in_leaf': 38, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.10973856544074853, 'one_hot_max_size': 9}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:24:55,567] Trial 71 finished with value: 0.7727987329122914 and parameters: {'iterations': 46590, 'learning_rate': 0.3090023196991626, 'reg_lambda': 45.50398085003506, 'random_strength': 88.21569630402153, 'min_data_in_leaf': 35, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.25757488024312114, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:25:28,737] Trial 72 finished with value: 0.7783420221960166 and parameters: {'iterations': 45565, 'learning_rate': 0.27683741910573323, 'reg_lambda': 38.779200875507215, 'random_strength': 92.9938842940649, 'min_data_in_leaf': 42, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.18926736957354612, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:26:00,916] Trial 73 finished with value: 0.7787634631831637 and parameters: {'iterations': 43681, 'learning_rate': 0.28486771449382736, 'reg_lambda': 48.20990174429974, 'random_strength': 98.08485545572556, 'min_data_in_leaf': 33, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.14782859497758025, 'one_hot_max_size': 9}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:26:35,367] Trial 74 finished with value: 0.7685042735087549 and parameters: {'iterations': 48315, 'learning_rate': 0.2003056616711582, 'reg_lambda': 51.872452393752006, 'random_strength': 91.0948592818406, 'min_data_in_leaf': 29, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.02266236052694214, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:27:05,918] Trial 75 finished with value: 0.782993777892554 and parameters: {'iterations': 46677, 'learning_rate': 0.3614373371799665, 'reg_lambda': 25.651436631802028, 'random_strength': 93.52177552528521, 'min_data_in_leaf': 50, 'leaf_estimation_iterations': 6, 'bagging_temperature': 0.22895548652691933, 'one_hot_max_size': 8}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:27:30,518] Trial 76 finished with value: 0.7746678724724303 and parameters: {'iterations': 47070, 'learning_rate': 0.35575028097508876, 'reg_lambda': 17.208884313696384, 'random_strength': 87.11451586566886, 'min_data_in_leaf': 50, 'leaf_estimation_iterations': 5, 'bagging_temperature': 0.22549768008687637, 'one_hot_max_size': 8}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:28:00,132] Trial 77 finished with value: 0.7770928568561282 and parameters: {'iterations': 44961, 'learning_rate': 0.340907630255623, 'reg_lambda': 26.889951911837695, 'random_strength': 89.01806012278499, 'min_data_in_leaf': 48, 'leaf_estimation_iterations': 6, 'bagging_temperature': 0.12737247035613555, 'one_hot_max_size': 9}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:28:27,377] Trial 78 finished with value: 0.7720845752535804 and parameters: {'iterations': 49973, 'learning_rate': 0.3976168219679406, 'reg_lambda': 40.584374556063, 'random_strength': 63.86545057223119, 'min_data_in_leaf': 50, 'leaf_estimation_iterations': 7, 'bagging_temperature': 0.08336079540398722, 'one_hot_max_size': 8}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:28:51,027] Trial 79 finished with value: 0.7692013029742114 and parameters: {'iterations': 41991, 'learning_rate': 0.46460193062091115, 'reg_lambda': 11.808581926920539, 'random_strength': 93.06889340552891, 'min_data_in_leaf': 46, 'leaf_estimation_iterations': 6, 'bagging_temperature': 0.9097597741269523, 'one_hot_max_size': 8}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:29:20,759] Trial 80 finished with value: 0.7739886345368325 and parameters: {'iterations': 48718, 'learning_rate': 0.2482023087044178, 'reg_lambda': 35.24263438675919, 'random_strength': 90.42508225774495, 'min_data_in_leaf': 40, 'leaf_estimation_iterations': 3, 'bagging_temperature': 0.19429163862225038, 'one_hot_max_size': 7}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:29:50,146] Trial 81 finished with value: 0.7749947472234523 and parameters: {'iterations': 46888, 'learning_rate': 0.30099295779331076, 'reg_lambda': 26.31388456925267, 'random_strength': 94.47648959446013, 'min_data_in_leaf': 37, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.28812727730088067, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:30:17,856] Trial 82 finished with value: 0.7731901696020408 and parameters: {'iterations': 45327, 'learning_rate': 0.4191107672259302, 'reg_lambda': 31.063485322309212, 'random_strength': 98.70036163951809, 'min_data_in_leaf': 35, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.16719721735900928, 'one_hot_max_size': 9}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:30:45,555] Trial 83 finished with value: 0.7694165955364806 and parameters: {'iterations': 46175, 'learning_rate': 0.3273282429084195, 'reg_lambda': 68.35378810636064, 'random_strength': 95.54903311705277, 'min_data_in_leaf': 33, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.20573483514515634, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:31:14,422] Trial 84 finished with value: 0.7792545808763294 and parameters: {'iterations': 42963, 'learning_rate': 0.36994096400895177, 'reg_lambda': 43.6119185365073, 'random_strength': 92.17005893169534, 'min_data_in_leaf': 39, 'leaf_estimation_iterations': 4, 'bagging_temperature': 0.2426627328525148, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:31:46,599] Trial 85 finished with value: 0.7715343389824764 and parameters: {'iterations': 47583, 'learning_rate': 0.2129861234366769, 'reg_lambda': 24.41237552102089, 'random_strength': 96.71593428418795, 'min_data_in_leaf': 31, 'leaf_estimation_iterations': 5, 'bagging_temperature': 0.029689731393968324, 'one_hot_max_size': 9}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:32:24,496] Trial 86 finished with value: 0.7801116694088764 and parameters: {'iterations': 10190, 'learning_rate': 0.25349458945149383, 'reg_lambda': 65.45081465209253, 'random_strength': 44.334243462626496, 'min_data_in_leaf': 37, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.12188120739467188, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:33:06,318] Trial 87 finished with value: 0.7714516242062845 and parameters: {'iterations': 44457, 'learning_rate': 0.18321657331316618, 'reg_lambda': 62.14976874775359, 'random_strength': 94.53179817873018, 'min_data_in_leaf': 41, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.07077650137882568, 'one_hot_max_size': 8}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:33:36,484] Trial 88 finished with value: 0.7771005290380976 and parameters: {'iterations': 27282, 'learning_rate': 0.2973919934244753, 'reg_lambda': 48.0286449437433, 'random_strength': 98.66326482693557, 'min_data_in_leaf': 48, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.2639690517756111, 'one_hot_max_size': 9}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:34:06,708] Trial 89 finished with value: 0.777972540129727 and parameters: {'iterations': 48905, 'learning_rate': 0.33460134434979505, 'reg_lambda': 55.13778658055805, 'random_strength': 82.16767102099676, 'min_data_in_leaf': 33, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.15044308982359494, 'one_hot_max_size': 6}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:34:27,178] Trial 90 finished with value: 0.7589027283757603 and parameters: {'iterations': 46441, 'learning_rate': 0.8988332060356069, 'reg_lambda': 86.12621638826037, 'random_strength': 89.53238990183375, 'min_data_in_leaf': 28, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.35349423120135776, 'one_hot_max_size': 7}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:35:02,154] Trial 91 finished with value: 0.7755590243448742 and parameters: {'iterations': 17794, 'learning_rate': 0.25381840764957686, 'reg_lambda': 65.50440409200718, 'random_strength': 52.31846078772835, 'min_data_in_leaf': 36, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.11681378964075195, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:35:29,640] Trial 92 finished with value: 0.7651224476856734 and parameters: {'iterations': 14734, 'learning_rate': 0.2796674807017795, 'reg_lambda': 59.787044832806515, 'random_strength': 42.16477328118407, 'min_data_in_leaf': 37, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.17865153700237324, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:36:09,567] Trial 93 finished with value: 0.7702365128584558 and parameters: {'iterations': 20414, 'learning_rate': 0.16483174973739528, 'reg_lambda': 71.89953139437083, 'random_strength': 42.39677499555534, 'min_data_in_leaf': 34, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.10195765020578915, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:36:44,619] Trial 94 finished with value: 0.7760218247960846 and parameters: {'iterations': 32151, 'learning_rate': 0.3149486088016111, 'reg_lambda': 79.79475371824999, 'random_strength': 72.247763210093, 'min_data_in_leaf': 38, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.002788342973072816, 'one_hot_max_size': 9}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:37:16,755] Trial 95 finished with value: 0.771786697611119 and parameters: {'iterations': 48119, 'learning_rate': 0.24220130393840517, 'reg_lambda': 69.31289682876506, 'random_strength': 67.76489326169359, 'min_data_in_leaf': 44, 'leaf_estimation_iterations': 7, 'bagging_temperature': 0.22361105103880263, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:37:51,920] Trial 96 finished with value: 0.7754959373201669 and parameters: {'iterations': 43474, 'learning_rate': 0.27678647208413376, 'reg_lambda': 63.423971661598145, 'random_strength': 93.36830944878702, 'min_data_in_leaf': 35, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.05911443899905747, 'one_hot_max_size': 9}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:38:34,699] Trial 97 finished with value: 0.7695977780878146 and parameters: {'iterations': 28685, 'learning_rate': 0.13305317294028288, 'reg_lambda': 36.765676562868514, 'random_strength': 62.74208462794422, 'min_data_in_leaf': 30, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.14898437438829182, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:39:09,295] Trial 98 finished with value: 0.7829515686577782 and parameters: {'iterations': 12273, 'learning_rate': 0.3674656952131463, 'reg_lambda': 65.97273336933881, 'random_strength': 86.16345773545171, 'min_data_in_leaf': 42, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.08747962634364287, 'one_hot_max_size': 6}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:39:36,558] Trial 99 finished with value: 0.7759204889920049 and parameters: {'iterations': 11943, 'learning_rate': 0.3795856659360948, 'reg_lambda': 56.65013729157269, 'random_strength': 85.80041655331975, 'min_data_in_leaf': 41, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.4695247194507754, 'one_hot_max_size': 6}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:40:08,183] Trial 100 finished with value: 0.7791691147319304 and parameters: {'iterations': 45383, 'learning_rate': 0.4174042461722433, 'reg_lambda': 67.54908099529828, 'random_strength': 82.51511969088733, 'min_data_in_leaf': 45, 'leaf_estimation_iterations': 8, 'bagging_temperature': 0.032532076360472076, 'one_hot_max_size': 6}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:40:36,811] Trial 101 finished with value: 0.7744028919946262 and parameters: {'iterations': 10729, 'learning_rate': 0.3599776624029441, 'reg_lambda': 65.75594918601846, 'random_strength': 87.66199748467778, 'min_data_in_leaf': 37, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.09148994032818199, 'one_hot_max_size': 7}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:41:08,696] Trial 102 finished with value: 0.7655010924386204 and parameters: {'iterations': 13922, 'learning_rate': 0.23055906857977482, 'reg_lambda': 70.66372710155801, 'random_strength': 44.96158346140622, 'min_data_in_leaf': 43, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.1258086890069888, 'one_hot_max_size': 5}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:41:39,329] Trial 103 finished with value: 0.772325746828061 and parameters: {'iterations': 11220, 'learning_rate': 0.31927065702983065, 'reg_lambda': 73.52510240338299, 'random_strength': 51.58295407394173, 'min_data_in_leaf': 39, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.0585030981288567, 'one_hot_max_size': 6}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:42:14,126] Trial 104 finished with value: 0.7753234350647882 and parameters: {'iterations': 23795, 'learning_rate': 0.26497145492925106, 'reg_lambda': 76.25600024839692, 'random_strength': 79.50931992074965, 'min_data_in_leaf': 32, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.6440103852565682, 'one_hot_max_size': 10}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:42:45,758] Trial 105 finished with value: 0.7814166320650154 and parameters: {'iterations': 12144, 'learning_rate': 0.29100285960610983, 'reg_lambda': 29.331520737169164, 'random_strength': 90.63438113086649, 'min_data_in_leaf': 36, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.18169985710805586, 'one_hot_max_size': 7}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:43:12,552] Trial 106 finished with value: 0.7729689270542979 and parameters: {'iterations': 12542, 'learning_rate': 0.453391397165425, 'reg_lambda': 29.78030131977984, 'random_strength': 91.01638124033065, 'min_data_in_leaf': 34, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.18256520889700112, 'one_hot_max_size': 7}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:43:38,635] Trial 107 finished with value: 0.7761559601575915 and parameters: {'iterations': 47141, 'learning_rate': 0.3947230478257327, 'reg_lambda': 19.747704452941583, 'random_strength': 95.52951852687744, 'min_data_in_leaf': 36, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.23142092697482042, 'one_hot_max_size': 7}. Best is trial 65 with value: 0.7830489349135604.
# [I 2024-02-16 20:44:11,679] Trial 108 finished with value: 0.783867070688819 and parameters: {'iterations': 18501, 'learning_rate': 0.299028263890918, 'reg_lambda': 25.334920744173303, 'random_strength': 84.34080336351649, 'min_data_in_leaf': 35, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.19928112384494767, 'one_hot_max_size': 6}. Best is trial 108 with value: 0.783867070688819.
# [I 2024-02-16 20:44:40,781] Trial 109 finished with value: 0.7749915140360158 and parameters: {'iterations': 16274, 'learning_rate': 0.3387145580866726, 'reg_lambda': 22.61278295977255, 'random_strength': 84.5635579353494, 'min_data_in_leaf': 48, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.20501799033108736, 'one_hot_max_size': 6}. Best is trial 108 with value: 0.783867070688819.
# [I 2024-02-16 20:45:10,582] Trial 110 finished with value: 0.7766692695828208 and parameters: {'iterations': 18546, 'learning_rate': 0.29426295352002707, 'reg_lambda': 25.754805535022843, 'random_strength': 85.46820981560928, 'min_data_in_leaf': 42, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.1387504930244251, 'one_hot_max_size': 6}. Best is trial 108 with value: 0.783867070688819.
# [I 2024-02-16 20:45:47,448] Trial 111 finished with value: 0.7799342728728791 and parameters: {'iterations': 13651, 'learning_rate': 0.2146883495423734, 'reg_lambda': 24.207248811980023, 'random_strength': 92.1839436776857, 'min_data_in_leaf': 35, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.16326657743928083, 'one_hot_max_size': 6}. Best is trial 108 with value: 0.783867070688819.
# [I 2024-02-16 20:46:18,691] Trial 112 finished with value: 0.7766789006448728 and parameters: {'iterations': 15865, 'learning_rate': 0.3097652005553867, 'reg_lambda': 29.581838438098956, 'random_strength': 88.75714509907044, 'min_data_in_leaf': 33, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.30102698051389615, 'one_hot_max_size': 7}. Best is trial 108 with value: 0.783867070688819.
# [I 2024-02-16 20:46:51,603] Trial 113 finished with value: 0.7810037609001808 and parameters: {'iterations': 19603, 'learning_rate': 0.3539503172498958, 'reg_lambda': 34.44285517904386, 'random_strength': 93.56316378841558, 'min_data_in_leaf': 38, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.2684897054717859, 'one_hot_max_size': 5}. Best is trial 108 with value: 0.783867070688819.
# [I 2024-02-16 20:47:24,672] Trial 114 finished with value: 0.7841663256627658 and parameters: {'iterations': 12459, 'learning_rate': 0.3613177781095513, 'reg_lambda': 32.9171899131589, 'random_strength': 90.26361486336376, 'min_data_in_leaf': 40, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.1907297463787061, 'one_hot_max_size': 5}. Best is trial 114 with value: 0.7841663256627658.
# [I 2024-02-16 20:47:55,800] Trial 115 finished with value: 0.7783036174985742 and parameters: {'iterations': 12029, 'learning_rate': 0.35725338514821603, 'reg_lambda': 33.02394052557409, 'random_strength': 87.27784580445605, 'min_data_in_leaf': 38, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.19348169880327964, 'one_hot_max_size': 5}. Best is trial 114 with value: 0.7841663256627658.
# [I 2024-02-16 20:48:23,045] Trial 116 finished with value: 0.7736226019671344 and parameters: {'iterations': 18839, 'learning_rate': 0.4089933801029495, 'reg_lambda': 37.00170370216486, 'random_strength': 97.15585343411186, 'min_data_in_leaf': 40, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.23469001880659932, 'one_hot_max_size': 5}. Best is trial 114 with value: 0.7841663256627658.
# [I 2024-02-16 20:48:52,589] Trial 117 finished with value: 0.7753056503294429 and parameters: {'iterations': 20230, 'learning_rate': 0.37025596028700325, 'reg_lambda': 39.827210253313645, 'random_strength': 90.35079397862506, 'min_data_in_leaf': 43, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.27341934761660314, 'one_hot_max_size': 5}. Best is trial 114 with value: 0.7841663256627658.
# [I 2024-02-16 20:49:19,877] Trial 118 finished with value: 0.7764042838829749 and parameters: {'iterations': 14764, 'learning_rate': 0.38541808535834615, 'reg_lambda': 27.929995474051307, 'random_strength': 93.92496693166002, 'min_data_in_leaf': 46, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.25519146858960506, 'one_hot_max_size': 5}. Best is trial 114 with value: 0.7841663256627658.
# [I 2024-02-16 20:49:46,809] Trial 119 finished with value: 0.7710279949443428 and parameters: {'iterations': 25866, 'learning_rate': 0.3293426888787835, 'reg_lambda': 31.171183032789138, 'random_strength': 92.15295860877059, 'min_data_in_leaf': 39, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.21167552961782252, 'one_hot_max_size': 5}. Best is trial 114 with value: 0.7841663256627658.
# ...
# [I 2024-02-16 23:52:45,955] Trial 481 finished with value: 0.7834869727454563 and parameters: {'iterations': 23505, 'learning_rate': 0.3824843214394266, 'reg_lambda': 13.365922869590225, 'random_strength': 99.10154959653237, 'min_data_in_leaf': 36, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.16262128358466346, 'one_hot_max_size': 5}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-16 23:53:16,065] Trial 482 finished with value: 0.7755267580592725 and parameters: {'iterations': 15372, 'learning_rate': 0.2892147035979909, 'reg_lambda': 16.286433799748366, 'random_strength': 90.63025226787022, 'min_data_in_leaf': 36, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.18814339695278487, 'one_hot_max_size': 4}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-16 23:53:46,694] Trial 483 finished with value: 0.7793260352508253 and parameters: {'iterations': 41447, 'learning_rate': 0.31543149516845753, 'reg_lambda': 16.079533690971974, 'random_strength': 93.98057984105307, 'min_data_in_leaf': 39, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.215704924265498, 'one_hot_max_size': 5}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-16 23:54:15,947] Trial 484 finished with value: 0.7759069922875844 and parameters: {'iterations': 18485, 'learning_rate': 0.35050793084720094, 'reg_lambda': 17.34615195407127, 'random_strength': 95.77270130734266, 'min_data_in_leaf': 38, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.3284816405868943, 'one_hot_max_size': 6}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-16 23:54:49,534] Trial 485 finished with value: 0.7736307006568618 and parameters: {'iterations': 24621, 'learning_rate': 0.2276496896225486, 'reg_lambda': 36.324398108793766, 'random_strength': 92.02610434212016, 'min_data_in_leaf': 44, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.1455618173522914, 'one_hot_max_size': 5}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-16 23:55:19,728] Trial 486 finished with value: 0.7781866123527419 and parameters: {'iterations': 17309, 'learning_rate': 0.3269294354293125, 'reg_lambda': 14.819276592764894, 'random_strength': 99.92265888638724, 'min_data_in_leaf': 39, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.17160150889297668, 'one_hot_max_size': 6}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-16 23:55:49,776] Trial 487 finished with value: 0.7737840828145587 and parameters: {'iterations': 19695, 'learning_rate': 0.2965262968827632, 'reg_lambda': 28.95326433813639, 'random_strength': 97.39682634199455, 'min_data_in_leaf': 46, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.1941853747315579, 'one_hot_max_size': 7}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-16 23:56:17,156] Trial 488 finished with value: 0.7747334619105848 and parameters: {'iterations': 36192, 'learning_rate': 0.3697107531379864, 'reg_lambda': 11.419285823192382, 'random_strength': 95.01674470669188, 'min_data_in_leaf': 47, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.1624770787144016, 'one_hot_max_size': 5}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-16 23:56:53,247] Trial 489 finished with value: 0.7841127507029898 and parameters: {'iterations': 38737, 'learning_rate': 0.2615510083954259, 'reg_lambda': 18.42801086713552, 'random_strength': 96.3391412789184, 'min_data_in_leaf': 38, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.22511140613175057, 'one_hot_max_size': 5}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-16 23:57:25,520] Trial 490 finished with value: 0.7727958791289656 and parameters: {'iterations': 38165, 'learning_rate': 0.24602858718741344, 'reg_lambda': 32.49628426009591, 'random_strength': 96.55741898062588, 'min_data_in_leaf': 37, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.2265894317274778, 'one_hot_max_size': 5}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-16 23:57:57,571] Trial 491 finished with value: 0.7773556833791443 and parameters: {'iterations': 38903, 'learning_rate': 0.2630348903521555, 'reg_lambda': 18.551245345600307, 'random_strength': 98.43377175684058, 'min_data_in_leaf': 16, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.26669447574296695, 'one_hot_max_size': 5}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-16 23:58:29,740] Trial 492 finished with value: 0.7757020794913385 and parameters: {'iterations': 38497, 'learning_rate': 0.2703619868090987, 'reg_lambda': 26.879462792033618, 'random_strength': 96.57481878077354, 'min_data_in_leaf': 36, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.22477039288076908, 'one_hot_max_size': 5}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-16 23:59:04,502] Trial 493 finished with value: 0.7811524007535706 and parameters: {'iterations': 39739, 'learning_rate': 0.2506640525885854, 'reg_lambda': 15.137312337878543, 'random_strength': 95.71956353037515, 'min_data_in_leaf': 38, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.2469504274952935, 'one_hot_max_size': 4}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-16 23:59:34,982] Trial 494 finished with value: 0.7780593557625971 and parameters: {'iterations': 40198, 'learning_rate': 0.34387620777581823, 'reg_lambda': 23.660038875912214, 'random_strength': 53.48526995613702, 'min_data_in_leaf': 39, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.2031701727744663, 'one_hot_max_size': 5}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-17 00:00:08,726] Trial 495 finished with value: 0.7788720449448914 and parameters: {'iterations': 40859, 'learning_rate': 0.27392739499679125, 'reg_lambda': 34.949512188408924, 'random_strength': 94.26367640981334, 'min_data_in_leaf': 37, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.210476229463664, 'one_hot_max_size': 5}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-17 00:00:35,802] Trial 496 finished with value: 0.7759266954923596 and parameters: {'iterations': 18066, 'learning_rate': 0.380857442900298, 'reg_lambda': 19.87762418354932, 'random_strength': 97.70588110596056, 'min_data_in_leaf': 38, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.2359784596738248, 'one_hot_max_size': 5}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-17 00:01:06,726] Trial 497 finished with value: 0.7798903241213998 and parameters: {'iterations': 38601, 'learning_rate': 0.35318111225975585, 'reg_lambda': 31.022615559495264, 'random_strength': 94.89972182041728, 'min_data_in_leaf': 38, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.1972165843597877, 'one_hot_max_size': 5}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-17 00:01:41,106] Trial 498 finished with value: 0.7718676673465905 and parameters: {'iterations': 37691, 'learning_rate': 0.20210273355767586, 'reg_lambda': 20.79418579335448, 'random_strength': 98.98086175442974, 'min_data_in_leaf': 35, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.22334672001309264, 'one_hot_max_size': 5}. Best is trial 348 with value: 0.7883235810800945.
# [I 2024-02-17 00:02:16,299] Trial 499 finished with value: 0.7814891446809394 and parameters: {'iterations': 39783, 'learning_rate': 0.23276098877319995, 'reg_lambda': 17.678134481349524, 'random_strength': 97.05562743596654, 'min_data_in_leaf': 40, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.17985352304093574, 'one_hot_max_size': 5}. Best is trial 348 with value: 0.7883235810800945.
# [W 2024-02-17 00:02:23,083] Trial 500 failed with parameters: {'iterations': 16429, 'learning_rate': 0.29390269898007204, 'reg_lambda': 12.79645201018592, 'random_strength': 99.94391605080659, 'min_data_in_leaf': 34, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.2803701771314536, 'one_hot_max_size': 5} because of the following error: KeyboardInterrupt('').
# Traceback (most recent call last):
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_2849306/681563270.py", line 26, in objective
#     clf.fit(train_pool, eval_set=val_pool)
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/catboost/core.py", line 5100, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/catboost/core.py", line 2319, in _fit
#     self._train(
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/catboost/core.py", line 1723, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4645, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4694, in _catboost._CatBoost._train
# KeyboardInterrupt
# [W 2024-02-17 00:02:23,084] Trial 500 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 36
#      34 # Hyperparameter Tuning
#      35 study = optuna.create_study(direction='maximize', sampler=TPESampler(seed=seed), pruner=SuccessiveHalvingPruner())
# ---> 36 study.optimize(objective, n_trials=None)
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[7], line 26, in objective(trial)
#      14 for train_pool, val_pool, y_true in zip(all_train_pool, all_val_pool, all_y_val):
#      15     clf = CatBoostClassifier(**params,
#      16                              scale_pos_weight=rate,
#      17                              loss_function='Logloss',
#    (...)
#      24
#      25                             )
# ---> 26     clf.fit(train_pool, eval_set=val_pool)
#      28     y_pred = clf.predict(val_pool)
#      29     y_pred = [False if i=='False' else True for i in y_pred]
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/catboost/core.py:5100, in CatBoostClassifier.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5097 if 'loss_function' in params:
#    5098     CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
# -> 5100 self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    5101           eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period,
#    5102           silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5103 return self
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/catboost/core.py:2319, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2315 allow_clear_pool = train_params["allow_clear_pool"]
#    2317 with log_fixup(log_cout, log_cerr), \
#    2318     plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2319     self._train(
#    2320         train_pool,
#    2321         train_params["eval_sets"],
#    2322         params,
#    2323         allow_clear_pool,
#    2324         train_params["init_model"]
#    2325     )
#    2327 # Have property feature_importance possibly set
#    2328 loss = self._object._get_loss_function_name()
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/catboost/core.py:1723, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1722 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1723     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1724     self._set_trained_model_attributes()
#
# File _catboost.pyx:4645, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4694, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
best_param = study.best_params
best_param
# Out:
# {'iterations': 15350,
#  'learning_rate': 0.3409005979799443,
#  'reg_lambda': 19.507665859119093,
#  'random_strength': 98.49018453709503,
#  'min_data_in_leaf': 41,
#  'leaf_estimation_iterations': 13,
#  'bagging_temperature': 0.22209159086426983,
#  'one_hot_max_size': 4}

# %%
best_models = []
for train_pool, val_pool in zip(all_train_pool, all_val_pool):
    best_model = CatBoostClassifier(**best_param,
                                 random_state=seed,
                                 scale_pos_weight=rate, 
                                 loss_function='Logloss',
                                 eval_metric='F1',
                                 task_type="GPU",
                                 devices='0',
                                verbose=False,
                                   early_stopping_rounds=100)
    
    best_model.fit(train_pool, eval_set=val_pool)
    best_models.append(best_model)

# %%
def get_clf_eval(y_test, y_pred=None):
    confusion = confusion_matrix(y_test, y_pred, labels=[True, False])
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, labels=[True, False])
    recall = recall_score(y_test, y_pred)
    F1 = f1_score(y_test, y_pred, labels=[True, False])

    print("오차행렬:\n", confusion)
    print("\n정확도: {:.4f}".format(accuracy))
    print("정밀도: {:.4f}".format(precision))
    print("재현율: {:.4f}".format(recall))
    print("F1: {:.4f}".format(F1))

# %%
train_pred = [best_model.predict_proba(df_train.drop("is_converted",axis=1)) for best_model in best_models]
y = list(df_train['is_converted'])
train_pred = np.mean(train_pred[:],axis=0)
threshold = min([num[1] if y[i] else 1 for i, num in enumerate(train_pred)])
train_y_pred = [True if i[1]>=0.5 else False for i in train_pred]
get_clf_eval(y, train_y_pred)
# Out:
# 오차행렬:
#  [[ 4612     8]
#  [  604 50556]]
#
# 정확도: 0.9890
# 정밀도: 0.8842
# 재현율: 0.9983
# F1: 0.9378

# %%
categorical_features =  [
                        "customer_country",
                        "business_subarea",
                        "business_area",
                        "business_unit",
                        "customer_type",
                        "enterprise",
                        "customer_job",
                        "inquiry_type",
                        "product_category",
                        "product_subcategory",
                        "product_modelname",
                        "customer_position",
                        "response_corporate",
                        "expected_timeline",
                        'customer_idx',
                        'lead_owner',
                        'lead_owner',
                    ]
# 
# 예측에 필요한 데이터 분리
x_test = df_test.drop(["is_converted", "id"], axis=1)
test_pool = Pool(data=x_test, cat_features=categorical_features)

# %%
# 예측 수행 (soft voting)
a_pred = [best_model.predict_proba(test_pool) for best_model in best_models]
pred = np.mean(a_pred[:], axis=0)
#pred = [True if i[1]>=threshold else False for i in pred]
pred = np.argmax(pred, axis=1)
sum(pred)
# Out:
# 1669

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["is_converted"] = pred

# 제출 파일 저장
df_sub.to_csv("submission-onehot.csv", index=False)

# %%
real = pd.read_csv(r'submission(0.767).csv')
get_clf_eval(real['is_converted'], pred)
# Out:
# 오차행렬:
#  [[1635  137]
#  [  34 3465]]
#
# 정확도: 0.9676
# 정밀도: 0.9796
# 재현율: 0.9227
# F1: 0.9503
