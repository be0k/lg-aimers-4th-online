# %%
# !pip3 install lightgbm scikit-learn tqdm catboost optuna xgboost ipywidgets imblearn
# 모델을 위해 필요한 라이브러리 설치(우수 예시에만 있는 부분)
# Out:
# Requirement already satisfied: lightgbm in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (4.1.0)
# Requirement already satisfied: scikit-learn in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (1.4.0)
# Requirement already satisfied: tqdm in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (4.65.0)
# Requirement already satisfied: catboost in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: optuna in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (3.5.0)
# Requirement already satisfied: xgboost in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: ipywidgets in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (8.0.4)
# Requirement already satisfied: imblearn in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (0.0)
# Requirement already satisfied: numpy in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from lightgbm) (1.26.0)
# Requirement already satisfied: scipy in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from lightgbm) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: graphviz in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (3.7.2)
# Requirement already satisfied: pandas>=0.24 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (2.0.3)
# Requirement already satisfied: plotly in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (5.18.0)
# Requirement already satisfied: six in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: alembic>=1.5.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (1.13.1)
# Requirement already satisfied: colorlog in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (6.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (2.0.25)
# Requirement already satisfied: PyYAML in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (6.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (6.25.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: imbalanced-learn in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from imblearn) (0.12.0)
# Requirement already satisfied: Mako in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (1.3.2)
# Requirement already satisfied: typing-extensions>=4 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (4.9.0)
# Requirement already satisfied: comm>=0.1.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: psutil in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.3)
# Requirement already satisfied: backcall in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pickleshare in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: greenlet!=0.4.17 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from plotly->catboost) (8.2.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: entrypoints in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# Requirement already satisfied: executing in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# WARNING: There was an error checking the latest version of pip.

# %%
k_fold_num = 5
seed=42

# %%
import pandas as pd
import sklearn
import numpy as np
from lightgbm import LGBMClassifier
import random
import os
from imblearn.over_sampling import SMOTE
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
import optuna
from optuna.samplers import TPESampler
from optuna.pruners import SuccessiveHalvingPruner
import warnings
warnings.filterwarnings('ignore')

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(seed) # Seed 고정

# %%
df_train = pd.read_csv("train.csv") # 학습용 데이터
df_test = pd.read_csv("submission.csv") # 테스트 데이터(제출파일의 데이터)

# %%
def label_encoding(series: pd.Series) -> pd.Series:
    """범주형 데이터를 시리즈 형태로 받아 숫자형 데이터로 변환합니다."""
    
    my_dict = {}

    # 모든 요소를 문자열로 변환
    series = series.astype(str)

    for idx, value in enumerate(sorted(series.unique())):
        my_dict[value] = idx
    series = series.map(my_dict)

    return series

def category_all(df_train, df_test):
    label_columns = [
    "customer_country",
    "business_subarea",
    "business_area",
    "business_unit",
    "customer_type",
    "enterprise",
    "customer_job",
    "inquiry_type",
    "product_category",
    "product_subcategory",
    "product_modelname",
    "customer_position",
    "response_corporate",
    "expected_timeline",
    ]
    for i in label_columns:
        df_train[i] = df_train[i].astype('category')
        df_test[i] = df_test[i].astype('category')
    return df_train, df_test    
        
def manage_label_encoding(df_train, df_test):
    tmp = len(df_train)
    label_columns = [
    "customer_country",
    "business_subarea",
    "business_area",
    "business_unit",
    "customer_type",
    "enterprise",
    "customer_job",
    "inquiry_type",
    "product_category",
    "product_subcategory",
    "product_modelname",
    "customer_position",
    "response_corporate",
    "expected_timeline",
    ]
    
    df_all = pd.concat([df_train[label_columns], df_test[label_columns]])

    for col in label_columns:
        df_all[col] = label_encoding(df_all[col])
    
    for col in label_columns:  
        df_train[col] = df_all.iloc[: tmp][col]
        df_test[col] = df_all.iloc[tmp :][col]

    return df_train, df_test

def preprocessing(df_train, df_test):
    df_train.drop_duplicates(keep='first', inplace=True)
    df_train.reset_index(inplace=True)
    df_train.drop('index',inplace=True, axis=1)
    df_test_id_temp = df_test['id'].copy()
    df_all = pd.concat([df_train,df_test.drop('id',axis=1)])
    df_all.drop('customer_country.1',axis=1,inplace=True)
    df_all.id_strategic_ver.fillna(0., inplace=True)
    df_all.it_strategic_ver.fillna(0., inplace=True)
    df_all.idit_strategic_ver.fillna(0., inplace=True)
    df_all.business_subarea.fillna('NAN', inplace=True)
    df_all.com_reg_ver_win_rate.fillna(0,inplace=True)
    df_all['customer_type'] = df_all['customer_type'].replace({
        'End-Customer':'End Customer'
    })
    df_all.customer_type.fillna('NAN',inplace=True)
    df_all.historical_existing_cnt.fillna(0, inplace=True)
    
    df_all.product_subcategory.fillna('NAN', inplace=True)
    
    df_all.product_modelname.fillna('NAN', inplace=True)

    df_all['expected_timeline'] = df_all['expected_timeline'].replace({
        'less_than_3_months': 'less than 3 months',  # merge into 'less than 3 months'
        'being followed up': 'being followed up.',  # merge into 'being followed up.'
        'less than 6 months': '3 months ~ 6 months',  # merge into '3 months ~ 6 months'
        '3_months_~_6_months' : '3 months ~ 6 months'
    })
    df_train['expected_timeline'] = df_train['expected_timeline'].replace({
        'less_than_3_months': 'less than 3 months',  # merge into 'less than 3 months'
        'being followed up': 'being followed up.',  # merge into 'being followed up.'
        'less than 6 months': '3 months ~ 6 months',  # merge into '3 months ~ 6 months'
        '3_months_~_6_months' : '3 months ~ 6 months'
    })
    
    top_expected_timelines = df_train['expected_timeline'].value_counts().nlargest(6).index
    df_all['expected_timeline'] = df_all['expected_timeline'].apply(lambda x: x if x in top_expected_timelines else 'Others')
    
    df_all.ver_win_rate_x.fillna(0,inplace=True)
    df_all.ver_win_ratio_per_bu.fillna(0,inplace=True)
    df_all.business_area.fillna('NAN',inplace=True)
    df_all.customer_job.fillna('NAN', inplace=True)
    df_all.product_category.fillna('NAN', inplace=True)
    
    #처리못한부분
    #customer_country
    df_all.customer_country.fillna('NAN', inplace=True)
    #inquiry_type
    df_all.inquiry_type.fillna('NAN', inplace=True)

    tmp_len = len(df_train)
    df_train = df_all.iloc[: tmp_len ]
    df_test = df_all.iloc[tmp_len :]
    df_test = pd.concat([df_test,df_test_id_temp],axis=1)
    return df_train, df_test
df_train, df_test = preprocessing(df_train, df_test)
df_train, df_test = category_all(df_train,df_test)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55780 entries, 0 to 55779
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   bant_submit              55780 non-null  float64
#  1   customer_country         55780 non-null  category
#  2   business_unit            55780 non-null  category
#  3   com_reg_ver_win_rate     55780 non-null  float64
#  4   customer_idx             55780 non-null  int64
#  5   customer_type            55780 non-null  category
#  6   enterprise               55780 non-null  category
#  7   historical_existing_cnt  55780 non-null  float64
#  8   id_strategic_ver         55780 non-null  float64
#  9   it_strategic_ver         55780 non-null  float64
#  10  idit_strategic_ver       55780 non-null  float64
#  11  customer_job             55780 non-null  category
#  12  lead_desc_length         55780 non-null  int64
#  13  inquiry_type             55780 non-null  category
#  14  product_category         55780 non-null  category
#  15  product_subcategory      55780 non-null  category
#  16  product_modelname        55780 non-null  category
#  17  customer_position        55780 non-null  category
#  18  response_corporate       55780 non-null  category
#  19  expected_timeline        55780 non-null  category
#  20  ver_cus                  55780 non-null  int64
#  21  ver_pro                  55780 non-null  int64
#  22  ver_win_rate_x           55780 non-null  float64
#  23  ver_win_ratio_per_bu     55780 non-null  float64
#  24  business_area            55780 non-null  category
#  25  business_subarea         55780 non-null  category
#  26  lead_owner               55780 non-null  int64
#  27  is_converted             55780 non-null  bool
# dtypes: bool(1), category(14), float64(8), int64(5)
# memory usage: 7.7 MB

# %%
rate = ((len(df_train)-sum(df_train['is_converted']))/sum(df_train['is_converted']))
def custom_split(df_train, num=5, idx=0, smote=False, false_rate=1):
    global rate

    #shuffle
    true_df_train = sklearn.utils.shuffle(df_train[df_train["is_converted"]==True], random_state=seed)
    false_df_train = sklearn.utils.shuffle(df_train[df_train["is_converted"]==False], random_state=seed)
    
    #k-fold num
    slice_num = len(true_df_train) // num
    
    #True:False = 1:1
    tmp_train = pd.concat([true_df_train[0:slice_num*idx],
                           true_df_train[slice_num*(idx+1):],
                           false_df_train[0:int((slice_num*false_rate)*idx)],
                           false_df_train[int((slice_num*false_rate)*(idx+1)):]])
    tmp_val = pd.concat([true_df_train[slice_num*idx:slice_num*(idx+1)],
                         false_df_train[int((slice_num*false_rate)*idx):int((slice_num*false_rate)*(idx+1))]])
    #shuffle
    tmp_train = sklearn.utils.shuffle(tmp_train, random_state=seed)
    tmp_val = sklearn.utils.shuffle(tmp_val, random_state=seed)

    #split x and y
    x_train, y_train = tmp_train.drop("is_converted",axis=1), tmp_train["is_converted"]
    x_val, y_val = tmp_val.drop("is_converted",axis=1), tmp_val["is_converted"]
    
    if(smote):
        sm = SMOTE(random_state=seed)
        x_train, y_train = sm.fit_resample(x_train, y_train)
    
    return x_train, y_train, x_val, y_val


all_x_trains = []
all_y_trains = []
all_x_vals = []
all_y_vals = []
for idx in range(k_fold_num):
    bundle = custom_split(df_train, num=k_fold_num, idx=idx, smote=False, false_rate=rate)
    all_x_trains.append(bundle[0])
    all_y_trains.append(bundle[1])
    all_x_vals.append(bundle[2])
    all_y_vals.append(bundle[3])

# %%
# params = {
#         'num_leaves': trial.suggest_int('num_leaves', 20,40), 
#         'max_depth': -1,
#         'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1), 
#         'n_estimators': trial.suggest_int('n_estimators', 50,200), 
#         'scale_pos_weight':rate,
#         'min_child_samples': trial.suggest_int('min_child_samples', 5, 80), 
#         'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
#         'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
#         'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
#         'objective':'binary',
#         'random_state': seed,
#         'type':'gpu',
#         'verbose':-1,
#         'n_jobs':-1,
#     }

def objective(trial):
    params = {
        'num_leaves': trial.suggest_int('num_leaves', 20,40), 
        'max_depth': -1,
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1), 
        'n_estimators': trial.suggest_int('n_estimators', 50,200), 
        'scale_pos_weight':rate,
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 80), 
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
        'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
        'objective':'binary',
        'random_state': seed,
        'type':'gpu',
        'verbose':-1,
        'n_jobs':-1,
    }
    
    score = []
    for all_x_train, all_y_train, all_x_val, all_y_val in zip(all_x_trains, all_y_trains, all_x_vals, all_y_vals):
        clf = LGBMClassifier(**params)
        clf.fit(all_x_train, all_y_train, feature_name='auto', categorical_feature = 'auto', )
        
        y_pred = clf.predict(all_x_val)
        y_true = all_y_val
        score.append((f1_score(y_true,y_pred,labels=[True,False]) + recall_score(y_true,y_pred))/2)
    score = np.mean(score)
    return score

# Hyperparameter Tuning
study = optuna.create_study(direction='maximize', sampler=TPESampler(seed=seed), pruner=SuccessiveHalvingPruner())
study.optimize(objective, n_trials=None)
# Out:
# [I 2024-02-07 23:32:42,797] A new study created in memory with name: no-name-ac6a6e86-c283-4b5a-9700-517c75cceb93
# [I 2024-02-07 23:32:44,426] Trial 0 finished with value: 0.8174005731833329 and parameters: {'num_leaves': 27, 'learning_rate': 0.0951207163345817, 'n_estimators': 160, 'min_child_samples': 50, 'colsample_bytree': 0.7468055921327309, 'reg_alpha': 0.15599452033620265, 'reg_lambda': 0.5808361216819946}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:32:46,382] Trial 1 finished with value: 0.811614082020571 and parameters: {'num_leaves': 38, 'learning_rate': 0.06051038616257767, 'n_estimators': 156, 'min_child_samples': 6, 'colsample_bytree': 0.9909729556485982, 'reg_alpha': 0.8324426408004217, 'reg_lambda': 2.1233911067827616}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:32:47,308] Trial 2 finished with value: 0.7748214999039584 and parameters: {'num_leaves': 23, 'learning_rate': 0.01915704647548995, 'n_estimators': 95, 'min_child_samples': 44, 'colsample_bytree': 0.8295835055926347, 'reg_alpha': 0.2912291401980419, 'reg_lambda': 6.118528947223795}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:32:48,278] Trial 3 finished with value: 0.7857669386649457 and parameters: {'num_leaves': 22, 'learning_rate': 0.0299223202049866, 'n_estimators': 105, 'min_child_samples': 39, 'colsample_bytree': 0.935552788417904, 'reg_alpha': 0.19967378215835974, 'reg_lambda': 5.142344384136116}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:32:49,950] Trial 4 finished with value: 0.6287211029110031 and parameters: {'num_leaves': 32, 'learning_rate': 0.005598590859279775, 'n_estimators': 141, 'min_child_samples': 17, 'colsample_bytree': 0.7195154778955838, 'reg_alpha': 0.9488855372533332, 'reg_lambda': 9.656320330745594}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:32:50,746] Trial 5 finished with value: 0.7870504483636293 and parameters: {'num_leaves': 36, 'learning_rate': 0.0311567631481637, 'n_estimators': 64, 'min_child_samples': 57, 'colsample_bytree': 0.8320457481218804, 'reg_alpha': 0.12203823484477883, 'reg_lambda': 4.951769101112702}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:32:51,562] Trial 6 finished with value: 0.8050106192089315 and parameters: {'num_leaves': 20, 'learning_rate': 0.09102271980579943, 'n_estimators': 89, 'min_child_samples': 55, 'colsample_bytree': 0.7935133228268233, 'reg_alpha': 0.5200680211778108, 'reg_lambda': 5.4671027934327965}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:32:53,099] Trial 7 finished with value: 0.8137188400187636 and parameters: {'num_leaves': 23, 'learning_rate': 0.0969888781486913, 'n_estimators': 167, 'min_child_samples': 76, 'colsample_bytree': 0.9684482051282947, 'reg_alpha': 0.5978999788110851, 'reg_lambda': 9.218742350231167}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:32:53,884] Trial 8 finished with value: 0.7403828781541144 and parameters: {'num_leaves': 21, 'learning_rate': 0.020402303379495376, 'n_estimators': 56, 'min_child_samples': 29, 'colsample_bytree': 0.8166031869068446, 'reg_alpha': 0.2713490317738959, 'reg_lambda': 8.287375091519294}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:32:55,297] Trial 9 finished with value: 0.7947330363718195 and parameters: {'num_leaves': 27, 'learning_rate': 0.028812516459050697, 'n_estimators': 131, 'min_child_samples': 15, 'colsample_bytree': 0.9406590942262119, 'reg_alpha': 0.07455064367977082, 'reg_lambda': 9.868869366005173}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:32:57,410] Trial 10 finished with value: 0.8154724227882484 and parameters: {'num_leaves': 29, 'learning_rate': 0.07090723154361725, 'n_estimators': 196, 'min_child_samples': 75, 'colsample_bytree': 0.7046103211984313, 'reg_alpha': 0.39804334222017657, 'reg_lambda': 0.1514423710275684}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:32:59,345] Trial 11 finished with value: 0.8168261372199723 and parameters: {'num_leaves': 29, 'learning_rate': 0.07290121015738923, 'n_estimators': 200, 'min_child_samples': 80, 'colsample_bytree': 0.7027683007133353, 'reg_alpha': 0.414991151713642, 'reg_lambda': 0.2856361724295679}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:01,367] Trial 12 finished with value: 0.8165272226705456 and parameters: {'num_leaves': 32, 'learning_rate': 0.07882140231542965, 'n_estimators': 200, 'min_child_samples': 63, 'colsample_bytree': 0.7606484557499934, 'reg_alpha': 0.645856440703241, 'reg_lambda': 0.6345304183914828}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:03,096] Trial 13 finished with value: 0.815864298692213 and parameters: {'num_leaves': 26, 'learning_rate': 0.08188782181176912, 'n_estimators': 173, 'min_child_samples': 80, 'colsample_bytree': 0.7489286126032791, 'reg_alpha': 0.018378117209663064, 'reg_lambda': 2.2713901165087846}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:05,412] Trial 14 finished with value: 0.8156831513907703 and parameters: {'num_leaves': 33, 'learning_rate': 0.051982070988073364, 'n_estimators': 181, 'min_child_samples': 65, 'colsample_bytree': 0.8857503632212278, 'reg_alpha': 0.3987297359297599, 'reg_lambda': 2.2339055734690056}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:06,936] Trial 15 finished with value: 0.8129906887125715 and parameters: {'num_leaves': 26, 'learning_rate': 0.06619612481331791, 'n_estimators': 147, 'min_child_samples': 47, 'colsample_bytree': 0.7631288284416022, 'reg_alpha': 0.3925477554058151, 'reg_lambda': 3.2002310840039963}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:08,768] Trial 16 finished with value: 0.8146595361169371 and parameters: {'num_leaves': 29, 'learning_rate': 0.08480917940034528, 'n_estimators': 184, 'min_child_samples': 33, 'colsample_bytree': 0.8768795505537277, 'reg_alpha': 0.23005845605986203, 'reg_lambda': 1.2355956853922276}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:10,226] Trial 17 finished with value: 0.8144482671957569 and parameters: {'num_leaves': 35, 'learning_rate': 0.09839724231640323, 'n_estimators': 120, 'min_child_samples': 68, 'colsample_bytree': 0.7318186695139761, 'reg_alpha': 0.7287174865812844, 'reg_lambda': 3.8944864548172147}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:11,812] Trial 18 finished with value: 0.8112267855171853 and parameters: {'num_leaves': 25, 'learning_rate': 0.04680024201587044, 'n_estimators': 163, 'min_child_samples': 52, 'colsample_bytree': 0.7001426982123469, 'reg_alpha': 0.4810815799796586, 'reg_lambda': 1.421151712985348}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:13,712] Trial 19 finished with value: 0.8149291559148951 and parameters: {'num_leaves': 29, 'learning_rate': 0.0760820184971802, 'n_estimators': 188, 'min_child_samples': 29, 'colsample_bytree': 0.7891088847919064, 'reg_alpha': 0.1741534877861226, 'reg_lambda': 7.2406001862713465}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:15,284] Trial 20 finished with value: 0.8167090151259956 and parameters: {'num_leaves': 40, 'learning_rate': 0.05936420753947611, 'n_estimators': 122, 'min_child_samples': 69, 'colsample_bytree': 0.7859468665619898, 'reg_alpha': 0.00036902387821721727, 'reg_lambda': 0.06581039145219303}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:16,821] Trial 21 finished with value: 0.8161234782779486 and parameters: {'num_leaves': 40, 'learning_rate': 0.060658954088416255, 'n_estimators': 119, 'min_child_samples': 71, 'colsample_bytree': 0.7820205971305, 'reg_alpha': 0.012255917793516868, 'reg_lambda': 0.2069947113894492}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:18,498] Trial 22 finished with value: 0.8132669069247423 and parameters: {'num_leaves': 31, 'learning_rate': 0.047646462827787506, 'n_estimators': 139, 'min_child_samples': 62, 'colsample_bytree': 0.7361029188014241, 'reg_alpha': 0.11455008475538071, 'reg_lambda': 1.099818946098962}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:20,603] Trial 23 finished with value: 0.8156926417650661 and parameters: {'num_leaves': 34, 'learning_rate': 0.08983954790675995, 'n_estimators': 152, 'min_child_samples': 80, 'colsample_bytree': 0.7720235478621211, 'reg_alpha': 0.32319077934642837, 'reg_lambda': 3.153235668875576}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:21,784] Trial 24 finished with value: 0.810259348078349 and parameters: {'num_leaves': 28, 'learning_rate': 0.05622901200725067, 'n_estimators': 104, 'min_child_samples': 71, 'colsample_bytree': 0.7273220767955038, 'reg_alpha': 0.0020509222467936516, 'reg_lambda': 0.11659823073936887}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:24,301] Trial 25 finished with value: 0.8166371228558174 and parameters: {'num_leaves': 37, 'learning_rate': 0.07274744072977374, 'n_estimators': 131, 'min_child_samples': 59, 'colsample_bytree': 0.8581773546522253, 'reg_alpha': 0.15014749200811028, 'reg_lambda': 1.573326838679155}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:25,779] Trial 26 finished with value: 0.8035625589160815 and parameters: {'num_leaves': 40, 'learning_rate': 0.04343249771409155, 'n_estimators': 75, 'min_child_samples': 50, 'colsample_bytree': 0.808193357238401, 'reg_alpha': 0.08443281400212588, 'reg_lambda': 0.873108634087082}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:27,989] Trial 27 finished with value: 0.8143904060152822 and parameters: {'num_leaves': 24, 'learning_rate': 0.08885880480412933, 'n_estimators': 174, 'min_child_samples': 37, 'colsample_bytree': 0.7462049127237005, 'reg_alpha': 0.4990093806463503, 'reg_lambda': 3.0968684317988426}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:29,279] Trial 28 finished with value: 0.8141521108823386 and parameters: {'num_leaves': 30, 'learning_rate': 0.06516308246929198, 'n_estimators': 113, 'min_child_samples': 73, 'colsample_bytree': 0.7194316614133558, 'reg_alpha': 0.3426948214982645, 'reg_lambda': 2.063106607343313}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:31,475] Trial 29 finished with value: 0.8139790925096921 and parameters: {'num_leaves': 38, 'learning_rate': 0.06075803494966612, 'n_estimators': 153, 'min_child_samples': 67, 'colsample_bytree': 0.8006918651058518, 'reg_alpha': 0.7997784052270356, 'reg_lambda': 4.336725589600288}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:33,139] Trial 30 finished with value: 0.8112431934325901 and parameters: {'num_leaves': 27, 'learning_rate': 0.04083760638064448, 'n_estimators': 161, 'min_child_samples': 80, 'colsample_bytree': 0.7519631747101472, 'reg_alpha': 0.19835410458571184, 'reg_lambda': 1.9898638565856765}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:34,957] Trial 31 finished with value: 0.8104511506139461 and parameters: {'num_leaves': 38, 'learning_rate': 0.07336898578630752, 'n_estimators': 131, 'min_child_samples': 60, 'colsample_bytree': 0.8637023508801525, 'reg_alpha': 0.15317916456629455, 'reg_lambda': 1.5877246661937099}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:36,885] Trial 32 finished with value: 0.8124963473757221 and parameters: {'num_leaves': 37, 'learning_rate': 0.069624625131917, 'n_estimators': 131, 'min_child_samples': 55, 'colsample_bytree': 0.8458918011889524, 'reg_alpha': 0.2552752165176052, 'reg_lambda': 0.5935557705952796}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:38,117] Trial 33 finished with value: 0.808103553120721 and parameters: {'num_leaves': 39, 'learning_rate': 0.05409973264165144, 'n_estimators': 92, 'min_child_samples': 42, 'colsample_bytree': 0.843037326296878, 'reg_alpha': 0.05849540712198785, 'reg_lambda': 0.0671881213370755}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:39,798] Trial 34 finished with value: 0.8093975501934223 and parameters: {'num_leaves': 37, 'learning_rate': 0.0817821776525614, 'n_estimators': 107, 'min_child_samples': 60, 'colsample_bytree': 0.9052520515365914, 'reg_alpha': 0.18413311108390218, 'reg_lambda': 2.6606327710630513}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:41,528] Trial 35 finished with value: 0.8144943939047209 and parameters: {'num_leaves': 35, 'learning_rate': 0.06515457875386141, 'n_estimators': 141, 'min_child_samples': 49, 'colsample_bytree': 0.8222585017244117, 'reg_alpha': 0.1285230053940494, 'reg_lambda': 0.8571463714425294}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:42,856] Trial 36 finished with value: 0.8107474605487214 and parameters: {'num_leaves': 39, 'learning_rate': 0.09491881354015783, 'n_estimators': 84, 'min_child_samples': 44, 'colsample_bytree': 0.9099257495975805, 'reg_alpha': 0.31228588078615943, 'reg_lambda': 1.512173337274935}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:45,131] Trial 37 finished with value: 0.8162742261810256 and parameters: {'num_leaves': 31, 'learning_rate': 0.07665860617502726, 'n_estimators': 191, 'min_child_samples': 57, 'colsample_bytree': 0.7175621618213772, 'reg_alpha': 0.9982835861660031, 'reg_lambda': 0.6449374272032539}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:46,336] Trial 38 finished with value: 0.0 and parameters: {'num_leaves': 36, 'learning_rate': 0.005620284124309684, 'n_estimators': 100, 'min_child_samples': 69, 'colsample_bytree': 0.7750576419046095, 'reg_alpha': 0.0708757601724389, 'reg_lambda': 6.005818949249972}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:47,819] Trial 39 finished with value: 0.8119552707517623 and parameters: {'num_leaves': 24, 'learning_rate': 0.08654820324482332, 'n_estimators': 125, 'min_child_samples': 74, 'colsample_bytree': 0.8643436197114994, 'reg_alpha': 0.5747273466798646, 'reg_lambda': 3.8726814764056643}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:49,417] Trial 40 finished with value: 0.8102957866090839 and parameters: {'num_leaves': 33, 'learning_rate': 0.03801217286337854, 'n_estimators': 144, 'min_child_samples': 65, 'colsample_bytree': 0.8261907638600396, 'reg_alpha': 0.4449400827384624, 'reg_lambda': 1.6646753436394568}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:51,641] Trial 41 finished with value: 0.8135665824943559 and parameters: {'num_leaves': 31, 'learning_rate': 0.092677166105832, 'n_estimators': 199, 'min_child_samples': 63, 'colsample_bytree': 0.7641484029830807, 'reg_alpha': 0.6425472140271882, 'reg_lambda': 0.5550310563297457}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:53,637] Trial 42 finished with value: 0.8163153972482025 and parameters: {'num_leaves': 28, 'learning_rate': 0.07756495199094607, 'n_estimators': 180, 'min_child_samples': 53, 'colsample_bytree': 0.7098937492620133, 'reg_alpha': 0.695886805437763, 'reg_lambda': 0.5632950930123504}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:55,941] Trial 43 finished with value: 0.8161443027238764 and parameters: {'num_leaves': 32, 'learning_rate': 0.08054265200324813, 'n_estimators': 191, 'min_child_samples': 77, 'colsample_bytree': 0.7411425746766377, 'reg_alpha': 0.841918865680588, 'reg_lambda': 1.092289673971134}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:57,850] Trial 44 finished with value: 0.8083253267371573 and parameters: {'num_leaves': 30, 'learning_rate': 0.07040207520329732, 'n_estimators': 173, 'min_child_samples': 64, 'colsample_bytree': 0.9995922797677858, 'reg_alpha': 0.5516371769161765, 'reg_lambda': 0.014813122640183751}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:33:59,868] Trial 45 finished with value: 0.8157654400327518 and parameters: {'num_leaves': 27, 'learning_rate': 0.055898750036213266, 'n_estimators': 199, 'min_child_samples': 58, 'colsample_bytree': 0.7645921832014828, 'reg_alpha': 0.6453399810432293, 'reg_lambda': 2.5225421735041693}. Best is trial 0 with value: 0.8174005731833329.
# [I 2024-02-07 23:34:01,333] Trial 46 finished with value: 0.817493543789908 and parameters: {'num_leaves': 22, 'learning_rate': 0.08440003266324114, 'n_estimators': 165, 'min_child_samples': 8, 'colsample_bytree': 0.8046003998408751, 'reg_alpha': 0.22488166664164522, 'reg_lambda': 1.622588173900867}. Best is trial 46 with value: 0.817493543789908.
# [I 2024-02-07 23:34:02,760] Trial 47 finished with value: 0.8138002869105495 and parameters: {'num_leaves': 22, 'learning_rate': 0.09975144644171624, 'n_estimators': 158, 'min_child_samples': 6, 'colsample_bytree': 0.8096310110161492, 'reg_alpha': 0.24062824856887163, 'reg_lambda': 7.4232813634123325}. Best is trial 46 with value: 0.817493543789908.
# [I 2024-02-07 23:34:03,961] Trial 48 finished with value: 0.8086106268004869 and parameters: {'num_leaves': 21, 'learning_rate': 0.08378547843462288, 'n_estimators': 136, 'min_child_samples': 22, 'colsample_bytree': 0.8355123560345178, 'reg_alpha': 0.27924942234950884, 'reg_lambda': 1.775959033882839}. Best is trial 46 with value: 0.817493543789908.
# [I 2024-02-07 23:34:05,403] Trial 49 finished with value: 0.8145132985289203 and parameters: {'num_leaves': 23, 'learning_rate': 0.07319028540874534, 'n_estimators': 150, 'min_child_samples': 5, 'colsample_bytree': 0.7945192330776911, 'reg_alpha': 0.12819592256350065, 'reg_lambda': 2.5918921916045576}. Best is trial 46 with value: 0.817493543789908.
# [I 2024-02-07 23:34:06,397] Trial 50 finished with value: 0.8072943393783675 and parameters: {'num_leaves': 20, 'learning_rate': 0.09357115991036367, 'n_estimators': 124, 'min_child_samples': 10, 'colsample_bytree': 0.8550673392224775, 'reg_alpha': 0.04101888208503002, 'reg_lambda': 1.1879452185966493}. Best is trial 46 with value: 0.817493543789908.
# [I 2024-02-07 23:34:08,039] Trial 51 finished with value: 0.8139568860582418 and parameters: {'num_leaves': 26, 'learning_rate': 0.07886724055881963, 'n_estimators': 171, 'min_child_samples': 77, 'colsample_bytree': 0.7521512046648257, 'reg_alpha': 0.3660703477432684, 'reg_lambda': 0.4643282110308743}. Best is trial 46 with value: 0.817493543789908.
# [I 2024-02-07 23:34:09,974] Trial 52 finished with value: 0.8167455413633746 and parameters: {'num_leaves': 33, 'learning_rate': 0.08780930796824674, 'n_estimators': 180, 'min_child_samples': 22, 'colsample_bytree': 0.7906270742545329, 'reg_alpha': 0.426760162492809, 'reg_lambda': 0.9639470862943771}. Best is trial 46 with value: 0.817493543789908.
# [I 2024-02-07 23:34:11,822] Trial 53 finished with value: 0.8170512098734897 and parameters: {'num_leaves': 34, 'learning_rate': 0.0872063246038942, 'n_estimators': 166, 'min_child_samples': 21, 'colsample_bytree': 0.7910477071113834, 'reg_alpha': 0.4416292682054925, 'reg_lambda': 1.03421061797222}. Best is trial 46 with value: 0.817493543789908.
# [I 2024-02-07 23:34:13,586] Trial 54 finished with value: 0.8156978803585572 and parameters: {'num_leaves': 33, 'learning_rate': 0.0875772800827061, 'n_estimators': 165, 'min_child_samples': 20, 'colsample_bytree': 0.7796359101681326, 'reg_alpha': 0.4642437754846091, 'reg_lambda': 0.993604955751382}. Best is trial 46 with value: 0.817493543789908.
# [I 2024-02-07 23:34:15,531] Trial 55 finished with value: 0.8180463748451141 and parameters: {'num_leaves': 34, 'learning_rate': 0.09043297226208458, 'n_estimators': 178, 'min_child_samples': 26, 'colsample_bytree': 0.7936568571464078, 'reg_alpha': 0.43118346768611954, 'reg_lambda': 0.37927552381146223}. Best is trial 55 with value: 0.8180463748451141.
# [I 2024-02-07 23:34:17,421] Trial 56 finished with value: 0.8166810205007966 and parameters: {'num_leaves': 34, 'learning_rate': 0.09600073090523509, 'n_estimators': 179, 'min_child_samples': 26, 'colsample_bytree': 0.809852795517734, 'reg_alpha': 0.43097944913251646, 'reg_lambda': 1.251536285521703}. Best is trial 55 with value: 0.8180463748451141.
# [I 2024-02-07 23:34:19,352] Trial 57 finished with value: 0.8160330172214001 and parameters: {'num_leaves': 34, 'learning_rate': 0.09149983663164869, 'n_estimators': 186, 'min_child_samples': 14, 'colsample_bytree': 0.7940665063969109, 'reg_alpha': 0.5270875806361568, 'reg_lambda': 0.3133083128619028}. Best is trial 55 with value: 0.8180463748451141.
# [I 2024-02-07 23:34:21,326] Trial 58 finished with value: 0.8184238583686726 and parameters: {'num_leaves': 35, 'learning_rate': 0.08479592011024407, 'n_estimators': 169, 'min_child_samples': 25, 'colsample_bytree': 0.7318474486319954, 'reg_alpha': 0.41420556448685947, 'reg_lambda': 1.9577083676697236}. Best is trial 58 with value: 0.8184238583686726.
# [I 2024-02-07 23:34:23,243] Trial 59 finished with value: 0.8167865474309084 and parameters: {'num_leaves': 35, 'learning_rate': 0.08390333214046508, 'n_estimators': 168, 'min_child_samples': 32, 'colsample_bytree': 0.7291277856212571, 'reg_alpha': 0.39431424080647415, 'reg_lambda': 1.9408533707022924}. Best is trial 58 with value: 0.8184238583686726.
# [I 2024-02-07 23:34:24,970] Trial 60 finished with value: 0.8167260164556872 and parameters: {'num_leaves': 32, 'learning_rate': 0.09736712092688289, 'n_estimators': 158, 'min_child_samples': 13, 'colsample_bytree': 0.7133505002229142, 'reg_alpha': 0.33600069206765676, 'reg_lambda': 2.3088649991887977}. Best is trial 58 with value: 0.8184238583686726.
# [I 2024-02-07 23:34:26,843] Trial 61 finished with value: 0.8168501385340482 and parameters: {'num_leaves': 35, 'learning_rate': 0.08538609780649944, 'n_estimators': 168, 'min_child_samples': 33, 'colsample_bytree': 0.7267452754104825, 'reg_alpha': 0.3844451846773937, 'reg_lambda': 2.9275852036787406}. Best is trial 58 with value: 0.8184238583686726.
# [I 2024-02-07 23:34:28,789] Trial 62 finished with value: 0.8198483720840374 and parameters: {'num_leaves': 35, 'learning_rate': 0.09138058403008813, 'n_estimators': 176, 'min_child_samples': 27, 'colsample_bytree': 0.7024971440414, 'reg_alpha': 0.3746544317836566, 'reg_lambda': 2.974374552636853}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:34:30,687] Trial 63 finished with value: 0.8178116388206453 and parameters: {'num_leaves': 36, 'learning_rate': 0.09058188822549955, 'n_estimators': 176, 'min_child_samples': 36, 'colsample_bytree': 0.7215946649522562, 'reg_alpha': 0.35824243663058103, 'reg_lambda': 3.5739485098566695}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:34:32,717] Trial 64 finished with value: 0.8158158975695551 and parameters: {'num_leaves': 36, 'learning_rate': 0.0903365084160113, 'n_estimators': 177, 'min_child_samples': 27, 'colsample_bytree': 0.700921682650644, 'reg_alpha': 0.2893044214069086, 'reg_lambda': 3.9726972528727713}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:34:34,654] Trial 65 finished with value: 0.817658918519742 and parameters: {'num_leaves': 36, 'learning_rate': 0.09963196275398403, 'n_estimators': 163, 'min_child_samples': 37, 'colsample_bytree': 0.7367715753902923, 'reg_alpha': 0.36382751923559575, 'reg_lambda': 3.5350278622296942}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:34:36,524] Trial 66 finished with value: 0.817585007821729 and parameters: {'num_leaves': 36, 'learning_rate': 0.09511434831010301, 'n_estimators': 160, 'min_child_samples': 38, 'colsample_bytree': 0.743265849585363, 'reg_alpha': 0.3609769556415569, 'reg_lambda': 3.506188106364944}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:34:38,652] Trial 67 finished with value: 0.815649847063769 and parameters: {'num_leaves': 37, 'learning_rate': 0.09982737970964357, 'n_estimators': 192, 'min_child_samples': 35, 'colsample_bytree': 0.7384338202884831, 'reg_alpha': 0.3621721718886574, 'reg_lambda': 5.0291280112409895}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:34:40,489] Trial 68 finished with value: 0.8169135166842014 and parameters: {'num_leaves': 36, 'learning_rate': 0.09403638978262865, 'n_estimators': 155, 'min_child_samples': 40, 'colsample_bytree': 0.7568658969408307, 'reg_alpha': 0.3137667890185869, 'reg_lambda': 3.5250939066218887}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:34:42,555] Trial 69 finished with value: 0.8174257806747487 and parameters: {'num_leaves': 36, 'learning_rate': 0.09634148354033192, 'n_estimators': 176, 'min_child_samples': 25, 'colsample_bytree': 0.7224062851394896, 'reg_alpha': 0.4746984194117494, 'reg_lambda': 4.654420585319363}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:34:44,721] Trial 70 finished with value: 0.8179449863603893 and parameters: {'num_leaves': 38, 'learning_rate': 0.09135683541023334, 'n_estimators': 184, 'min_child_samples': 29, 'colsample_bytree': 0.7449320890788333, 'reg_alpha': 0.22018483329749533, 'reg_lambda': 3.634463672683851}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:34:46,819] Trial 71 finished with value: 0.8175133750211139 and parameters: {'num_leaves': 38, 'learning_rate': 0.09080660744250252, 'n_estimators': 183, 'min_child_samples': 29, 'colsample_bytree': 0.7395214766865522, 'reg_alpha': 0.34935860739756264, 'reg_lambda': 3.4826985974940934}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:34:49,142] Trial 72 finished with value: 0.8175540028245036 and parameters: {'num_leaves': 39, 'learning_rate': 0.09128370825608169, 'n_estimators': 186, 'min_child_samples': 30, 'colsample_bytree': 0.7442525734321122, 'reg_alpha': 0.3692045534294375, 'reg_lambda': 3.4710825540850223}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:34:51,135] Trial 73 finished with value: 0.8157919835257399 and parameters: {'num_leaves': 37, 'learning_rate': 0.09728133075080796, 'n_estimators': 172, 'min_child_samples': 37, 'colsample_bytree': 0.7069452067559144, 'reg_alpha': 0.49470018428818774, 'reg_lambda': 4.344132523886825}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:34:53,437] Trial 74 finished with value: 0.819018087435493 and parameters: {'num_leaves': 39, 'learning_rate': 0.09301078873395566, 'n_estimators': 184, 'min_child_samples': 31, 'colsample_bytree': 0.7444820272338676, 'reg_alpha': 0.3791662097869414, 'reg_lambda': 3.4890013909362234}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:34:55,805] Trial 75 finished with value: 0.8163973587939781 and parameters: {'num_leaves': 38, 'learning_rate': 0.09357437972822648, 'n_estimators': 194, 'min_child_samples': 36, 'colsample_bytree': 0.7340556184855496, 'reg_alpha': 0.41404288830141533, 'reg_lambda': 4.166468585797908}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:34:57,790] Trial 76 finished with value: 0.8138764768111975 and parameters: {'num_leaves': 35, 'learning_rate': 0.08150241129994423, 'n_estimators': 183, 'min_child_samples': 39, 'colsample_bytree': 0.7692477135768638, 'reg_alpha': 0.3040805793544814, 'reg_lambda': 5.477530989714634}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:34:59,728] Trial 77 finished with value: 0.8194383147787943 and parameters: {'num_leaves': 39, 'learning_rate': 0.09995675397085473, 'n_estimators': 161, 'min_child_samples': 31, 'colsample_bytree': 0.7157798138814471, 'reg_alpha': 0.2693556150323577, 'reg_lambda': 2.7658437390089183}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:01,847] Trial 78 finished with value: 0.8179572765888018 and parameters: {'num_leaves': 39, 'learning_rate': 0.09845011560611579, 'n_estimators': 188, 'min_child_samples': 18, 'colsample_bytree': 0.7133196302163172, 'reg_alpha': 0.2684666570823268, 'reg_lambda': 2.9664775063449103}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:03,963] Trial 79 finished with value: 0.8166147666563749 and parameters: {'num_leaves': 39, 'learning_rate': 0.09025704395906398, 'n_estimators': 189, 'min_child_samples': 23, 'colsample_bytree': 0.7134594732485888, 'reg_alpha': 0.258316493615689, 'reg_lambda': 2.867811779044708}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:06,099] Trial 80 finished with value: 0.8093206839947982 and parameters: {'num_leaves': 40, 'learning_rate': 0.02230883305753812, 'n_estimators': 176, 'min_child_samples': 18, 'colsample_bytree': 0.7215432391886737, 'reg_alpha': 0.21990412212073734, 'reg_lambda': 3.2512004743127534}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:08,118] Trial 81 finished with value: 0.8149678068491484 and parameters: {'num_leaves': 38, 'learning_rate': 0.09925531757510672, 'n_estimators': 170, 'min_child_samples': 31, 'colsample_bytree': 0.7070364847786488, 'reg_alpha': 0.28855108508131994, 'reg_lambda': 3.7600510356685413}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:10,415] Trial 82 finished with value: 0.8164445887333821 and parameters: {'num_leaves': 39, 'learning_rate': 0.09316609611636122, 'n_estimators': 195, 'min_child_samples': 34, 'colsample_bytree': 0.7299325411078921, 'reg_alpha': 0.33383280187741343, 'reg_lambda': 2.7603475978329888}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:12,506] Trial 83 finished with value: 0.8184068666077206 and parameters: {'num_leaves': 37, 'learning_rate': 0.0972614936117565, 'n_estimators': 187, 'min_child_samples': 27, 'colsample_bytree': 0.752522616319002, 'reg_alpha': 0.40767814540083536, 'reg_lambda': 2.3430488189089873}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:14,623] Trial 84 finished with value: 0.8160875005912098 and parameters: {'num_leaves': 38, 'learning_rate': 0.09638606790156368, 'n_estimators': 188, 'min_child_samples': 24, 'colsample_bytree': 0.7545299359326515, 'reg_alpha': 0.45640446818605823, 'reg_lambda': 2.351343915826354}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:16,880] Trial 85 finished with value: 0.8139657330772405 and parameters: {'num_leaves': 40, 'learning_rate': 0.08824349059494413, 'n_estimators': 184, 'min_child_samples': 27, 'colsample_bytree': 0.9667351973343224, 'reg_alpha': 0.5284030986321733, 'reg_lambda': 3.248462185718473}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:19,281] Trial 86 finished with value: 0.8175923475577391 and parameters: {'num_leaves': 37, 'learning_rate': 0.08897133114437109, 'n_estimators': 179, 'min_child_samples': 18, 'colsample_bytree': 0.7185474449331394, 'reg_alpha': 0.4084689223554672, 'reg_lambda': 3.0078419975686925}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:20,157] Trial 87 finished with value: 0.8106580156674393 and parameters: {'num_leaves': 39, 'learning_rate': 0.09718412189274486, 'n_estimators': 50, 'min_child_samples': 28, 'colsample_bytree': 0.7246217371773217, 'reg_alpha': 0.19953277271650852, 'reg_lambda': 4.473619138647985}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:22,610] Trial 88 finished with value: 0.8184915497440933 and parameters: {'num_leaves': 38, 'learning_rate': 0.09265549475036002, 'n_estimators': 174, 'min_child_samples': 31, 'colsample_bytree': 0.7491574072359464, 'reg_alpha': 0.26784064686087516, 'reg_lambda': 2.5180182699346916}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:25,200] Trial 89 finished with value: 0.8159540264235137 and parameters: {'num_leaves': 38, 'learning_rate': 0.09409862345476822, 'n_estimators': 195, 'min_child_samples': 25, 'colsample_bytree': 0.7493730219856558, 'reg_alpha': 0.26435236702149484, 'reg_lambda': 2.543568594143695}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:27,921] Trial 90 finished with value: 0.8178787084713285 and parameters: {'num_leaves': 40, 'learning_rate': 0.08306946823620968, 'n_estimators': 188, 'min_child_samples': 16, 'colsample_bytree': 0.7694089285499358, 'reg_alpha': 0.16521195658621357, 'reg_lambda': 2.0746749942552585}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:30,211] Trial 91 finished with value: 0.8173791869866921 and parameters: {'num_leaves': 40, 'learning_rate': 0.08547699633665182, 'n_estimators': 182, 'min_child_samples': 16, 'colsample_bytree': 0.7590278331453973, 'reg_alpha': 0.18508856572593907, 'reg_lambda': 2.1025563746701357}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:32,233] Trial 92 finished with value: 0.8170339621880556 and parameters: {'num_leaves': 39, 'learning_rate': 0.07967427084017759, 'n_estimators': 188, 'min_child_samples': 20, 'colsample_bytree': 0.7704081771241771, 'reg_alpha': 0.2372503599617627, 'reg_lambda': 1.8945424615953639}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:34,448] Trial 93 finished with value: 0.8151084594705248 and parameters: {'num_leaves': 40, 'learning_rate': 0.09196925233395593, 'n_estimators': 173, 'min_child_samples': 31, 'colsample_bytree': 0.7812391274916914, 'reg_alpha': 0.16082757661169278, 'reg_lambda': 2.2168234485372817}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:37,463] Trial 94 finished with value: 0.81634266437453 and parameters: {'num_leaves': 37, 'learning_rate': 0.08636858978336416, 'n_estimators': 198, 'min_child_samples': 28, 'colsample_bytree': 0.7649167829360023, 'reg_alpha': 0.313004477244842, 'reg_lambda': 2.5161556737121424}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:39,988] Trial 95 finished with value: 0.8176768413836368 and parameters: {'num_leaves': 38, 'learning_rate': 0.09522088138870208, 'n_estimators': 190, 'min_child_samples': 19, 'colsample_bytree': 0.7461592988675835, 'reg_alpha': 0.3872318573109201, 'reg_lambda': 2.8292042100477848}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:41,955] Trial 96 finished with value: 0.8158432857742113 and parameters: {'num_leaves': 39, 'learning_rate': 0.08362908025854403, 'n_estimators': 184, 'min_child_samples': 24, 'colsample_bytree': 0.7119457828653948, 'reg_alpha': 0.10360275086763902, 'reg_lambda': 3.053033310037748}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:43,765] Trial 97 finished with value: 0.8146539330304815 and parameters: {'num_leaves': 40, 'learning_rate': 0.0891076314175422, 'n_estimators': 169, 'min_child_samples': 12, 'colsample_bytree': 0.7357342768250354, 'reg_alpha': 0.2711942118982726, 'reg_lambda': 1.4301678167376717}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:45,661] Trial 98 finished with value: 0.8160811838022084 and parameters: {'num_leaves': 37, 'learning_rate': 0.09787268134716232, 'n_estimators': 179, 'min_child_samples': 16, 'colsample_bytree': 0.7006283683644082, 'reg_alpha': 0.2086818109138438, 'reg_lambda': 8.959002957967927}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:47,582] Trial 99 finished with value: 0.0 and parameters: {'num_leaves': 39, 'learning_rate': 0.003084109695941903, 'n_estimators': 192, 'min_child_samples': 30, 'colsample_bytree': 0.773754796481989, 'reg_alpha': 0.24317140587901448, 'reg_lambda': 2.360544519809895}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:49,417] Trial 100 finished with value: 0.8169028388235567 and parameters: {'num_leaves': 37, 'learning_rate': 0.09237926425183916, 'n_estimators': 185, 'min_child_samples': 32, 'colsample_bytree': 0.751432724364093, 'reg_alpha': 0.14932289534309237, 'reg_lambda': 3.1955349361769594}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:51,132] Trial 101 finished with value: 0.8179823062236045 and parameters: {'num_leaves': 35, 'learning_rate': 0.0829072691511862, 'n_estimators': 176, 'min_child_samples': 34, 'colsample_bytree': 0.7166078520661978, 'reg_alpha': 0.3319088486059795, 'reg_lambda': 3.7257225574666153}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:53,129] Trial 102 finished with value: 0.8178619499611358 and parameters: {'num_leaves': 35, 'learning_rate': 0.08295503552059884, 'n_estimators': 175, 'min_child_samples': 26, 'colsample_bytree': 0.7131896160957927, 'reg_alpha': 0.33256803015496417, 'reg_lambda': 4.0169040712200195}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:54,933] Trial 103 finished with value: 0.8186503681252899 and parameters: {'num_leaves': 34, 'learning_rate': 0.07534138589435173, 'n_estimators': 181, 'min_child_samples': 34, 'colsample_bytree': 0.7305165166711185, 'reg_alpha': 0.38688695113273924, 'reg_lambda': 3.7476945427913937}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:56,691] Trial 104 finished with value: 0.8176700382907984 and parameters: {'num_leaves': 34, 'learning_rate': 0.07684009700181761, 'n_estimators': 181, 'min_child_samples': 34, 'colsample_bytree': 0.7324918737765503, 'reg_alpha': 0.4308466702116445, 'reg_lambda': 4.628119693626901}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:58,276] Trial 105 finished with value: 0.8167984970885558 and parameters: {'num_leaves': 33, 'learning_rate': 0.08636237268742489, 'n_estimators': 163, 'min_child_samples': 45, 'colsample_bytree': 0.7164161667192124, 'reg_alpha': 0.3032771546711949, 'reg_lambda': 2.7392993933721894}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:35:59,937] Trial 106 finished with value: 0.8147607539411155 and parameters: {'num_leaves': 35, 'learning_rate': 0.09517570751902567, 'n_estimators': 171, 'min_child_samples': 29, 'colsample_bytree': 0.7067823707174736, 'reg_alpha': 0.3784000420578908, 'reg_lambda': 3.78616776694562}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:01,700] Trial 107 finished with value: 0.8192579245715143 and parameters: {'num_leaves': 34, 'learning_rate': 0.09832770125789518, 'n_estimators': 178, 'min_child_samples': 33, 'colsample_bytree': 0.7264861599233551, 'reg_alpha': 0.4051710850307283, 'reg_lambda': 3.6902450404690397}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:03,399] Trial 108 finished with value: 0.8152687282070812 and parameters: {'num_leaves': 34, 'learning_rate': 0.09848207704774023, 'n_estimators': 178, 'min_child_samples': 42, 'colsample_bytree': 0.7265539155291573, 'reg_alpha': 0.405346657751629, 'reg_lambda': 3.377765045278173}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:05,015] Trial 109 finished with value: 0.8148526405165726 and parameters: {'num_leaves': 32, 'learning_rate': 0.09768322000116837, 'n_estimators': 174, 'min_child_samples': 40, 'colsample_bytree': 0.7299120498789458, 'reg_alpha': 0.46999076705070225, 'reg_lambda': 4.087799667507394}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:06,619] Trial 110 finished with value: 0.8164536694171176 and parameters: {'num_leaves': 33, 'learning_rate': 0.06793452269298736, 'n_estimators': 166, 'min_child_samples': 33, 'colsample_bytree': 0.7069837374027599, 'reg_alpha': 0.4379396304361327, 'reg_lambda': 5.407460417075463}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:08,350] Trial 111 finished with value: 0.8174876078065502 and parameters: {'num_leaves': 34, 'learning_rate': 0.08897554995857662, 'n_estimators': 181, 'min_child_samples': 27, 'colsample_bytree': 0.7408464192554588, 'reg_alpha': 0.3384832059932597, 'reg_lambda': 3.742335284730487}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:10,160] Trial 112 finished with value: 0.8145479425368037 and parameters: {'num_leaves': 35, 'learning_rate': 0.09237378146560812, 'n_estimators': 186, 'min_child_samples': 31, 'colsample_bytree': 0.7199312454277426, 'reg_alpha': 0.2905365785846427, 'reg_lambda': 3.2963537206497002}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:11,899] Trial 113 finished with value: 0.8161317892866217 and parameters: {'num_leaves': 36, 'learning_rate': 0.09508680564193661, 'n_estimators': 177, 'min_child_samples': 22, 'colsample_bytree': 0.7467975633707903, 'reg_alpha': 0.4946479843274442, 'reg_lambda': 3.6782313244731095}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:13,619] Trial 114 finished with value: 0.8150923997393335 and parameters: {'num_leaves': 38, 'learning_rate': 0.0998530135588295, 'n_estimators': 170, 'min_child_samples': 35, 'colsample_bytree': 0.7590125204814604, 'reg_alpha': 0.4145114693486686, 'reg_lambda': 3.0114079654069603}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:14,458] Trial 115 finished with value: 0.8127110324905367 and parameters: {'num_leaves': 33, 'learning_rate': 0.09275112752449445, 'n_estimators': 71, 'min_child_samples': 29, 'colsample_bytree': 0.724807917307031, 'reg_alpha': 0.388893926842786, 'reg_lambda': 2.6109513087319463}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:16,282] Trial 116 finished with value: 0.8173152512084896 and parameters: {'num_leaves': 34, 'learning_rate': 0.0810733588714362, 'n_estimators': 193, 'min_child_samples': 26, 'colsample_bytree': 0.7366044904382051, 'reg_alpha': 0.3219100263233333, 'reg_lambda': 3.1048613413382484}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:17,873] Trial 117 finished with value: 0.8178439750638876 and parameters: {'num_leaves': 35, 'learning_rate': 0.09072310290273464, 'n_estimators': 161, 'min_child_samples': 33, 'colsample_bytree': 0.7114802473102184, 'reg_alpha': 0.453758524154142, 'reg_lambda': 4.244711256485166}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:19,675] Trial 118 finished with value: 0.815881620103681 and parameters: {'num_leaves': 36, 'learning_rate': 0.08715287182399858, 'n_estimators': 174, 'min_child_samples': 24, 'colsample_bytree': 0.7325631118168475, 'reg_alpha': 0.5140574746258211, 'reg_lambda': 3.935464012903326}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:21,776] Trial 119 finished with value: 0.8174389166811655 and parameters: {'num_leaves': 38, 'learning_rate': 0.07526880847202597, 'n_estimators': 182, 'min_child_samples': 30, 'colsample_bytree': 0.7175149426715572, 'reg_alpha': 0.3547636545637351, 'reg_lambda': 1.742715332748829}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:23,509] Trial 120 finished with value: 0.8184340789500792 and parameters: {'num_leaves': 31, 'learning_rate': 0.09578646025770517, 'n_estimators': 197, 'min_child_samples': 32, 'colsample_bytree': 0.7020580792081009, 'reg_alpha': 0.42206937324678195, 'reg_lambda': 2.85473390493158}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:25,223] Trial 121 finished with value: 0.8168602624409133 and parameters: {'num_leaves': 31, 'learning_rate': 0.09596014775171674, 'n_estimators': 191, 'min_child_samples': 32, 'colsample_bytree': 0.7074879640699778, 'reg_alpha': 0.3979964425935091, 'reg_lambda': 2.4861435730369}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:27,099] Trial 122 finished with value: 0.817852780052014 and parameters: {'num_leaves': 35, 'learning_rate': 0.09397742654072228, 'n_estimators': 196, 'min_child_samples': 35, 'colsample_bytree': 0.7022695591166087, 'reg_alpha': 0.42135110257548813, 'reg_lambda': 2.8419189807796554}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:29,096] Trial 123 finished with value: 0.8154269004145155 and parameters: {'num_leaves': 39, 'learning_rate': 0.09839114391942, 'n_estimators': 197, 'min_child_samples': 28, 'colsample_bytree': 0.7240309130567507, 'reg_alpha': 0.37949669728562224, 'reg_lambda': 3.31318247230622}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:30,864] Trial 124 finished with value: 0.8178689381081673 and parameters: {'num_leaves': 34, 'learning_rate': 0.08966705799079044, 'n_estimators': 186, 'min_child_samples': 30, 'colsample_bytree': 0.7419224783734787, 'reg_alpha': 0.25771933693912463, 'reg_lambda': 2.7271310518756158}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:32,574] Trial 125 finished with value: 0.8163694375211226 and parameters: {'num_leaves': 33, 'learning_rate': 0.09602054681079839, 'n_estimators': 178, 'min_child_samples': 34, 'colsample_bytree': 0.7303741569437024, 'reg_alpha': 0.4494942439727159, 'reg_lambda': 3.635551637768049}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:34,177] Trial 126 finished with value: 0.8176787615050743 and parameters: {'num_leaves': 30, 'learning_rate': 0.09262092079250663, 'n_estimators': 181, 'min_child_samples': 27, 'colsample_bytree': 0.7174269105833064, 'reg_alpha': 0.34603405146623045, 'reg_lambda': 2.957499736383788}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:35,632] Trial 127 finished with value: 0.8158843641999832 and parameters: {'num_leaves': 28, 'learning_rate': 0.09751573862837881, 'n_estimators': 168, 'min_child_samples': 25, 'colsample_bytree': 0.7000359859186648, 'reg_alpha': 0.4809846906036436, 'reg_lambda': 2.330545438903356}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:37,584] Trial 128 finished with value: 0.8134119728139835 and parameters: {'num_leaves': 38, 'learning_rate': 0.03356079561614886, 'n_estimators': 187, 'min_child_samples': 38, 'colsample_bytree': 0.7533154307438933, 'reg_alpha': 0.28884802042807395, 'reg_lambda': 1.9016085041755921}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:39,467] Trial 129 finished with value: 0.8137618692949994 and parameters: {'num_leaves': 37, 'learning_rate': 0.08520656929502526, 'n_estimators': 190, 'min_child_samples': 32, 'colsample_bytree': 0.7115738260240737, 'reg_alpha': 0.32609129979265217, 'reg_lambda': 4.848365231558239}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:41,098] Trial 130 finished with value: 0.8151215770423837 and parameters: {'num_leaves': 32, 'learning_rate': 0.0999193672955047, 'n_estimators': 174, 'min_child_samples': 28, 'colsample_bytree': 0.7241842051952954, 'reg_alpha': 0.22668428241245858, 'reg_lambda': 3.181766380114117}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:43,105] Trial 131 finished with value: 0.8160807188769725 and parameters: {'num_leaves': 40, 'learning_rate': 0.08247980845392729, 'n_estimators': 188, 'min_child_samples': 23, 'colsample_bytree': 0.7664436268861584, 'reg_alpha': 0.4063657847717574, 'reg_lambda': 2.1248385672543155}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:45,115] Trial 132 finished with value: 0.817999452060309 and parameters: {'num_leaves': 39, 'learning_rate': 0.07952409365650845, 'n_estimators': 199, 'min_child_samples': 12, 'colsample_bytree': 0.744738802505358, 'reg_alpha': 0.16709755043941604, 'reg_lambda': 2.177500941586929}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:47,134] Trial 133 finished with value: 0.8184843376811812 and parameters: {'num_leaves': 39, 'learning_rate': 0.07819261425370884, 'n_estimators': 199, 'min_child_samples': 31, 'colsample_bytree': 0.7474444311485322, 'reg_alpha': 0.27405243879329383, 'reg_lambda': 2.414164367670071}. Best is trial 62 with value: 0.8198483720840374.
# [I 2024-02-07 23:36:49,116] Trial 134 finished with value: 0.8160183350340529 and parameters: {'num_leaves': 39, 'learning_rate': 0.080200135962216, 'n_estimators': 194, 'min_child_samples': 36, 'colsample_bytree': 0.7401915281708341, 'reg_alpha': 0.30666227678850444, 'reg_lambda': 2.4881389253728434}. Best is trial 62 with value: 0.8198483720840374.
# ...
# [I 2024-02-07 23:38:56,690] Trial 192 finished with value: 0.8194357114968718 and parameters: {'num_leaves': 35, 'learning_rate': 0.0679499192273949, 'n_estimators': 184, 'min_child_samples': 28, 'colsample_bytree': 0.7036505400510636, 'reg_alpha': 0.43890162504458513, 'reg_lambda': 2.6226862437459864}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:38:58,950] Trial 193 finished with value: 0.816577418861602 and parameters: {'num_leaves': 35, 'learning_rate': 0.07345829451075725, 'n_estimators': 191, 'min_child_samples': 31, 'colsample_bytree': 0.7020244631972221, 'reg_alpha': 0.44501081662479325, 'reg_lambda': 2.6492912934199584}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:01,216] Trial 194 finished with value: 0.8195843931894033 and parameters: {'num_leaves': 35, 'learning_rate': 0.06283865525748762, 'n_estimators': 185, 'min_child_samples': 28, 'colsample_bytree': 0.7120422355941046, 'reg_alpha': 0.47600889442881916, 'reg_lambda': 1.821925541226935}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:03,506] Trial 195 finished with value: 0.8188130593790535 and parameters: {'num_leaves': 36, 'learning_rate': 0.06469950784018737, 'n_estimators': 185, 'min_child_samples': 29, 'colsample_bytree': 0.7130712616686187, 'reg_alpha': 0.4969287033578598, 'reg_lambda': 1.9897471895099805}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:05,913] Trial 196 finished with value: 0.8179141669659968 and parameters: {'num_leaves': 36, 'learning_rate': 0.06441661996911985, 'n_estimators': 184, 'min_child_samples': 29, 'colsample_bytree': 0.7002959199440133, 'reg_alpha': 0.5036940757391717, 'reg_lambda': 2.0536599398282416}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:08,247] Trial 197 finished with value: 0.8186017823045549 and parameters: {'num_leaves': 36, 'learning_rate': 0.06177854835127874, 'n_estimators': 186, 'min_child_samples': 28, 'colsample_bytree': 0.7169549975253556, 'reg_alpha': 0.5414287315396317, 'reg_lambda': 2.362105243562265}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:10,378] Trial 198 finished with value: 0.8179457798043984 and parameters: {'num_leaves': 36, 'learning_rate': 0.06558967512062656, 'n_estimators': 180, 'min_child_samples': 27, 'colsample_bytree': 0.7149093519877566, 'reg_alpha': 0.4911850879283865, 'reg_lambda': 2.4750847912881415}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:12,694] Trial 199 finished with value: 0.8186596306642203 and parameters: {'num_leaves': 36, 'learning_rate': 0.05948829601574935, 'n_estimators': 184, 'min_child_samples': 28, 'colsample_bytree': 0.7103590661407352, 'reg_alpha': 0.525580231252491, 'reg_lambda': 2.8231799163867097}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:14,891] Trial 200 finished with value: 0.8183299607216687 and parameters: {'num_leaves': 35, 'learning_rate': 0.06061320462639562, 'n_estimators': 183, 'min_child_samples': 29, 'colsample_bytree': 0.711000026746985, 'reg_alpha': 0.5470127679332865, 'reg_lambda': 2.886021218525026}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:17,393] Trial 201 finished with value: 0.8162946560433365 and parameters: {'num_leaves': 36, 'learning_rate': 0.059245519432663866, 'n_estimators': 186, 'min_child_samples': 27, 'colsample_bytree': 0.7184583372361827, 'reg_alpha': 0.531939316699984, 'reg_lambda': 2.6787139015092154}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:19,823] Trial 202 finished with value: 0.818136028321166 and parameters: {'num_leaves': 36, 'learning_rate': 0.06239197867975794, 'n_estimators': 181, 'min_child_samples': 28, 'colsample_bytree': 0.7104812340610648, 'reg_alpha': 0.5114805513569883, 'reg_lambda': 2.355237744648756}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:21,885] Trial 203 finished with value: 0.8169937835492707 and parameters: {'num_leaves': 35, 'learning_rate': 0.06337046817696952, 'n_estimators': 178, 'min_child_samples': 31, 'colsample_bytree': 0.7059504308539307, 'reg_alpha': 0.4793686610799455, 'reg_lambda': 2.5937667201451067}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:24,024] Trial 204 finished with value: 0.8195625799820494 and parameters: {'num_leaves': 36, 'learning_rate': 0.06615352991868945, 'n_estimators': 184, 'min_child_samples': 26, 'colsample_bytree': 0.7220196212860732, 'reg_alpha': 0.555741930576252, 'reg_lambda': 3.0209739148058685}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:26,176] Trial 205 finished with value: 0.815884959075678 and parameters: {'num_leaves': 35, 'learning_rate': 0.06094014253185107, 'n_estimators': 184, 'min_child_samples': 25, 'colsample_bytree': 0.7209948511150469, 'reg_alpha': 0.5583618894931183, 'reg_lambda': 3.1020684616306173}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:28,029] Trial 206 finished with value: 0.8173210489585507 and parameters: {'num_leaves': 36, 'learning_rate': 0.06491452898132331, 'n_estimators': 150, 'min_child_samples': 29, 'colsample_bytree': 0.7143729254830921, 'reg_alpha': 0.5242861321281701, 'reg_lambda': 3.469684401676413}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:30,186] Trial 207 finished with value: 0.8160961966633747 and parameters: {'num_leaves': 36, 'learning_rate': 0.06971652009172397, 'n_estimators': 176, 'min_child_samples': 26, 'colsample_bytree': 0.7226951986703058, 'reg_alpha': 0.5854445304027108, 'reg_lambda': 2.8471003455674246}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:32,660] Trial 208 finished with value: 0.8180755115379419 and parameters: {'num_leaves': 35, 'learning_rate': 0.0666365778423037, 'n_estimators': 190, 'min_child_samples': 30, 'colsample_bytree': 0.7042588439630229, 'reg_alpha': 0.5367653501041519, 'reg_lambda': 2.9871953620088743}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:35,138] Trial 209 finished with value: 0.8179309252763833 and parameters: {'num_leaves': 34, 'learning_rate': 0.06243269548041347, 'n_estimators': 182, 'min_child_samples': 28, 'colsample_bytree': 0.7132311909594157, 'reg_alpha': 0.5059447149576379, 'reg_lambda': 3.3371331396170523}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:36,961] Trial 210 finished with value: 0.8153565296383855 and parameters: {'num_leaves': 37, 'learning_rate': 0.05793767936698817, 'n_estimators': 128, 'min_child_samples': 32, 'colsample_bytree': 0.7261556661773412, 'reg_alpha': 0.5557543671354531, 'reg_lambda': 2.7578892071112286}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:39,963] Trial 211 finished with value: 0.8171295434412486 and parameters: {'num_leaves': 36, 'learning_rate': 0.06986360931774377, 'n_estimators': 188, 'min_child_samples': 27, 'colsample_bytree': 0.7005680583755157, 'reg_alpha': 0.4751861257382056, 'reg_lambda': 2.45635983243062}. Best is trial 163 with value: 0.8203972011375779.
# [I 2024-02-07 23:39:42,483] Trial 212 finished with value: 0.8125592602152072 and parameters: {'num_leaves': 37, 'learning_rate': 0.06513838833252904, 'n_estimators': 186, 'min_child_samples': 24, 'colsample_bytree': 0.9735576857458822, 'reg_alpha': 0.9289010799915601, 'reg_lambda': 2.255635896856212}. Best is trial 163 with value: 0.8203972011375779.
# [W 2024-02-07 23:39:43,012] Trial 213 failed with parameters: {'num_leaves': 36, 'learning_rate': 0.06001742728135502, 'n_estimators': 138, 'min_child_samples': 30, 'colsample_bytree': 0.7092689269886858, 'reg_alpha': 0.4023557584926646, 'reg_lambda': 1.919012301558215} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_1012107/1099647613.py", line 39, in objective
#     clf.fit(all_x_train, all_y_train, feature_name='auto', categorical_feature = 'auto', )
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/sklearn.py", line 1142, in fit
#     super().fit(
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/sklearn.py", line 842, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/engine.py", line 276, in train
#     booster.update(fobj=fobj)
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/basic.py", line 3658, in update
#     _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# [W 2024-02-07 23:39:43,014] Trial 213 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 49
#      47 # Hyperparameter Tuning
#      48 study = optuna.create_study(direction='maximize', sampler=TPESampler(seed=seed), pruner=SuccessiveHalvingPruner())
# ---> 49 study.optimize(objective, n_trials=None)
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[29], line 39, in objective(trial)
#      37 for all_x_train, all_y_train, all_x_val, all_y_val in zip(all_x_trains, all_y_trains, all_x_vals, all_y_vals):
#      38     clf = LGBMClassifier(**params)
# ---> 39     clf.fit(all_x_train, all_y_train, feature_name='auto', categorical_feature = 'auto', )
#      41     y_pred = clf.predict(all_x_val)
#      42     y_true = all_y_val
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/sklearn.py:1142, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1139         else:
#    1140             valid_sets.append((valid_x, self._le.transform(valid_y)))
# -> 1142 super().fit(
#    1143     X,
#    1144     _y,
#    1145     sample_weight=sample_weight,
#    1146     init_score=init_score,
#    1147     eval_set=valid_sets,
#    1148     eval_names=eval_names,
#    1149     eval_sample_weight=eval_sample_weight,
#    1150     eval_class_weight=eval_class_weight,
#    1151     eval_init_score=eval_init_score,
#    1152     eval_metric=eval_metric,
#    1153     feature_name=feature_name,
#    1154     categorical_feature=categorical_feature,
#    1155     callbacks=callbacks,
#    1156     init_model=init_model
#    1157 )
#    1158 return self
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/sklearn.py:842, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#     839 evals_result: _EvalResultDict = {}
#     840 callbacks.append(record_evaluation(evals_result))
# --> 842 self._Booster = train(
#     843     params=params,
#     844     train_set=train_set,
#     845     num_boost_round=self.n_estimators,
#     846     valid_sets=valid_sets,
#     847     valid_names=eval_names,
#     848     feval=eval_metrics_callable,  # type: ignore[arg-type]
#     849     init_model=init_model,
#     850     feature_name=feature_name,
#     851     callbacks=callbacks
#     852 )
#     854 self._evals_result = evals_result
#     855 self._best_iteration = self._Booster.best_iteration
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/engine.py:276, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     268 for cb in callbacks_before_iter:
#     269     cb(callback.CallbackEnv(model=booster,
#     270                             params=params,
#     271                             iteration=i,
#     272                             begin_iteration=init_iteration,
#     273                             end_iteration=init_iteration + num_boost_round,
#     274                             evaluation_result_list=None))
# --> 276 booster.update(fobj=fobj)
#     278 evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#     279 # check evaluation result.
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/basic.py:3658, in Booster.update(self, train_set, fobj)
#    3656 if self.__set_objective_to_none:
#    3657     raise LightGBMError('Cannot update due to null objective function.')
# -> 3658 _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    3659     self._handle,
#    3660     ctypes.byref(is_finished)))
#    3661 self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    3662 return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
best_param = study.best_params
best_param['verbose'] = -1
best_param['random_state'] = seed
best_param['objective'] = 'binary'
best_param['verbose'] = -1
best_param['scale_pos_weight'] = rate
best_param
# Out:
# {'num_leaves': 38,
#  'learning_rate': 0.09405113587997047,
#  'n_estimators': 191,
#  'min_child_samples': 17,
#  'colsample_bytree': 0.7367765197862572,
#  'reg_alpha': 0.3822819694158223,
#  'reg_lambda': 2.291905899445273,
#  'verbose': -1,
#  'random_state': 42,
#  'objective': 'binary',
#  'scale_pos_weight': 11.073593073593074}

# %%
best_models = []
for all_x_train, all_y_train in zip(all_x_trains, all_y_trains):
    best_model = LGBMClassifier(**best_param)
    best_model.fit(all_x_train, all_y_train, feature_name='auto', categorical_feature = 'auto',)
    best_models.append(best_model)

# %%
def get_clf_eval(y_test, y_pred=None):
    confusion = confusion_matrix(y_test, y_pred, labels=[True, False])
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, labels=[True, False])
    recall = recall_score(y_test, y_pred)
    F1 = f1_score(y_test, y_pred, labels=[True, False])

    print("오차행렬:\n", confusion)
    print("\n정확도: {:.4f}".format(accuracy))
    print("정밀도: {:.4f}".format(precision))
    print("재현율: {:.4f}".format(recall))
    print("F1: {:.4f}".format(F1))

# %%
train_pred = np.mean([best_model.predict_proba(df_train.drop("is_converted",axis=1)) for best_model in best_models], axis=0)
y = df_train['is_converted']
threshold = min([num[1] if y[i] else 1 for i, num in enumerate(train_pred)])
train_y_pred = [True if i[1]>=threshold else False for i in train_pred]
get_clf_eval(df_train['is_converted'], train_y_pred)
# Out:
# 오차행렬:
#  [[ 4620     0]
#  [ 1175 49985]]
#
# 정확도: 0.9789
# 정밀도: 0.7972
# 재현율: 1.0000
# F1: 0.8872

# %%
train_y_pred = [True if i[1]>=0.5 else False for i in train_pred]
get_clf_eval(df_train['is_converted'], train_y_pred)
# Out:
# 오차행렬:
#  [[ 4616     4]
#  [  853 50307]]
#
# 정확도: 0.9846
# 정밀도: 0.8440
# 재현율: 0.9991
# F1: 0.9151

# %%
x_train=df_train.drop("is_converted",axis=1)
y_train = df_train["is_converted"]
f1_sum = 0
for i in range(k_fold_num):
    pred = best_models[i].predict(all_x_vals[i])
    get_clf_eval(all_y_vals[i], pred)
    f1_sum += f1_score(all_y_vals[i], pred, labels=[True, False])
print(f'\n\n{f1_sum/k_fold_num}')
# Out:
# 오차행렬:
#  [[ 801  123]
#  [ 256 9976]]
#
# 정확도: 0.9660
# 정밀도: 0.7578
# 재현율: 0.8669
# F1: 0.8087
# 오차행렬:
#  [[ 752  172]
#  [ 269 9963]]
#
# 정확도: 0.9605
# 정밀도: 0.7365
# 재현율: 0.8139
# F1: 0.7733
# 오차행렬:
#  [[ 792  132]
#  [ 294 9938]]
#
# 정확도: 0.9618
# 정밀도: 0.7293
# 재현율: 0.8571
# F1: 0.7881
# 오차행렬:
#  [[ 800  124]
#  [ 275 9957]]
#
# 정확도: 0.9642
# 정밀도: 0.7442
# 재현율: 0.8658
# F1: 0.8004
# 오차행렬:
#  [[ 785  139]
#  [ 303 9929]]
#
# 정확도: 0.9604
# 정밀도: 0.7215
# 재현율: 0.8496
# F1: 0.7803
#
#
# 0.7901450516258053

# %%
# 예측에 필요한 데이터 분리
x_test = df_test.drop(["is_converted", "id"], axis=1)

# %%
# 예측 수행 (soft voting)
print(format(threshold,'f'))
a_pred = [best_model.predict_proba(x_test) for best_model in best_models]
pred = np.mean(a_pred, axis=0)
pred = [True if i[1]>threshold else False for i in pred]
sum(pred)
# Out:
# 0.396372
# 1310

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["is_converted"] = pred

# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)

# %%
real = pd.read_csv('73per.csv')
get_clf_eval(real['is_converted'], pred)
# Out:
# 오차행렬:
#  [[1256  898]
#  [  54 3063]]
#
# 정확도: 0.8194
# 정밀도: 0.9588
# 재현율: 0.5831
# F1: 0.7252
