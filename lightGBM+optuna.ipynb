# %%
# !pip3 install lightgbm scikit-learn tqdm catboost optuna xgboost ipywidgets imblearn
# 모델을 위해 필요한 라이브러리 설치(우수 예시에만 있는 부분)
# Out:
# Requirement already satisfied: lightgbm in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (4.1.0)
# Requirement already satisfied: scikit-learn in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (1.4.0)
# Requirement already satisfied: tqdm in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (4.65.0)
# Requirement already satisfied: catboost in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: optuna in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (3.5.0)
# Requirement already satisfied: xgboost in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: ipywidgets in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (8.0.4)
# Requirement already satisfied: imblearn in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (0.0)
# Requirement already satisfied: numpy in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from lightgbm) (1.26.0)
# Requirement already satisfied: scipy in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from lightgbm) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: graphviz in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (3.7.2)
# Requirement already satisfied: pandas>=0.24 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (2.0.3)
# Requirement already satisfied: plotly in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (5.18.0)
# Requirement already satisfied: six in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: alembic>=1.5.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (1.13.1)
# Requirement already satisfied: colorlog in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (6.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (2.0.25)
# Requirement already satisfied: PyYAML in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (6.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (6.25.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: imbalanced-learn in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from imblearn) (0.12.0)
# Requirement already satisfied: Mako in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (1.3.2)
# Requirement already satisfied: typing-extensions>=4 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (4.9.0)
# Requirement already satisfied: comm>=0.1.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: psutil in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.3)
# Requirement already satisfied: backcall in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pickleshare in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: greenlet!=0.4.17 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from plotly->catboost) (8.2.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: entrypoints in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# Requirement already satisfied: executing in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# WARNING: There was an error checking the latest version of pip.

# %%
k_fold_num = 5
seed=42

# %%
import pandas as pd
import sklearn
import numpy as np
from lightgbm import LGBMClassifier
import random
import os
from imblearn.over_sampling import SMOTE
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
import optuna
from optuna.samplers import TPESampler
from optuna.pruners import SuccessiveHalvingPruner
import warnings
warnings.filterwarnings('ignore')

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(seed) # Seed 고정

# %%
df_train = pd.read_csv("train.csv") # 학습용 데이터
df_test = pd.read_csv("submission.csv") # 테스트 데이터(제출파일의 데이터)

# %%
def label_encoding(series: pd.Series) -> pd.Series:
    """범주형 데이터를 시리즈 형태로 받아 숫자형 데이터로 변환합니다."""
    
    my_dict = {}

    # 모든 요소를 문자열로 변환
    series = series.astype(str)

    for idx, value in enumerate(sorted(series.unique())):
        my_dict[value] = idx
    series = series.map(my_dict)

    return series

def manage_label_encoding(df_train, df_test):
    tmp = len(df_train)
    label_columns = [
    "customer_country",
    "business_subarea",
    "business_area",
    "business_unit",
    "customer_type",
    "enterprise",
    "customer_job",
    "inquiry_type",
    "product_category",
    "product_subcategory",
    "product_modelname",
    "customer_position",
    "response_corporate",
    "expected_timeline",
    ]
    
    df_all = pd.concat([df_train[label_columns], df_test[label_columns]])

    for col in label_columns:
        df_all[col] = label_encoding(df_all[col])
    
    for col in label_columns:  
        df_train[col] = df_all.iloc[: tmp][col]
        df_test[col] = df_all.iloc[tmp :][col]

    return df_train, df_test


def category_all(df_train, df_test):
    label_columns = [
    "customer_country",
    "business_subarea",
    "business_area",
    "business_unit",
    "customer_type",
    "enterprise",
    "customer_job",
    "inquiry_type",
    "product_category",
    "product_subcategory",
    "product_modelname",
    "customer_position",
    "response_corporate",
    "expected_timeline",
    ]
    for i in label_columns:
        df_train[i] = df_train[i].astype('category')
        df_test[i] = df_test[i].astype('category')
    return df_train, df_test    
        
    
def preprocessing(df_train, df_test):
    df_train.drop_duplicates(keep='first', inplace=True)
    df_train.reset_index(inplace=True)
    df_train.drop('index',inplace=True, axis=1)
    df_test_id_temp = df_test['id'].copy()
    df_all = pd.concat([df_train,df_test.drop('id',axis=1)])
    df_all.drop('customer_country.1',axis=1,inplace=True)
    df_all.id_strategic_ver.fillna(0., inplace=True)
    df_all.it_strategic_ver.fillna(0., inplace=True)
    df_all.idit_strategic_ver.fillna(0., inplace=True)
    df_all.business_subarea.fillna('NAN', inplace=True)
    df_all.com_reg_ver_win_rate.fillna(0,inplace=True)
    df_all['customer_type'] = df_all['customer_type'].replace({
        'End-Customer':'End Customer'
    })
    df_all.customer_type.fillna('NAN',inplace=True)
    df_all.historical_existing_cnt.fillna(0, inplace=True)
    
    df_all.product_subcategory.fillna('NAN', inplace=True)
    
    df_all.product_modelname.fillna('NAN', inplace=True)

    df_all['expected_timeline'] = df_all['expected_timeline'].replace({
        'less_than_3_months': 'less than 3 months',  # merge into 'less than 3 months'
        'being followed up': 'being followed up.',  # merge into 'being followed up.'
        'less than 6 months': '3 months ~ 6 months',  # merge into '3 months ~ 6 months'
        '3_months_~_6_months' : '3 months ~ 6 months'
    })
    df_train['expected_timeline'] = df_train['expected_timeline'].replace({
        'less_than_3_months': 'less than 3 months',  # merge into 'less than 3 months'
        'being followed up': 'being followed up.',  # merge into 'being followed up.'
        'less than 6 months': '3 months ~ 6 months',  # merge into '3 months ~ 6 months'
        '3_months_~_6_months' : '3 months ~ 6 months'
    })
    
    top_expected_timelines = df_train['expected_timeline'].value_counts().nlargest(6).index
    df_all['expected_timeline'] = df_all['expected_timeline'].apply(lambda x: x if x in top_expected_timelines else 'Others')
    
    df_all.ver_win_rate_x.fillna(0,inplace=True)
    df_all.ver_win_ratio_per_bu.fillna(0,inplace=True)
    df_all.business_area.fillna('NAN',inplace=True)
    df_all.customer_job.fillna('NAN', inplace=True)
    df_all.product_category.fillna('NAN', inplace=True)
    
    #처리못한부분
    #customer_country
    df_all.customer_country.fillna('NAN', inplace=True)
    #inquiry_type
    df_all.inquiry_type.fillna('NAN', inplace=True)

    tmp_len = len(df_train)
    df_train = df_all.iloc[: tmp_len ]
    df_test = df_all.iloc[tmp_len :]
    df_test = pd.concat([df_test,df_test_id_temp],axis=1)
    return df_train, df_test
df_train, df_test = preprocessing(df_train, df_test)
df_train, df_test = manage_label_encoding(df_train,df_test)

# %%
rate = ((len(df_train)-sum(df_train['is_converted']))/sum(df_train['is_converted']))
def custom_split(df_train, num=5, idx=0, smote=False, false_rate=1):
    global rate

    #shuffle
    true_df_train = sklearn.utils.shuffle(df_train[df_train["is_converted"]==True], random_state=seed)
    false_df_train = sklearn.utils.shuffle(df_train[df_train["is_converted"]==False], random_state=seed)
    
    #k-fold num
    slice_num = len(true_df_train) // num
    
    #True:False = 1:1
    tmp_train = pd.concat([true_df_train[0:slice_num*idx],
                           true_df_train[slice_num*(idx+1):],
                           false_df_train[0:int((slice_num*false_rate)*idx)],
                           false_df_train[int((slice_num*false_rate)*(idx+1)):]])
    tmp_val = pd.concat([true_df_train[slice_num*idx:slice_num*(idx+1)],
                         false_df_train[int((slice_num*false_rate)*idx):int((slice_num*false_rate)*(idx+1))]])
    #shuffle
    tmp_train = sklearn.utils.shuffle(tmp_train, random_state=seed)
    tmp_val = sklearn.utils.shuffle(tmp_val, random_state=seed)

    #split x and y
    x_train, y_train = tmp_train.drop("is_converted",axis=1).fillna(0), tmp_train["is_converted"]
    x_val, y_val = tmp_val.drop("is_converted",axis=1).fillna(0), tmp_val["is_converted"]
    
    if(smote):
        sm = SMOTE(random_state=seed)
        x_train, y_train = sm.fit_resample(x_train, y_train)
    
    return x_train, y_train, x_val, y_val


all_x_trains = []
all_y_trains = []
all_x_vals = []
all_y_vals = []
for idx in range(k_fold_num):
    bundle = custom_split(df_train, num=k_fold_num, idx=idx, smote=False, false_rate=rate)
    all_x_trains.append(bundle[0])
    all_y_trains.append(bundle[1])
    all_x_vals.append(bundle[2])
    all_y_vals.append(bundle[3])

# %%
# params = {
#         'num_leaves': trial.suggest_int('num_leaves', 20,40), 
#         'max_depth': -1,
#         'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1), 
#         'n_estimators': trial.suggest_int('n_estimators', 50,200), 
#         'scale_pos_weight':rate,
#         'min_child_samples': trial.suggest_int('min_child_samples', 5, 80), 
#         'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
#         'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
#         'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
#         'objective':'binary',
#         'random_state': seed,
#         'type':'gpu',
#         'verbose':-1,
#         'n_jobs':-1,
#     }

def objective(trial):
    params = {
        'num_leaves': trial.suggest_int('num_leaves', 20,40), 
        'max_depth': -1,
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1), 
        'n_estimators': trial.suggest_int('n_estimators', 50,200), 
        'scale_pos_weight':rate,
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 80), 
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
        'reg_alpha': trial.suggest_uniform('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_uniform('reg_lambda', 0.0, 10.0),
        'objective':'binary',
        'random_state': seed,
        'type':'gpu',
        'verbose':-1,
        'n_jobs':-1,
    }
    
    score = []
    for all_x_train, all_y_train, all_x_val, all_y_val in zip(all_x_trains, all_y_trains, all_x_vals, all_y_vals):
        clf = LGBMClassifier(**params)
        clf.fit(all_x_train, all_y_train)
        
        y_pred = clf.predict(all_x_val)
        y_true = all_y_val
        score.append((f1_score(y_true,y_pred,labels=[True,False]) + recall_score(y_true,y_pred))/2)
    score = np.mean(score)
    return score

# Hyperparameter Tuning
study = optuna.create_study(direction='maximize', sampler=TPESampler(seed=seed), pruner=SuccessiveHalvingPruner())
study.optimize(objective, n_trials=None)
# Out:
# [I 2024-02-07 19:32:30,143] A new study created in memory with name: no-name-7606cd3f-edf6-4ed4-979a-13f590276c35
# [I 2024-02-07 19:32:31,362] Trial 0 finished with value: 0.8274774594024914 and parameters: {'num_leaves': 27, 'learning_rate': 0.0951207163345817, 'n_estimators': 160, 'min_child_samples': 50, 'colsample_bytree': 0.7468055921327309, 'reg_alpha': 0.15599452033620265, 'reg_lambda': 0.5808361216819946}. Best is trial 0 with value: 0.8274774594024914.
# [I 2024-02-07 19:32:32,618] Trial 1 finished with value: 0.8222501925021044 and parameters: {'num_leaves': 38, 'learning_rate': 0.06051038616257767, 'n_estimators': 156, 'min_child_samples': 6, 'colsample_bytree': 0.9909729556485982, 'reg_alpha': 0.8324426408004217, 'reg_lambda': 2.1233911067827616}. Best is trial 0 with value: 0.8274774594024914.
# [I 2024-02-07 19:32:33,382] Trial 2 finished with value: 0.7692359196854787 and parameters: {'num_leaves': 23, 'learning_rate': 0.01915704647548995, 'n_estimators': 95, 'min_child_samples': 44, 'colsample_bytree': 0.8295835055926347, 'reg_alpha': 0.2912291401980419, 'reg_lambda': 6.118528947223795}. Best is trial 0 with value: 0.8274774594024914.
# [I 2024-02-07 19:32:34,122] Trial 3 finished with value: 0.7835038867611968 and parameters: {'num_leaves': 22, 'learning_rate': 0.0299223202049866, 'n_estimators': 105, 'min_child_samples': 39, 'colsample_bytree': 0.935552788417904, 'reg_alpha': 0.19967378215835974, 'reg_lambda': 5.142344384136116}. Best is trial 0 with value: 0.8274774594024914.
# [I 2024-02-07 19:32:35,355] Trial 4 finished with value: 0.6267320499334927 and parameters: {'num_leaves': 32, 'learning_rate': 0.005598590859279775, 'n_estimators': 141, 'min_child_samples': 17, 'colsample_bytree': 0.7195154778955838, 'reg_alpha': 0.9488855372533332, 'reg_lambda': 9.656320330745594}. Best is trial 0 with value: 0.8274774594024914.
# [I 2024-02-07 19:32:36,274] Trial 5 finished with value: 0.7843045139016244 and parameters: {'num_leaves': 36, 'learning_rate': 0.0311567631481637, 'n_estimators': 64, 'min_child_samples': 57, 'colsample_bytree': 0.8320457481218804, 'reg_alpha': 0.12203823484477883, 'reg_lambda': 4.951769101112702}. Best is trial 0 with value: 0.8274774594024914.
# [I 2024-02-07 19:32:36,951] Trial 6 finished with value: 0.8065466600257152 and parameters: {'num_leaves': 20, 'learning_rate': 0.09102271980579943, 'n_estimators': 89, 'min_child_samples': 55, 'colsample_bytree': 0.7935133228268233, 'reg_alpha': 0.5200680211778108, 'reg_lambda': 5.4671027934327965}. Best is trial 0 with value: 0.8274774594024914.
# [I 2024-02-07 19:32:38,034] Trial 7 finished with value: 0.823899488815704 and parameters: {'num_leaves': 23, 'learning_rate': 0.0969888781486913, 'n_estimators': 167, 'min_child_samples': 76, 'colsample_bytree': 0.9684482051282947, 'reg_alpha': 0.5978999788110851, 'reg_lambda': 9.218742350231167}. Best is trial 0 with value: 0.8274774594024914.
# [I 2024-02-07 19:32:38,626] Trial 8 finished with value: 0.7244317464480063 and parameters: {'num_leaves': 21, 'learning_rate': 0.020402303379495376, 'n_estimators': 56, 'min_child_samples': 29, 'colsample_bytree': 0.8166031869068446, 'reg_alpha': 0.2713490317738959, 'reg_lambda': 8.287375091519294}. Best is trial 0 with value: 0.8274774594024914.
# [I 2024-02-07 19:32:40,048] Trial 9 finished with value: 0.7892575644309918 and parameters: {'num_leaves': 27, 'learning_rate': 0.028812516459050697, 'n_estimators': 131, 'min_child_samples': 15, 'colsample_bytree': 0.9406590942262119, 'reg_alpha': 0.07455064367977082, 'reg_lambda': 9.868869366005173}. Best is trial 0 with value: 0.8274774594024914.
# [I 2024-02-07 19:32:41,705] Trial 10 finished with value: 0.830777096521565 and parameters: {'num_leaves': 29, 'learning_rate': 0.07090723154361725, 'n_estimators': 196, 'min_child_samples': 75, 'colsample_bytree': 0.7046103211984313, 'reg_alpha': 0.39804334222017657, 'reg_lambda': 0.1514423710275684}. Best is trial 10 with value: 0.830777096521565.
# [I 2024-02-07 19:32:43,466] Trial 11 finished with value: 0.8324736109250024 and parameters: {'num_leaves': 29, 'learning_rate': 0.07290121015738923, 'n_estimators': 200, 'min_child_samples': 80, 'colsample_bytree': 0.7027683007133353, 'reg_alpha': 0.414991151713642, 'reg_lambda': 0.2856361724295679}. Best is trial 11 with value: 0.8324736109250024.
# [I 2024-02-07 19:32:45,220] Trial 12 finished with value: 0.8308850237242567 and parameters: {'num_leaves': 31, 'learning_rate': 0.07049967815463387, 'n_estimators': 200, 'min_child_samples': 80, 'colsample_bytree': 0.7023298688781557, 'reg_alpha': 0.3875942040639607, 'reg_lambda': 0.4501661697847158}. Best is trial 11 with value: 0.8324736109250024.
# [I 2024-02-07 19:32:46,627] Trial 13 finished with value: 0.8329755980085188 and parameters: {'num_leaves': 32, 'learning_rate': 0.07672752200391571, 'n_estimators': 194, 'min_child_samples': 80, 'colsample_bytree': 0.7714102893405995, 'reg_alpha': 0.444260272340844, 'reg_lambda': 2.2713901165087846}. Best is trial 13 with value: 0.8329755980085188.
# [I 2024-02-07 19:32:48,096] Trial 14 finished with value: 0.8340147204057896 and parameters: {'num_leaves': 35, 'learning_rate': 0.07850413310747746, 'n_estimators': 181, 'min_child_samples': 67, 'colsample_bytree': 0.7674019769404626, 'reg_alpha': 0.6634064286119825, 'reg_lambda': 2.4287522194687883}. Best is trial 14 with value: 0.8340147204057896.
# [I 2024-02-07 19:32:49,769] Trial 15 finished with value: 0.8266440677785921 and parameters: {'num_leaves': 34, 'learning_rate': 0.055058970509010347, 'n_estimators': 177, 'min_child_samples': 65, 'colsample_bytree': 0.7680329238983784, 'reg_alpha': 0.6866548980401573, 'reg_lambda': 2.893853823038998}. Best is trial 14 with value: 0.8340147204057896.
# [I 2024-02-07 19:32:51,345] Trial 16 finished with value: 0.8339600358575623 and parameters: {'num_leaves': 40, 'learning_rate': 0.08547699696125818, 'n_estimators': 184, 'min_child_samples': 66, 'colsample_bytree': 0.881259551274359, 'reg_alpha': 0.6998275927607389, 'reg_lambda': 2.747074078048049}. Best is trial 14 with value: 0.8340147204057896.
# [I 2024-02-07 19:32:53,386] Trial 17 finished with value: 0.8306436947794076 and parameters: {'num_leaves': 40, 'learning_rate': 0.08515881644303783, 'n_estimators': 180, 'min_child_samples': 66, 'colsample_bytree': 0.8798505514770758, 'reg_alpha': 0.7444244392995552, 'reg_lambda': 3.5422265055270117}. Best is trial 14 with value: 0.8340147204057896.
# [I 2024-02-07 19:32:54,775] Trial 18 finished with value: 0.8158938620609559 and parameters: {'num_leaves': 40, 'learning_rate': 0.04532272482190751, 'n_estimators': 145, 'min_child_samples': 65, 'colsample_bytree': 0.8971435912982684, 'reg_alpha': 0.9719529809507922, 'reg_lambda': 4.011822223779507}. Best is trial 14 with value: 0.8340147204057896.
# [I 2024-02-07 19:32:55,706] Trial 19 finished with value: 0.8249674433855123 and parameters: {'num_leaves': 36, 'learning_rate': 0.08302207197020955, 'n_estimators': 117, 'min_child_samples': 69, 'colsample_bytree': 0.871054491897576, 'reg_alpha': 0.6161346521679243, 'reg_lambda': 1.6405553597722955}. Best is trial 14 with value: 0.8340147204057896.
# [I 2024-02-07 19:32:57,404] Trial 20 finished with value: 0.8267271581674116 and parameters: {'num_leaves': 35, 'learning_rate': 0.061179767923317294, 'n_estimators': 182, 'min_child_samples': 38, 'colsample_bytree': 0.9055153644792805, 'reg_alpha': 0.8112070474685089, 'reg_lambda': 6.310240322987689}. Best is trial 14 with value: 0.8340147204057896.
# [I 2024-02-07 19:32:58,858] Trial 21 finished with value: 0.8327023173823642 and parameters: {'num_leaves': 33, 'learning_rate': 0.08148296719262604, 'n_estimators': 186, 'min_child_samples': 71, 'colsample_bytree': 0.7834867107040626, 'reg_alpha': 0.5557141029208543, 'reg_lambda': 1.7976968288761546}. Best is trial 14 with value: 0.8340147204057896.
# [I 2024-02-07 19:33:00,318] Trial 22 finished with value: 0.8342217991514131 and parameters: {'num_leaves': 38, 'learning_rate': 0.07472479757931544, 'n_estimators': 169, 'min_child_samples': 58, 'colsample_bytree': 0.756146894520497, 'reg_alpha': 0.6934559757182114, 'reg_lambda': 2.897260764032758}. Best is trial 22 with value: 0.8342217991514131.
# [I 2024-02-07 19:33:01,601] Trial 23 finished with value: 0.8334546215952425 and parameters: {'num_leaves': 37, 'learning_rate': 0.0996263130561193, 'n_estimators': 168, 'min_child_samples': 56, 'colsample_bytree': 0.7401439072496075, 'reg_alpha': 0.6980966400054012, 'reg_lambda': 3.947312295189467}. Best is trial 22 with value: 0.8342217991514131.
# [I 2024-02-07 19:33:02,926] Trial 24 finished with value: 0.8177015272089934 and parameters: {'num_leaves': 38, 'learning_rate': 0.04751239301678558, 'n_estimators': 150, 'min_child_samples': 61, 'colsample_bytree': 0.8556091826468576, 'reg_alpha': 0.8523599597695553, 'reg_lambda': 3.0045620412859497}. Best is trial 22 with value: 0.8342217991514131.
# [I 2024-02-07 19:33:04,520] Trial 25 finished with value: 0.8298653764606787 and parameters: {'num_leaves': 39, 'learning_rate': 0.06487672736026631, 'n_estimators': 169, 'min_child_samples': 49, 'colsample_bytree': 0.7987829060845949, 'reg_alpha': 0.6408941435366401, 'reg_lambda': 1.1571544807726646}. Best is trial 22 with value: 0.8342217991514131.
# [I 2024-02-07 19:33:05,854] Trial 26 finished with value: 0.8307166444293632 and parameters: {'num_leaves': 38, 'learning_rate': 0.0882700315156589, 'n_estimators': 132, 'min_child_samples': 60, 'colsample_bytree': 0.7403219904546202, 'reg_alpha': 0.7663421949435337, 'reg_lambda': 2.866938139981309}. Best is trial 22 with value: 0.8342217991514131.
# [I 2024-02-07 19:33:07,339] Trial 27 finished with value: 0.8321109752355584 and parameters: {'num_leaves': 35, 'learning_rate': 0.08203964550101411, 'n_estimators': 187, 'min_child_samples': 52, 'colsample_bytree': 0.8090381029415411, 'reg_alpha': 0.9275916119933424, 'reg_lambda': 3.94652620979994}. Best is trial 22 with value: 0.8342217991514131.
# [I 2024-02-07 19:33:09,567] Trial 28 finished with value: 0.8330882568100819 and parameters: {'num_leaves': 40, 'learning_rate': 0.07675326794095541, 'n_estimators': 175, 'min_child_samples': 72, 'colsample_bytree': 0.8408829241805595, 'reg_alpha': 0.6957081769594511, 'reg_lambda': 4.494835609586898}. Best is trial 22 with value: 0.8342217991514131.
# [I 2024-02-07 19:33:10,687] Trial 29 finished with value: 0.8310223280021948 and parameters: {'num_leaves': 37, 'learning_rate': 0.09220826994529403, 'n_estimators': 157, 'min_child_samples': 46, 'colsample_bytree': 0.7471371932271111, 'reg_alpha': 0.8871698766914266, 'reg_lambda': 0.877657793321005}. Best is trial 22 with value: 0.8342217991514131.
# [I 2024-02-07 19:33:12,141] Trial 30 finished with value: 0.8156949611308815 and parameters: {'num_leaves': 34, 'learning_rate': 0.04083760638064448, 'n_estimators': 160, 'min_child_samples': 61, 'colsample_bytree': 0.758686163403366, 'reg_alpha': 0.00026211230471273606, 'reg_lambda': 7.2211924777949115}. Best is trial 22 with value: 0.8342217991514131.
# [I 2024-02-07 19:33:13,770] Trial 31 finished with value: 0.8332430573045093 and parameters: {'num_leaves': 37, 'learning_rate': 0.09589694136031408, 'n_estimators': 165, 'min_child_samples': 53, 'colsample_bytree': 0.7301362419577635, 'reg_alpha': 0.7231679610275606, 'reg_lambda': 3.53193389182379}. Best is trial 22 with value: 0.8342217991514131.
# [I 2024-02-07 19:33:15,556] Trial 32 finished with value: 0.8350661416537095 and parameters: {'num_leaves': 39, 'learning_rate': 0.09818165885108596, 'n_estimators': 174, 'min_child_samples': 58, 'colsample_bytree': 0.7549080056821382, 'reg_alpha': 0.782776434270354, 'reg_lambda': 2.3170209676835234}. Best is trial 32 with value: 0.8350661416537095.
# [I 2024-02-07 19:33:16,779] Trial 33 finished with value: 0.8311042228772433 and parameters: {'num_leaves': 39, 'learning_rate': 0.06656636908558346, 'n_estimators': 150, 'min_child_samples': 65, 'colsample_bytree': 0.784193005781161, 'reg_alpha': 0.8094053437551609, 'reg_lambda': 2.414645170716735}. Best is trial 32 with value: 0.8350661416537095.
# [I 2024-02-07 19:33:18,482] Trial 34 finished with value: 0.8350026547051801 and parameters: {'num_leaves': 39, 'learning_rate': 0.08839951901099927, 'n_estimators': 174, 'min_child_samples': 40, 'colsample_bytree': 0.7570767201879367, 'reg_alpha': 0.6457092094250116, 'reg_lambda': 1.4146706449340256}. Best is trial 32 with value: 0.8350661416537095.
# [I 2024-02-07 19:33:19,678] Trial 35 finished with value: 0.8215228689213582 and parameters: {'num_leaves': 38, 'learning_rate': 0.05535883242722608, 'n_estimators': 137, 'min_child_samples': 35, 'colsample_bytree': 0.7637565495033273, 'reg_alpha': 0.557388402064622, 'reg_lambda': 1.3663456423529197}. Best is trial 32 with value: 0.8350661416537095.
# [I 2024-02-07 19:33:20,669] Trial 36 finished with value: 0.8277683600684437 and parameters: {'num_leaves': 36, 'learning_rate': 0.07792700375562348, 'n_estimators': 116, 'min_child_samples': 30, 'colsample_bytree': 0.7214123354484382, 'reg_alpha': 0.4802156885774356, 'reg_lambda': 1.7698259608063118}. Best is trial 32 with value: 0.8350661416537095.
# [I 2024-02-07 19:33:21,972] Trial 37 finished with value: 0.8356991201667995 and parameters: {'num_leaves': 39, 'learning_rate': 0.0893185884826169, 'n_estimators': 173, 'min_child_samples': 43, 'colsample_bytree': 0.7517289145694261, 'reg_alpha': 0.642874807660173, 'reg_lambda': 0.9351926228882265}. Best is trial 37 with value: 0.8356991201667995.
# [I 2024-02-07 19:33:23,082] Trial 38 finished with value: 0.8251161471042406 and parameters: {'num_leaves': 26, 'learning_rate': 0.08966420429944295, 'n_estimators': 153, 'min_child_samples': 42, 'colsample_bytree': 0.749753947735031, 'reg_alpha': 0.5950465419170106, 'reg_lambda': 1.1212994559145704}. Best is trial 37 with value: 0.8356991201667995.
# [I 2024-02-07 19:33:24,679] Trial 39 finished with value: 0.8366169415602283 and parameters: {'num_leaves': 39, 'learning_rate': 0.09982047985061834, 'n_estimators': 172, 'min_child_samples': 48, 'colsample_bytree': 0.7267463684443649, 'reg_alpha': 0.7564351903249326, 'reg_lambda': 2.0090236550279617}. Best is trial 39 with value: 0.8366169415602283.
# [I 2024-02-07 19:33:25,547] Trial 40 finished with value: 0.822794395778071 and parameters: {'num_leaves': 39, 'learning_rate': 0.09625602569508002, 'n_estimators': 80, 'min_child_samples': 46, 'colsample_bytree': 0.7243683213146103, 'reg_alpha': 0.7705906754264111, 'reg_lambda': 0.8766177275848884}. Best is trial 39 with value: 0.8366169415602283.
# [I 2024-02-07 19:33:27,211] Trial 41 finished with value: 0.8354007819017001 and parameters: {'num_leaves': 38, 'learning_rate': 0.09150260992275072, 'n_estimators': 173, 'min_child_samples': 41, 'colsample_bytree': 0.7351066513971343, 'reg_alpha': 0.8757113333323513, 'reg_lambda': 1.990719289088372}. Best is trial 39 with value: 0.8366169415602283.
# [I 2024-02-07 19:33:28,727] Trial 42 finished with value: 0.8367337135156616 and parameters: {'num_leaves': 39, 'learning_rate': 0.09221886546709424, 'n_estimators': 160, 'min_child_samples': 35, 'colsample_bytree': 0.718442519755511, 'reg_alpha': 0.8920225628400933, 'reg_lambda': 1.8798845654437373}. Best is trial 42 with value: 0.8367337135156616.
# [I 2024-02-07 19:33:30,400] Trial 43 finished with value: 0.8335595901495259 and parameters: {'num_leaves': 37, 'learning_rate': 0.09958765236050936, 'n_estimators': 157, 'min_child_samples': 33, 'colsample_bytree': 0.7334298659065811, 'reg_alpha': 0.9165328695662444, 'reg_lambda': 1.9956241064395461}. Best is trial 42 with value: 0.8367337135156616.
# [I 2024-02-07 19:33:32,424] Trial 44 finished with value: 0.84272449135544 and parameters: {'num_leaves': 39, 'learning_rate': 0.09249119937212143, 'n_estimators': 190, 'min_child_samples': 25, 'colsample_bytree': 0.7152979201163386, 'reg_alpha': 0.8713242171786584, 'reg_lambda': 0.04839028941966328}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:34,094] Trial 45 finished with value: 0.8416158571801704 and parameters: {'num_leaves': 40, 'learning_rate': 0.09294514843731405, 'n_estimators': 189, 'min_child_samples': 24, 'colsample_bytree': 0.7153164990837948, 'reg_alpha': 0.869988323499088, 'reg_lambda': 0.044070154740745646}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:35,370] Trial 46 finished with value: 0.8314541691029813 and parameters: {'num_leaves': 25, 'learning_rate': 0.09350361736431137, 'n_estimators': 188, 'min_child_samples': 22, 'colsample_bytree': 0.7140196196408238, 'reg_alpha': 0.9650500206243249, 'reg_lambda': 0.20667041472705683}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:37,499] Trial 47 finished with value: 0.841587748951589 and parameters: {'num_leaves': 40, 'learning_rate': 0.0938351135048438, 'n_estimators': 192, 'min_child_samples': 23, 'colsample_bytree': 0.7136533199436713, 'reg_alpha': 0.8271918736528732, 'reg_lambda': 0.051896066649379555}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:39,528] Trial 48 finished with value: 0.7928310185101454 and parameters: {'num_leaves': 40, 'learning_rate': 0.009846005190651805, 'n_estimators': 193, 'min_child_samples': 23, 'colsample_bytree': 0.7083574843399362, 'reg_alpha': 0.999573833946649, 'reg_lambda': 0.02684344386975024}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:40,998] Trial 49 finished with value: 0.8403350692624618 and parameters: {'num_leaves': 36, 'learning_rate': 0.09559572686395684, 'n_estimators': 192, 'min_child_samples': 5, 'colsample_bytree': 0.7128715420060665, 'reg_alpha': 0.8353069060023212, 'reg_lambda': 0.6190548940188136}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:42,463] Trial 50 finished with value: 0.8383363654215694 and parameters: {'num_leaves': 36, 'learning_rate': 0.08612561649328859, 'n_estimators': 192, 'min_child_samples': 6, 'colsample_bytree': 0.7018218989455988, 'reg_alpha': 0.8308536082986936, 'reg_lambda': 0.4634576454363081}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:44,024] Trial 51 finished with value: 0.8375906082093069 and parameters: {'num_leaves': 36, 'learning_rate': 0.09321792837092807, 'n_estimators': 192, 'min_child_samples': 7, 'colsample_bytree': 0.7126940855227464, 'reg_alpha': 0.8544506463410718, 'reg_lambda': 0.6099948289514054}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:45,375] Trial 52 finished with value: 0.837934458528097 and parameters: {'num_leaves': 33, 'learning_rate': 0.08654726741155341, 'n_estimators': 193, 'min_child_samples': 5, 'colsample_bytree': 0.7029748265348085, 'reg_alpha': 0.8246912122918061, 'reg_lambda': 0.6355456996981697}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:46,760] Trial 53 finished with value: 0.8372207308937332 and parameters: {'num_leaves': 32, 'learning_rate': 0.08562850329478533, 'n_estimators': 200, 'min_child_samples': 9, 'colsample_bytree': 0.7010869419077597, 'reg_alpha': 0.8228757414871997, 'reg_lambda': 0.5974656510730645}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:47,975] Trial 54 finished with value: 0.8338368627858239 and parameters: {'num_leaves': 30, 'learning_rate': 0.0801378659319041, 'n_estimators': 191, 'min_child_samples': 13, 'colsample_bytree': 0.7135337033155709, 'reg_alpha': 0.9313848668029585, 'reg_lambda': 0.013743794561441001}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:49,326] Trial 55 finished with value: 0.8363963610466328 and parameters: {'num_leaves': 34, 'learning_rate': 0.08554586153005703, 'n_estimators': 195, 'min_child_samples': 5, 'colsample_bytree': 0.7001651345292708, 'reg_alpha': 0.7958977440099859, 'reg_lambda': 0.6399532471634231}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:50,516] Trial 56 finished with value: 0.8350270448345682 and parameters: {'num_leaves': 33, 'learning_rate': 0.09526709579724973, 'n_estimators': 182, 'min_child_samples': 20, 'colsample_bytree': 0.7272208070974866, 'reg_alpha': 0.8491124172958079, 'reg_lambda': 0.4134724844557994}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:51,969] Trial 57 finished with value: 0.8361800055544613 and parameters: {'num_leaves': 36, 'learning_rate': 0.07288101734990997, 'n_estimators': 197, 'min_child_samples': 11, 'colsample_bytree': 0.9978397176218622, 'reg_alpha': 0.31714357795548054, 'reg_lambda': 1.2668719573353129}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:53,263] Trial 58 finished with value: 0.8335367369529507 and parameters: {'num_leaves': 31, 'learning_rate': 0.08459892542263873, 'n_estimators': 188, 'min_child_samples': 18, 'colsample_bytree': 0.9507709113842973, 'reg_alpha': 0.9085583555085737, 'reg_lambda': 0.40239350238209953}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:54,638] Trial 59 finished with value: 0.8312516480377733 and parameters: {'num_leaves': 35, 'learning_rate': 0.06929997373947167, 'n_estimators': 180, 'min_child_samples': 26, 'colsample_bytree': 0.776809761638469, 'reg_alpha': 0.7396653435987104, 'reg_lambda': 0.8500660359267378}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:56,158] Trial 60 finished with value: 0.8328136422157918 and parameters: {'num_leaves': 33, 'learning_rate': 0.08737553205436394, 'n_estimators': 185, 'min_child_samples': 14, 'colsample_bytree': 0.7147869234870603, 'reg_alpha': 0.8371435166852728, 'reg_lambda': 8.960901541288491}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:57,656] Trial 61 finished with value: 0.8381567037166737 and parameters: {'num_leaves': 37, 'learning_rate': 0.09425808340060476, 'n_estimators': 193, 'min_child_samples': 8, 'colsample_bytree': 0.7113233484054674, 'reg_alpha': 0.8735640512161805, 'reg_lambda': 0.5837686643144088}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:33:59,076] Trial 62 finished with value: 0.8426078167412074 and parameters: {'num_leaves': 37, 'learning_rate': 0.0957576394914958, 'n_estimators': 195, 'min_child_samples': 8, 'colsample_bytree': 0.7387577953209464, 'reg_alpha': 0.9937846108455028, 'reg_lambda': 0.05535478733424093}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:00,574] Trial 63 finished with value: 0.8406536040392979 and parameters: {'num_leaves': 37, 'learning_rate': 0.09596824395286697, 'n_estimators': 199, 'min_child_samples': 10, 'colsample_bytree': 0.7406834519928122, 'reg_alpha': 0.9868876649467666, 'reg_lambda': 0.33026363637340156}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:01,972] Trial 64 finished with value: 0.839168987918795 and parameters: {'num_leaves': 40, 'learning_rate': 0.09688253518020204, 'n_estimators': 180, 'min_child_samples': 17, 'colsample_bytree': 0.7400881051243565, 'reg_alpha': 0.997646609838824, 'reg_lambda': 0.1854530506040769}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:03,559] Trial 65 finished with value: 0.8406218021592862 and parameters: {'num_leaves': 40, 'learning_rate': 0.09555074053568381, 'n_estimators': 199, 'min_child_samples': 16, 'colsample_bytree': 0.7429766221276208, 'reg_alpha': 0.9857948301634677, 'reg_lambda': 0.13563496888159302}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:05,185] Trial 66 finished with value: 0.8382867400206008 and parameters: {'num_leaves': 40, 'learning_rate': 0.09093345656631344, 'n_estimators': 200, 'min_child_samples': 11, 'colsample_bytree': 0.741992129751695, 'reg_alpha': 0.9467084490651846, 'reg_lambda': 0.18129221573851945}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:06,797] Trial 67 finished with value: 0.8218176489896564 and parameters: {'num_leaves': 38, 'learning_rate': 0.03732661147488302, 'n_estimators': 197, 'min_child_samples': 26, 'colsample_bytree': 0.7320594895939941, 'reg_alpha': 0.9737502519851262, 'reg_lambda': 1.053181238567538}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:08,295] Trial 68 finished with value: 0.8361441744357716 and parameters: {'num_leaves': 37, 'learning_rate': 0.08092938640144774, 'n_estimators': 186, 'min_child_samples': 11, 'colsample_bytree': 0.7233200384534231, 'reg_alpha': 0.9578897663164836, 'reg_lambda': 1.5184456252790746}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:09,773] Trial 69 finished with value: 0.837027400493235 and parameters: {'num_leaves': 40, 'learning_rate': 0.0960390221348058, 'n_estimators': 178, 'min_child_samples': 16, 'colsample_bytree': 0.8246733170510854, 'reg_alpha': 0.9056832251983236, 'reg_lambda': 5.972220506975959}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:10,517] Trial 70 finished with value: 0.8254567537763012 and parameters: {'num_leaves': 38, 'learning_rate': 0.09734024080467443, 'n_estimators': 89, 'min_child_samples': 19, 'colsample_bytree': 0.7945000027717607, 'reg_alpha': 0.9390431574722347, 'reg_lambda': 0.12728033738481792}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:12,107] Trial 71 finished with value: 0.8392822110150202 and parameters: {'num_leaves': 40, 'learning_rate': 0.09454276070344991, 'n_estimators': 189, 'min_child_samples': 16, 'colsample_bytree': 0.7420892620157201, 'reg_alpha': 0.9990185216343221, 'reg_lambda': 0.0035722531393971857}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:13,640] Trial 72 finished with value: 0.8388560379072099 and parameters: {'num_leaves': 40, 'learning_rate': 0.09078093949324598, 'n_estimators': 189, 'min_child_samples': 23, 'colsample_bytree': 0.7727730806674553, 'reg_alpha': 0.9738648208854954, 'reg_lambda': 0.043662748277107574}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:15,131] Trial 73 finished with value: 0.8422759321960724 and parameters: {'num_leaves': 38, 'learning_rate': 0.09950263582743463, 'n_estimators': 199, 'min_child_samples': 26, 'colsample_bytree': 0.7438424364197337, 'reg_alpha': 0.9874522478050064, 'reg_lambda': 0.9364902310302157}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:16,709] Trial 74 finished with value: 0.8375647865329994 and parameters: {'num_leaves': 37, 'learning_rate': 0.09885166231991693, 'n_estimators': 200, 'min_child_samples': 26, 'colsample_bytree': 0.7613407528430047, 'reg_alpha': 0.9307853015646275, 'reg_lambda': 0.7926926981542441}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:18,280] Trial 75 finished with value: 0.8099405996716132 and parameters: {'num_leaves': 38, 'learning_rate': 0.025966437930172212, 'n_estimators': 183, 'min_child_samples': 29, 'colsample_bytree': 0.7204482251679113, 'reg_alpha': 0.8657873355036357, 'reg_lambda': 1.1063678370646026}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:19,863] Trial 76 finished with value: 0.8398164201009664 and parameters: {'num_leaves': 39, 'learning_rate': 0.09348420886435692, 'n_estimators': 197, 'min_child_samples': 13, 'colsample_bytree': 0.7361989699793723, 'reg_alpha': 0.8979944197747551, 'reg_lambda': 0.3456726477520262}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:20,393] Trial 77 finished with value: 0.8111975463659125 and parameters: {'num_leaves': 38, 'learning_rate': 0.09997274971927975, 'n_estimators': 53, 'min_child_samples': 21, 'colsample_bytree': 0.7436582401942662, 'reg_alpha': 0.9712983400757816, 'reg_lambda': 1.5340487525265631}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:21,974] Trial 78 finished with value: 0.8372569766899378 and parameters: {'num_leaves': 37, 'learning_rate': 0.08985660882751859, 'n_estimators': 197, 'min_child_samples': 10, 'colsample_bytree': 0.7490912805379305, 'reg_alpha': 0.9360066898006529, 'reg_lambda': 7.331837308410014}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:22,583] Trial 79 finished with value: 0.8191594455199762 and parameters: {'num_leaves': 39, 'learning_rate': 0.09595542100430456, 'n_estimators': 66, 'min_child_samples': 24, 'colsample_bytree': 0.7805373304975647, 'reg_alpha': 0.1899350035298505, 'reg_lambda': 1.265225697302517}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:23,720] Trial 80 finished with value: 0.829874187933725 and parameters: {'num_leaves': 28, 'learning_rate': 0.08820267599431345, 'n_estimators': 164, 'min_child_samples': 31, 'colsample_bytree': 0.7657230987497247, 'reg_alpha': 0.8832254494296727, 'reg_lambda': 0.842226337868292}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:25,594] Trial 81 finished with value: 0.8415276546312296 and parameters: {'num_leaves': 39, 'learning_rate': 0.09284330497755049, 'n_estimators': 196, 'min_child_samples': 14, 'colsample_bytree': 0.7325615930401137, 'reg_alpha': 0.8998052589446771, 'reg_lambda': 0.291265435215847}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:27,587] Trial 82 finished with value: 0.8353181324742168 and parameters: {'num_leaves': 38, 'learning_rate': 0.0916448241947327, 'n_estimators': 186, 'min_child_samples': 14, 'colsample_bytree': 0.7287804241010933, 'reg_alpha': 0.9096038664494595, 'reg_lambda': 0.3705557804908452}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:29,626] Trial 83 finished with value: 0.8399445094623165 and parameters: {'num_leaves': 39, 'learning_rate': 0.0978107157149555, 'n_estimators': 195, 'min_child_samples': 8, 'colsample_bytree': 0.7214394619756501, 'reg_alpha': 0.9508225009864834, 'reg_lambda': 0.363599580350813}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:31,563] Trial 84 finished with value: 0.8399684082302301 and parameters: {'num_leaves': 40, 'learning_rate': 0.0830435541905548, 'n_estimators': 177, 'min_child_samples': 19, 'colsample_bytree': 0.7508739386021097, 'reg_alpha': 0.9835520164456399, 'reg_lambda': 0.7063882864112054}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:33,120] Trial 85 finished with value: 0.8412414926401874 and parameters: {'num_leaves': 38, 'learning_rate': 0.09368329947103289, 'n_estimators': 190, 'min_child_samples': 12, 'colsample_bytree': 0.7082818992769204, 'reg_alpha': 0.7965353671388852, 'reg_lambda': 1.0148854753164473}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:34,779] Trial 86 finished with value: 0.8390065005246404 and parameters: {'num_leaves': 39, 'learning_rate': 0.08331921486149448, 'n_estimators': 200, 'min_child_samples': 15, 'colsample_bytree': 0.7329479406217049, 'reg_alpha': 0.8053556780162631, 'reg_lambda': 0.99301892470612}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:36,366] Trial 87 finished with value: 0.8387250423004227 and parameters: {'num_leaves': 39, 'learning_rate': 0.08834552146269485, 'n_estimators': 189, 'min_child_samples': 28, 'colsample_bytree': 0.707135577225269, 'reg_alpha': 0.87040489762906, 'reg_lambda': 1.691238032229275}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:37,084] Trial 88 finished with value: 0.8178980708271937 and parameters: {'num_leaves': 22, 'learning_rate': 0.09317067191694722, 'n_estimators': 112, 'min_child_samples': 12, 'colsample_bytree': 0.7211951251067027, 'reg_alpha': 0.9543294036120853, 'reg_lambda': 0.29616983429391475}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:38,436] Trial 89 finished with value: 0.836916687755355 and parameters: {'num_leaves': 38, 'learning_rate': 0.09734271211652862, 'n_estimators': 183, 'min_child_samples': 25, 'colsample_bytree': 0.80899380566378, 'reg_alpha': 0.789652467436704, 'reg_lambda': 1.3179106120665862}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:40,142] Trial 90 finished with value: 0.8367273925979732 and parameters: {'num_leaves': 35, 'learning_rate': 0.07949475354194047, 'n_estimators': 196, 'min_child_samples': 20, 'colsample_bytree': 0.755907847566262, 'reg_alpha': 0.9169718696587673, 'reg_lambda': 1.0710273776989203}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:41,561] Trial 91 finished with value: 0.8373363745845523 and parameters: {'num_leaves': 36, 'learning_rate': 0.09464083576312624, 'n_estimators': 191, 'min_child_samples': 7, 'colsample_bytree': 0.7098571678406228, 'reg_alpha': 0.8481983994101974, 'reg_lambda': 0.5517766676098846}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:43,081] Trial 92 finished with value: 0.8387713847617893 and parameters: {'num_leaves': 37, 'learning_rate': 0.09040077079013649, 'n_estimators': 190, 'min_child_samples': 9, 'colsample_bytree': 0.7175144868783796, 'reg_alpha': 0.7238988169823376, 'reg_lambda': 0.7059590161430433}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:44,657] Trial 93 finished with value: 0.837781061736256 and parameters: {'num_leaves': 40, 'learning_rate': 0.09435923570960347, 'n_estimators': 195, 'min_child_samples': 22, 'colsample_bytree': 0.727523004794174, 'reg_alpha': 0.8936645581327263, 'reg_lambda': 0.011755478283453101}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:46,125] Trial 94 finished with value: 0.8393625790930648 and parameters: {'num_leaves': 39, 'learning_rate': 0.09788174387734642, 'n_estimators': 185, 'min_child_samples': 18, 'colsample_bytree': 0.7366881267674571, 'reg_alpha': 0.778760715123421, 'reg_lambda': 0.28237674542559593}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:47,611] Trial 95 finished with value: 0.8395570993985855 and parameters: {'num_leaves': 38, 'learning_rate': 0.09149586216485707, 'n_estimators': 192, 'min_child_samples': 5, 'colsample_bytree': 0.706755119549911, 'reg_alpha': 0.9808428389435637, 'reg_lambda': 0.49487531001170115}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:49,078] Trial 96 finished with value: 0.8397050087853524 and parameters: {'num_leaves': 37, 'learning_rate': 0.09997764169009228, 'n_estimators': 197, 'min_child_samples': 13, 'colsample_bytree': 0.7462320726523681, 'reg_alpha': 0.9267371257609474, 'reg_lambda': 0.9115924212773289}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:50,600] Trial 97 finished with value: 0.8305047773597669 and parameters: {'num_leaves': 38, 'learning_rate': 0.05359948827465781, 'n_estimators': 178, 'min_child_samples': 10, 'colsample_bytree': 0.7179081338196742, 'reg_alpha': 0.8200662585171203, 'reg_lambda': 0.7526430654821697}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:52,102] Trial 98 finished with value: 0.8342524207240691 and parameters: {'num_leaves': 36, 'learning_rate': 0.087953140074229, 'n_estimators': 200, 'min_child_samples': 32, 'colsample_bytree': 0.9192775897926974, 'reg_alpha': 0.8619289923994575, 'reg_lambda': 0.2695610272668817}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:53,776] Trial 99 finished with value: 0.0 and parameters: {'num_leaves': 40, 'learning_rate': 0.003084109695941903, 'n_estimators': 183, 'min_child_samples': 28, 'colsample_bytree': 0.70872246380259, 'reg_alpha': 0.8891922902705667, 'reg_lambda': 4.858074029078394}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:55,325] Trial 100 finished with value: 0.8384893673091722 and parameters: {'num_leaves': 39, 'learning_rate': 0.09294469342392529, 'n_estimators': 187, 'min_child_samples': 16, 'colsample_bytree': 0.9796781160836372, 'reg_alpha': 0.9550275036485614, 'reg_lambda': 0.47722515016631856}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:56,983] Trial 101 finished with value: 0.8354105731308289 and parameters: {'num_leaves': 40, 'learning_rate': 0.08329400550843459, 'n_estimators': 177, 'min_child_samples': 19, 'colsample_bytree': 0.7520643545183168, 'reg_alpha': 0.9876125610370645, 'reg_lambda': 0.6750507660487222}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:58,514] Trial 102 finished with value: 0.8365402998676565 and parameters: {'num_leaves': 40, 'learning_rate': 0.09582875076923571, 'n_estimators': 191, 'min_child_samples': 21, 'colsample_bytree': 0.7265362815740484, 'reg_alpha': 0.9846833497760895, 'reg_lambda': 1.1515684892106801}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:34:59,516] Trial 103 finished with value: 0.8313031030263828 and parameters: {'num_leaves': 39, 'learning_rate': 0.08404777338074026, 'n_estimators': 126, 'min_child_samples': 15, 'colsample_bytree': 0.7391597043428433, 'reg_alpha': 0.9674987272702452, 'reg_lambda': 0.1550078884991043}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:01,336] Trial 104 finished with value: 0.8391801264782727 and parameters: {'num_leaves': 40, 'learning_rate': 0.09002341323816562, 'n_estimators': 194, 'min_child_samples': 7, 'colsample_bytree': 0.7324918737765503, 'reg_alpha': 0.8414964401407159, 'reg_lambda': 1.4496443261015821}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:03,117] Trial 105 finished with value: 0.8383590321952665 and parameters: {'num_leaves': 38, 'learning_rate': 0.08659178423010144, 'n_estimators': 180, 'min_child_samples': 17, 'colsample_bytree': 0.7480876427112587, 'reg_alpha': 0.9235909012916877, 'reg_lambda': 0.7552385752648225}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:04,484] Trial 106 finished with value: 0.8383656043327736 and parameters: {'num_leaves': 39, 'learning_rate': 0.09775487818179275, 'n_estimators': 187, 'min_child_samples': 9, 'colsample_bytree': 0.715183720097176, 'reg_alpha': 0.9473460304252223, 'reg_lambda': 0.49584615079841643}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:06,050] Trial 107 finished with value: 0.8407675558341392 and parameters: {'num_leaves': 37, 'learning_rate': 0.09200519966276713, 'n_estimators': 195, 'min_child_samples': 12, 'colsample_bytree': 0.7592556375338738, 'reg_alpha': 0.9998436991924335, 'reg_lambda': 0.19221282050877114}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:07,639] Trial 108 finished with value: 0.8392736745360194 and parameters: {'num_leaves': 37, 'learning_rate': 0.09213362154836449, 'n_estimators': 194, 'min_child_samples': 12, 'colsample_bytree': 0.7002657474720675, 'reg_alpha': 0.9987608290254605, 'reg_lambda': 2.565494643866062}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:09,285] Trial 109 finished with value: 0.8379064860627625 and parameters: {'num_leaves': 36, 'learning_rate': 0.09527546627899182, 'n_estimators': 198, 'min_child_samples': 6, 'colsample_bytree': 0.8641532658790255, 'reg_alpha': 0.8981367911610099, 'reg_lambda': 0.21936859785317134}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:10,788] Trial 110 finished with value: 0.8362546146159289 and parameters: {'num_leaves': 37, 'learning_rate': 0.09296317061179092, 'n_estimators': 171, 'min_child_samples': 10, 'colsample_bytree': 0.7687509966365661, 'reg_alpha': 0.7579084353106266, 'reg_lambda': 0.9315058939611537}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:12,420] Trial 111 finished with value: 0.8392766608975887 and parameters: {'num_leaves': 40, 'learning_rate': 0.09636742967809714, 'n_estimators': 191, 'min_child_samples': 14, 'colsample_bytree': 0.7604873759124156, 'reg_alpha': 0.9744587864848184, 'reg_lambda': 0.02559061174473598}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:14,159] Trial 112 finished with value: 0.8384799272425129 and parameters: {'num_leaves': 38, 'learning_rate': 0.08899794894452592, 'n_estimators': 195, 'min_child_samples': 18, 'colsample_bytree': 0.7245140394189952, 'reg_alpha': 0.9323157805576544, 'reg_lambda': 0.5606165440687569}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:15,740] Trial 113 finished with value: 0.8409771287844123 and parameters: {'num_leaves': 39, 'learning_rate': 0.09763209719003395, 'n_estimators': 198, 'min_child_samples': 12, 'colsample_bytree': 0.7445618505966458, 'reg_alpha': 0.9606810916764823, 'reg_lambda': 0.2869212949438079}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:17,604] Trial 114 finished with value: 0.7932798210126848 and parameters: {'num_leaves': 39, 'learning_rate': 0.013093795692874964, 'n_estimators': 198, 'min_child_samples': 37, 'colsample_bytree': 0.7362049880190797, 'reg_alpha': 0.9141471967959484, 'reg_lambda': 0.28187515043502087}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:19,199] Trial 115 finished with value: 0.8410194809144091 and parameters: {'num_leaves': 38, 'learning_rate': 0.09856502858887471, 'n_estimators': 189, 'min_child_samples': 8, 'colsample_bytree': 0.7428260146843192, 'reg_alpha': 0.9601795081029598, 'reg_lambda': 0.4470166584031763}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:20,247] Trial 116 finished with value: 0.8254536035409291 and parameters: {'num_leaves': 20, 'learning_rate': 0.0997201534017291, 'n_estimators': 188, 'min_child_samples': 12, 'colsample_bytree': 0.7444573007288583, 'reg_alpha': 0.9565178598239351, 'reg_lambda': 0.16440856222181185}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:22,014] Trial 117 finished with value: 0.8378141444071664 and parameters: {'num_leaves': 39, 'learning_rate': 0.09863427714697874, 'n_estimators': 185, 'min_child_samples': 8, 'colsample_bytree': 0.7552416071293148, 'reg_alpha': 0.34345068493793013, 'reg_lambda': 3.378032746070973}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:23,741] Trial 118 finished with value: 0.8316022823303628 and parameters: {'num_leaves': 38, 'learning_rate': 0.06016377042312423, 'n_estimators': 200, 'min_child_samples': 11, 'colsample_bytree': 0.7308755582999187, 'reg_alpha': 0.9435756272511527, 'reg_lambda': 0.30366450961464175}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:25,319] Trial 119 finished with value: 0.8370114187617448 and parameters: {'num_leaves': 37, 'learning_rate': 0.09386409577540292, 'n_estimators': 193, 'min_child_samples': 23, 'colsample_bytree': 0.761791325953788, 'reg_alpha': 0.878998273134457, 'reg_lambda': 0.43533907873993494}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:26,796] Trial 120 finished with value: 0.8389406499010722 and parameters: {'num_leaves': 39, 'learning_rate': 0.0913029037666722, 'n_estimators': 190, 'min_child_samples': 13, 'colsample_bytree': 0.7398339870891124, 'reg_alpha': 0.9989385986234911, 'reg_lambda': 0.012314830529804963}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:28,308] Trial 121 finished with value: 0.8417309107613195 and parameters: {'num_leaves': 36, 'learning_rate': 0.09657410196335434, 'n_estimators': 197, 'min_child_samples': 6, 'colsample_bytree': 0.7147730955937667, 'reg_alpha': 0.9668907636942033, 'reg_lambda': 0.9620629425329661}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:29,854] Trial 122 finished with value: 0.8396962864201107 and parameters: {'num_leaves': 38, 'learning_rate': 0.09716358033985636, 'n_estimators': 195, 'min_child_samples': 9, 'colsample_bytree': 0.7240037123632731, 'reg_alpha': 0.9661493473788173, 'reg_lambda': 0.9795496000039413}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:31,341] Trial 123 finished with value: 0.8397294281069246 and parameters: {'num_leaves': 37, 'learning_rate': 0.09518704108590485, 'n_estimators': 197, 'min_child_samples': 7, 'colsample_bytree': 0.7165288732994893, 'reg_alpha': 0.9159975745949321, 'reg_lambda': 1.2516433941539966}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:33,093] Trial 124 finished with value: 0.8400675513945893 and parameters: {'num_leaves': 38, 'learning_rate': 0.09769376271689355, 'n_estimators': 200, 'min_child_samples': 15, 'colsample_bytree': 0.7318750505079753, 'reg_alpha': 0.9425944686951306, 'reg_lambda': 0.7977089287640051}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:34,648] Trial 125 finished with value: 0.8382081062845611 and parameters: {'num_leaves': 35, 'learning_rate': 0.09277846492242708, 'n_estimators': 189, 'min_child_samples': 27, 'colsample_bytree': 0.7457851293021183, 'reg_alpha': 0.9763537750785429, 'reg_lambda': 0.4418300719108927}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:35,671] Trial 126 finished with value: 0.8290865253480121 and parameters: {'num_leaves': 24, 'learning_rate': 0.0895025330113454, 'n_estimators': 183, 'min_child_samples': 11, 'colsample_bytree': 0.711777720282934, 'reg_alpha': 0.959425057530275, 'reg_lambda': 0.1608411705831456}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:36,687] Trial 127 finished with value: 0.8352138568435696 and parameters: {'num_leaves': 37, 'learning_rate': 0.09489877761383139, 'n_estimators': 140, 'min_child_samples': 24, 'colsample_bytree': 0.7055837170972109, 'reg_alpha': 0.4613542626628875, 'reg_lambda': 0.6897347676846193}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:38,198] Trial 128 finished with value: 0.840497301161516 and parameters: {'num_leaves': 39, 'learning_rate': 0.08698584711003166, 'n_estimators': 193, 'min_child_samples': 6, 'colsample_bytree': 0.7732539400377674, 'reg_alpha': 0.9023101790991958, 'reg_lambda': 0.009614210217411823}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:39,674] Trial 129 finished with value: 0.839633521174202 and parameters: {'num_leaves': 36, 'learning_rate': 0.09833494991793021, 'n_estimators': 197, 'min_child_samples': 9, 'colsample_bytree': 0.7260319327179233, 'reg_alpha': 0.9311343145408226, 'reg_lambda': 1.0788913233259747}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:41,170] Trial 130 finished with value: 0.8410554803546901 and parameters: {'num_leaves': 40, 'learning_rate': 0.09992877267628643, 'n_estimators': 186, 'min_child_samples': 14, 'colsample_bytree': 0.7385127361398722, 'reg_alpha': 0.8604810189369604, 'reg_lambda': 1.6099784992996462}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:42,642] Trial 131 finished with value: 0.835889286372878 and parameters: {'num_leaves': 40, 'learning_rate': 0.09992175113467806, 'n_estimators': 186, 'min_child_samples': 14, 'colsample_bytree': 0.7371001735872612, 'reg_alpha': 0.8625803063879454, 'reg_lambda': 0.42826050803634036}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:44,189] Trial 132 finished with value: 0.8408100288905722 and parameters: {'num_leaves': 40, 'learning_rate': 0.09692437228192143, 'n_estimators': 194, 'min_child_samples': 11, 'colsample_bytree': 0.7186458949512321, 'reg_alpha': 0.8809543136904674, 'reg_lambda': 2.1818622781877925}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:45,805] Trial 133 finished with value: 0.8409015148449267 and parameters: {'num_leaves': 39, 'learning_rate': 0.09687845041414311, 'n_estimators': 190, 'min_child_samples': 12, 'colsample_bytree': 0.721669436710526, 'reg_alpha': 0.8009313995938153, 'reg_lambda': 1.4983531534064374}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:46,670] Trial 134 finished with value: 0.8284177012171019 and parameters: {'num_leaves': 39, 'learning_rate': 0.0933951971607052, 'n_estimators': 101, 'min_child_samples': 12, 'colsample_bytree': 0.7195556963855343, 'reg_alpha': 0.8206203117063322, 'reg_lambda': 2.0844442219386816}. Best is trial 44 with value: 0.84272449135544.
# [I 2024-02-07 19:35:48,175] Trial 135 finished with value: 0.8390842204577483 and parameters: {'num_leaves': 40, 'learning_rate': 0.09737013109837363, 'n_estimators': 182, 'min_child_samples': 8, 'colsample_bytree': 0.7092639299716547, 'reg_alpha': 0.8033604243309502, 'reg_lambda': 1.4043595915341858}. Best is trial 44 with value: 0.84272449135544.
# ...
# [I 2024-02-07 19:42:37,347] Trial 405 finished with value: 0.8347424630867982 and parameters: {'num_leaves': 26, 'learning_rate': 0.09412696108169849, 'n_estimators': 192, 'min_child_samples': 9, 'colsample_bytree': 0.7153379828603925, 'reg_alpha': 0.46363957512830933, 'reg_lambda': 0.6918965085289649}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:42:38,969] Trial 406 finished with value: 0.8380799031038851 and parameters: {'num_leaves': 39, 'learning_rate': 0.09792971873287266, 'n_estimators': 197, 'min_child_samples': 12, 'colsample_bytree': 0.7050719866881517, 'reg_alpha': 0.43369209004418485, 'reg_lambda': 7.2756799728326005}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:42:40,454] Trial 407 finished with value: 0.8406653083414183 and parameters: {'num_leaves': 38, 'learning_rate': 0.09238212492596991, 'n_estimators': 200, 'min_child_samples': 26, 'colsample_bytree': 0.7320941886649887, 'reg_alpha': 0.348715781166263, 'reg_lambda': 0.42181694822735916}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:42:41,918] Trial 408 finished with value: 0.8387414526673966 and parameters: {'num_leaves': 37, 'learning_rate': 0.09631335990819088, 'n_estimators': 189, 'min_child_samples': 16, 'colsample_bytree': 0.7218224000828833, 'reg_alpha': 0.28240369212783084, 'reg_lambda': 3.12287658241277}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:42:43,545] Trial 409 finished with value: 0.8395929233108153 and parameters: {'num_leaves': 40, 'learning_rate': 0.09530315129609584, 'n_estimators': 194, 'min_child_samples': 15, 'colsample_bytree': 0.7006035895264149, 'reg_alpha': 0.309214003906851, 'reg_lambda': 0.198648121299256}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:42:44,848] Trial 410 finished with value: 0.829001582364391 and parameters: {'num_leaves': 29, 'learning_rate': 0.06457525855011403, 'n_estimators': 197, 'min_child_samples': 11, 'colsample_bytree': 0.7080937746598549, 'reg_alpha': 0.050637924122053715, 'reg_lambda': 0.5742401181243024}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:42:46,347] Trial 411 finished with value: 0.8385583778773587 and parameters: {'num_leaves': 39, 'learning_rate': 0.09816952645092976, 'n_estimators': 192, 'min_child_samples': 18, 'colsample_bytree': 0.7451412813972373, 'reg_alpha': 0.19132982180798333, 'reg_lambda': 1.0132716087260778}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:42:47,869] Trial 412 finished with value: 0.8413040862517359 and parameters: {'num_leaves': 39, 'learning_rate': 0.09093905469652412, 'n_estimators': 195, 'min_child_samples': 9, 'colsample_bytree': 0.7157729574291557, 'reg_alpha': 0.23311182581822537, 'reg_lambda': 0.3412284789017554}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:42:49,355] Trial 413 finished with value: 0.840068508087161 and parameters: {'num_leaves': 36, 'learning_rate': 0.09996345636618734, 'n_estimators': 200, 'min_child_samples': 30, 'colsample_bytree': 0.7005976783168002, 'reg_alpha': 0.40389647892187985, 'reg_lambda': 0.17689740268651702}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:42:50,741] Trial 414 finished with value: 0.8347671216688177 and parameters: {'num_leaves': 38, 'learning_rate': 0.094708950294754, 'n_estimators': 170, 'min_child_samples': 49, 'colsample_bytree': 0.7268321853486646, 'reg_alpha': 0.41606445095804384, 'reg_lambda': 0.002632910372583508}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:42:51,688] Trial 415 finished with value: 0.8330228268814885 and parameters: {'num_leaves': 40, 'learning_rate': 0.08717645672032244, 'n_estimators': 120, 'min_child_samples': 13, 'colsample_bytree': 0.7201905120214348, 'reg_alpha': 0.02522749240506572, 'reg_lambda': 0.6880050500636763}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:42:53,200] Trial 416 finished with value: 0.838677422152952 and parameters: {'num_leaves': 37, 'learning_rate': 0.09249413067427588, 'n_estimators': 187, 'min_child_samples': 12, 'colsample_bytree': 0.7116465771409178, 'reg_alpha': 0.3670511952579704, 'reg_lambda': 0.43085756058463137}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:42:54,863] Trial 417 finished with value: 0.8394808407883796 and parameters: {'num_leaves': 39, 'learning_rate': 0.09708551127106611, 'n_estimators': 190, 'min_child_samples': 20, 'colsample_bytree': 0.7364330845308434, 'reg_alpha': 0.25983787438921513, 'reg_lambda': 0.8787780263460134}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:42:56,546] Trial 418 finished with value: 0.8391231176112829 and parameters: {'num_leaves': 38, 'learning_rate': 0.09995439896975643, 'n_estimators': 197, 'min_child_samples': 45, 'colsample_bytree': 0.7099253738093385, 'reg_alpha': 0.2075858799497382, 'reg_lambda': 0.20110840749991438}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:42:58,494] Trial 419 finished with value: 0.8397307810377249 and parameters: {'num_leaves': 40, 'learning_rate': 0.09416998453205919, 'n_estimators': 194, 'min_child_samples': 25, 'colsample_bytree': 0.922319198540412, 'reg_alpha': 0.9564641660852007, 'reg_lambda': 0.49596493566018746}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:42:59,921] Trial 420 finished with value: 0.8407355421461752 and parameters: {'num_leaves': 38, 'learning_rate': 0.08908014609116179, 'n_estimators': 192, 'min_child_samples': 10, 'colsample_bytree': 0.7002853565089605, 'reg_alpha': 0.9348210017032655, 'reg_lambda': 0.2799236532300962}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:43:01,614] Trial 421 finished with value: 0.8372942427315582 and parameters: {'num_leaves': 39, 'learning_rate': 0.09661726633432421, 'n_estimators': 184, 'min_child_samples': 14, 'colsample_bytree': 0.726103717199165, 'reg_alpha': 0.9822190314668708, 'reg_lambda': 1.2797971477950691}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:43:03,178] Trial 422 finished with value: 0.8392253012348808 and parameters: {'num_leaves': 37, 'learning_rate': 0.09810960556715488, 'n_estimators': 198, 'min_child_samples': 17, 'colsample_bytree': 0.7152377796051984, 'reg_alpha': 0.3833679842466987, 'reg_lambda': 0.6388030189720828}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:43:04,776] Trial 423 finished with value: 0.8420291858083919 and parameters: {'num_leaves': 40, 'learning_rate': 0.09533353763196162, 'n_estimators': 200, 'min_child_samples': 28, 'colsample_bytree': 0.7213320056157716, 'reg_alpha': 0.5053381066148198, 'reg_lambda': 0.010629188507057519}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:43:06,182] Trial 424 finished with value: 0.839564828963794 and parameters: {'num_leaves': 36, 'learning_rate': 0.09257654233538724, 'n_estimators': 200, 'min_child_samples': 29, 'colsample_bytree': 0.7313067201065793, 'reg_alpha': 0.5879495276587668, 'reg_lambda': 0.363449171782505}. Best is trial 153 with value: 0.8441547497383001.
# [I 2024-02-07 19:43:07,963] Trial 425 finished with value: 0.8403739515079465 and parameters: {'num_leaves': 40, 'learning_rate': 0.09066951971599399, 'n_estimators': 200, 'min_child_samples': 15, 'colsample_bytree': 0.7226346117962448, 'reg_alpha': 0.49927288088596694, 'reg_lambda': 0.02154117229231927}. Best is trial 153 with value: 0.8441547497383001.
# [W 2024-02-07 19:43:08,695] Trial 426 failed with parameters: {'num_leaves': 38, 'learning_rate': 0.0938042870866983, 'n_estimators': 197, 'min_child_samples': 10, 'colsample_bytree': 0.720406443619809, 'reg_alpha': 0.565942729013048, 'reg_lambda': 0.1786107481809912} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_985995/4067417121.py", line 39, in objective
#     clf.fit(all_x_train, all_y_train)
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/sklearn.py", line 1142, in fit
#     super().fit(
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/sklearn.py", line 842, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/engine.py", line 276, in train
#     booster.update(fobj=fobj)
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/basic.py", line 3658, in update
#     _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# [W 2024-02-07 19:43:08,696] Trial 426 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[241], line 49
#      47 # Hyperparameter Tuning
#      48 study = optuna.create_study(direction='maximize', sampler=TPESampler(seed=seed), pruner=SuccessiveHalvingPruner())
# ---> 49 study.optimize(objective, n_trials=None)
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[241], line 39, in objective(trial)
#      37 for all_x_train, all_y_train, all_x_val, all_y_val in zip(all_x_trains, all_y_trains, all_x_vals, all_y_vals):
#      38     clf = LGBMClassifier(**params)
# ---> 39     clf.fit(all_x_train, all_y_train)
#      41     y_pred = clf.predict(all_x_val)
#      42     y_true = all_y_val
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/sklearn.py:1142, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1139         else:
#    1140             valid_sets.append((valid_x, self._le.transform(valid_y)))
# -> 1142 super().fit(
#    1143     X,
#    1144     _y,
#    1145     sample_weight=sample_weight,
#    1146     init_score=init_score,
#    1147     eval_set=valid_sets,
#    1148     eval_names=eval_names,
#    1149     eval_sample_weight=eval_sample_weight,
#    1150     eval_class_weight=eval_class_weight,
#    1151     eval_init_score=eval_init_score,
#    1152     eval_metric=eval_metric,
#    1153     feature_name=feature_name,
#    1154     categorical_feature=categorical_feature,
#    1155     callbacks=callbacks,
#    1156     init_model=init_model
#    1157 )
#    1158 return self
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/sklearn.py:842, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#     839 evals_result: _EvalResultDict = {}
#     840 callbacks.append(record_evaluation(evals_result))
# --> 842 self._Booster = train(
#     843     params=params,
#     844     train_set=train_set,
#     845     num_boost_round=self.n_estimators,
#     846     valid_sets=valid_sets,
#     847     valid_names=eval_names,
#     848     feval=eval_metrics_callable,  # type: ignore[arg-type]
#     849     init_model=init_model,
#     850     feature_name=feature_name,
#     851     callbacks=callbacks
#     852 )
#     854 self._evals_result = evals_result
#     855 self._best_iteration = self._Booster.best_iteration
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/engine.py:276, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     268 for cb in callbacks_before_iter:
#     269     cb(callback.CallbackEnv(model=booster,
#     270                             params=params,
#     271                             iteration=i,
#     272                             begin_iteration=init_iteration,
#     273                             end_iteration=init_iteration + num_boost_round,
#     274                             evaluation_result_list=None))
# --> 276 booster.update(fobj=fobj)
#     278 evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#     279 # check evaluation result.
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/lightgbm/basic.py:3658, in Booster.update(self, train_set, fobj)
#    3656 if self.__set_objective_to_none:
#    3657     raise LightGBMError('Cannot update due to null objective function.')
# -> 3658 _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    3659     self._handle,
#    3660     ctypes.byref(is_finished)))
#    3661 self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    3662 return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
best_param = study.best_params
best_param['verbose'] = -1
best_param['random_state'] = seed
best_param['objective'] = 'binary'
best_param['verbose'] = -1
best_param['scale_pos_weight'] = rate
best_param
# Out:
# {'num_leaves': 39,
#  'learning_rate': 0.09211688808142465,
#  'n_estimators': 192,
#  'min_child_samples': 10,
#  'colsample_bytree': 0.7003587174473991,
#  'reg_alpha': 0.9874391587667168,
#  'reg_lambda': 0.003041692669265003,
#  'verbose': -1,
#  'random_state': 42,
#  'objective': 'binary',
#  'scale_pos_weight': 11.073593073593074}

# %%
best_models = []
for all_x_train, all_y_train in zip(all_x_trains, all_y_trains):
    best_model = LGBMClassifier(**best_param)
    best_model.fit(all_x_train, all_y_train)
    best_models.append(best_model)

# %%
def get_clf_eval(y_test, y_pred=None):
    confusion = confusion_matrix(y_test, y_pred, labels=[True, False])
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, labels=[True, False])
    recall = recall_score(y_test, y_pred)
    F1 = f1_score(y_test, y_pred, labels=[True, False])

    print("오차행렬:\n", confusion)
    print("\n정확도: {:.4f}".format(accuracy))
    print("정밀도: {:.4f}".format(precision))
    print("재현율: {:.4f}".format(recall))
    print("F1: {:.4f}".format(F1))

# %%
train_pred = np.mean([best_model.predict_proba(df_train.drop("is_converted",axis=1).fillna(0)) for best_model in best_models], axis=0)
y = df_train['is_converted']
threshold = min([num[1] if y[i] else 1 for i, num in enumerate(train_pred)])
train_y_pred = [True if i[1]>=threshold else False for i in train_pred]
get_clf_eval(df_train['is_converted'], train_y_pred)
# Out:
# 오차행렬:
#  [[ 4620     0]
#  [ 2611 48549]]
#
# 정확도: 0.9532
# 정밀도: 0.6389
# 재현율: 1.0000
# F1: 0.7797

# %%
train_y_pred = [True if i[1]>=0.5 else False for i in train_pred]
get_clf_eval(df_train['is_converted'], train_y_pred)
# Out:
# 오차행렬:
#  [[ 4599    21]
#  [ 1532 49628]]
#
# 정확도: 0.9722
# 정밀도: 0.7501
# 재현율: 0.9955
# F1: 0.8555

# %%
x_train=df_train.drop("is_converted",axis=1).fillna(0)
y_train = df_train["is_converted"]
f1_sum = 0
for i in range(k_fold_num):
    pred = best_models[i].predict(all_x_vals[i])
    get_clf_eval(all_y_vals[i], pred)
    f1_sum += f1_score(all_y_vals[i], pred, labels=[True, False])
print(f'\n\n{f1_sum/k_fold_num}')
# Out:
# 오차행렬:
#  [[ 862   62]
#  [ 366 9866]]
#
# 정확도: 0.9616
# 정밀도: 0.7020
# 재현율: 0.9329
# F1: 0.8011
# 오차행렬:
#  [[ 825   99]
#  [ 395 9837]]
#
# 정확도: 0.9557
# 정밀도: 0.6762
# 재현율: 0.8929
# F1: 0.7696
# 오차행렬:
#  [[ 853   71]
#  [ 415 9817]]
#
# 정확도: 0.9564
# 정밀도: 0.6727
# 재현율: 0.9232
# F1: 0.7783
# 오차행렬:
#  [[ 830   94]
#  [ 411 9821]]
#
# 정확도: 0.9547
# 정밀도: 0.6688
# 재현율: 0.8983
# F1: 0.7667
# 오차행렬:
#  [[ 848   76]
#  [ 457 9775]]
#
# 정확도: 0.9522
# 정밀도: 0.6498
# 재현율: 0.9177
# F1: 0.7609
#
#
# 0.7753224864895871

# %%
# 예측에 필요한 데이터 분리
x_test = df_test.drop(["is_converted", "id"], axis=1).fillna(0)

# %%
# 예측 수행 (soft voting)
print(format(threshold,'f'))
a_pred = [best_model.predict_proba(x_test) for best_model in best_models]
pred = np.mean(a_pred, axis=0)
pred = [True if i[1]>threshold else False for i in pred]
sum(pred)
# Out:
# 0.351002
# 1586

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["is_converted"] = pred

# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)

# %%
real = pd.read_csv('73per.csv')
get_clf_eval(real['is_converted'], pred)
# Out:
# 오차행렬:
#  [[1572  582]
#  [  14 3103]]
#
# 정확도: 0.8869
# 정밀도: 0.9912
# 재현율: 0.7298
# F1: 0.8406
