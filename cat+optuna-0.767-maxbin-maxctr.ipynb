# %%
# !pip3 install scikit-learn tqdm catboost optuna xgboost ipywidgets imblearn
# Out:
# Requirement already satisfied: scikit-learn in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (1.4.0)
# Requirement already satisfied: tqdm in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (4.65.0)
# Requirement already satisfied: catboost in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: optuna in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (3.5.0)
# Requirement already satisfied: xgboost in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: ipywidgets in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (8.0.4)
# Requirement already satisfied: imblearn in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (0.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from scikit-learn) (1.26.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: graphviz in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (3.7.2)
# Requirement already satisfied: pandas>=0.24 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (2.0.3)
# Requirement already satisfied: plotly in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (5.18.0)
# Requirement already satisfied: six in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: alembic>=1.5.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (1.13.1)
# Requirement already satisfied: colorlog in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (6.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (2.0.25)
# Requirement already satisfied: PyYAML in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from optuna) (6.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (6.25.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: imbalanced-learn in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from imblearn) (0.12.0)
# Requirement already satisfied: Mako in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (1.3.2)
# Requirement already satisfied: typing-extensions>=4 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (4.9.0)
# Requirement already satisfied: comm>=0.1.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: psutil in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.3)
# Requirement already satisfied: backcall in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pickleshare in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: greenlet!=0.4.17 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from plotly->catboost) (8.2.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: entrypoints in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# Requirement already satisfied: executing in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in /home/server4/anaconda3/envs/jy/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# WARNING: There was an error checking the latest version of pip.

# %%
import pandas as pd
import sklearn
import numpy as np
import random
import os
from imblearn.over_sampling import BorderlineSMOTE
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
import optuna
from optuna.samplers import TPESampler
from optuna.pruners import SuccessiveHalvingPruner
from catboost import CatBoostClassifier, Pool

import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import StratifiedKFold

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed=42
seed_everything(seed) # Seed 고정

# %%
df_train = pd.read_csv("train.csv") # 학습용 데이터
df_test = pd.read_csv("submission.csv") # 테스트 데이터(제출파일의 데이터)

# %%
def category_all(df_train, df_test):
    label_columns = [
    "customer_country",
    "business_subarea",
    "business_area",
    "business_unit",
    "customer_type",
    "enterprise",
    "customer_job",
    "inquiry_type",
    "product_category",
    "product_subcategory",
    "product_modelname",
    "customer_position",
    "response_corporate",
    "expected_timeline",
    'customer_idx',
    'lead_owner',

    ]
    for i in label_columns:
        df_train[i] = df_train[i].astype('category')
        df_test[i] = df_test[i].astype('category')
    return df_train, df_test    


def preprocessing(df_train, df_test):
    df_train.drop_duplicates(keep='first', inplace=True)
    df_train.reset_index(inplace=True)
    df_train.drop('index',inplace=True, axis=1)
    df_test_id_temp = df_test['id'].copy()
    df_all = pd.concat([df_train,df_test.drop('id',axis=1)])
    df_all.drop('customer_country.1',axis=1,inplace=True)
    df_all.id_strategic_ver.fillna(0., inplace=True)
    df_all.it_strategic_ver.fillna(0., inplace=True)
    df_all.idit_strategic_ver.fillna(0., inplace=True)
    df_all.business_subarea.fillna('NAN', inplace=True)
    df_all.com_reg_ver_win_rate.fillna(0,inplace=True)
    df_all['customer_type'] = df_all['customer_type'].replace({
        'End-Customer':'End Customer'
    })
    df_all.customer_type.fillna('NAN',inplace=True)
    df_all.historical_existing_cnt.fillna(0, inplace=True)
    
    df_all.product_subcategory.fillna('NAN', inplace=True)
    
    df_all.product_modelname.fillna('NAN', inplace=True)

    df_all['expected_timeline'] = df_all['expected_timeline'].replace({
        'less_than_3_months': 'less than 3 months',
        'being followed up': 'being followed up.',
        'less than 6 months': '3 months ~ 6 months',
        '3_months_~_6_months' : '3 months ~ 6 months'
    })

    df_all.expected_timeline.fillna('NAN',inplace=True)
    df_all.ver_win_rate_x.fillna(0,inplace=True)
    df_all.ver_win_ratio_per_bu.fillna(0,inplace=True)
    df_all.business_area.fillna('NAN',inplace=True)
    df_all.customer_job.fillna('NAN', inplace=True)
    df_all.product_category.fillna('NAN', inplace=True)
    
    #처리못한부분
    #customer_country
    df_all.customer_country.fillna('NAN', inplace=True)
    #inquiry_type
    df_all.inquiry_type.fillna('NAN', inplace=True)

    label_columns = [
    "customer_country",
    "business_subarea",
    "business_area",
    "business_unit",
    "customer_type",
    "enterprise",
    "customer_job",
    "inquiry_type",
    "product_category",
    "product_subcategory",
    "product_modelname",
    "customer_position",
    "response_corporate",
    "expected_timeline",
    ]
    
    ###############################
    #detect special char and to lower
    for i in label_columns:
        df_all[i] = df_all[i].str.lower()
        df_all[i] = df_all[i].str.replace(pat=r'[^\w]', repl=r'', regex=True)
        
    #to int
    df_all['id_strategic_ver'] = df_all['id_strategic_ver'].astype('int64')
    df_all['it_strategic_ver'] = df_all['it_strategic_ver'].astype('int64')
    df_all['idit_strategic_ver'] = df_all['idit_strategic_ver'].astype('int64')
    df_all['lead_desc_length'] = df_all['lead_desc_length'].astype('int64')
    df_all['historical_existing_cnt'] = df_all['historical_existing_cnt'].astype('int64')
    
    #seperate
    tmp_len = len(df_train)
    df_train = df_all.iloc[: tmp_len ]
    df_test = df_all.iloc[tmp_len :]
    df_test = pd.concat([df_test,df_test_id_temp],axis=1)
    
    #RobustScaler
    robustScaler = RobustScaler()
    df_train['ver_win_rate_x'] = robustScaler.fit_transform(df_train[['ver_win_rate_x']])
    df_test['ver_win_rate_x'] = robustScaler.transform(df_test[['ver_win_rate_x']])
    robustScaler = RobustScaler()
    df_train['ver_win_ratio_per_bu'] = robustScaler.fit_transform(df_train[['ver_win_ratio_per_bu']])
    df_test['ver_win_ratio_per_bu'] = robustScaler.transform(df_test[['ver_win_ratio_per_bu']])
    ##############################
    
    return df_train, df_test


df_train, df_test = preprocessing(df_train, df_test)
df_train, df_test = category_all(df_train, df_test)
rate = ((len(df_train)-sum(df_train['is_converted']))/sum(df_train['is_converted']))
x_train, y_train = df_train.drop("is_converted",axis=1), df_train["is_converted"]

# %%
categorical_features = [
    "customer_country",
    "business_subarea",
    "business_area",
    "business_unit",
    "customer_type",
    "enterprise",
    "customer_job",
    "inquiry_type",
    "product_category",
    "product_subcategory",
    "product_modelname",
    "customer_position",
    "response_corporate",
    "expected_timeline",
   'customer_idx',
   'lead_owner',
    ]

S_kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)

all_train_pool = []
all_val_pool = []
all_y_val = []
for train_idx, val_idx in S_kfold.split(x_train, list(y_train)):
    tmp_x_train, tmp_x_val = x_train.iloc[train_idx], x_train.iloc[val_idx]
    tmp_y_train, tmp_y_val = y_train[train_idx], y_train[val_idx]
    train_pool = Pool(data=tmp_x_train, label=tmp_y_train, cat_features=categorical_features)
    val_pool = Pool(data=tmp_x_val, label=tmp_y_val, cat_features=categorical_features)
    all_train_pool.append(train_pool)
    all_val_pool.append(val_pool)
    all_y_val.append(list(tmp_y_val))

# %%
def objective(trial):
    params = {'iterations':trial.suggest_int("iterations", 10000, 50000),
        'learning_rate' : trial.suggest_float('learning_rate',0.001, 1),
        'reg_lambda': trial.suggest_float('reg_lambda',10,100),
        'random_strength': trial.suggest_float('random_strength',40,100),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf',1,50),
        'leaf_estimation_iterations': trial.suggest_int('leaf_estimation_iterations',1,15),
        'bagging_temperature' :trial.suggest_float('bagging_temperature', 0, 1),
             }
    
    #score = []
    tmp_score = []
    for train_pool, val_pool, y_true in zip(all_train_pool, all_val_pool, all_y_val):
        clf = CatBoostClassifier(**params,
                                 scale_pos_weight=rate, 
                                 loss_function='Logloss',
                                 eval_metric='F1',
                                 early_stopping_rounds=100,
                                 verbose=False,
                                random_state=seed,
                                 task_type="GPU",
                                 devices='0',
                                 max_bin=254,
                                 max_ctr_complexity=15
                                )
        clf.fit(train_pool, eval_set=val_pool)
        
        y_pred = clf.predict(val_pool)
        y_pred = [False if i=='False' else True for i in y_pred]
        tmp_score.append(f1_score(y_true,y_pred,labels=[True, False]))
    tmp_score = np.mean(tmp_score)
    return tmp_score

# Hyperparameter Tuning
study = optuna.create_study(direction='maximize', sampler=TPESampler(seed=seed), pruner=SuccessiveHalvingPruner())
study.optimize(objective, n_trials=None)
# Out:
# [I 2024-02-16 15:39:14,867] A new study created in memory with name: no-name-4c1a155f-0b8f-4cab-819b-a6e34b98205e
# [I 2024-02-16 15:39:34,535] Trial 0 finished with value: 0.7483384199519001 and parameters: {'iterations': 24981, 'learning_rate': 0.9507635921035062, 'reg_lambda': 75.87945476302646, 'random_strength': 75.91950905182219, 'min_data_in_leaf': 8, 'leaf_estimation_iterations': 3, 'bagging_temperature': 0.05808361216819946}. Best is trial 0 with value: 0.7483384199519001.
# [I 2024-02-16 15:40:01,446] Trial 1 finished with value: 0.7690482912079661 and parameters: {'iterations': 44647, 'learning_rate': 0.6015138967314656, 'reg_lambda': 73.7265320016441, 'random_strength': 41.23506965774815, 'min_data_in_leaf': 49, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.21233911067827616}. Best is trial 1 with value: 0.7690482912079661.
# [I 2024-02-16 15:40:37,054] Trial 2 finished with value: 0.7697394434074869 and parameters: {'iterations': 17273, 'learning_rate': 0.18422110534358038, 'reg_lambda': 37.381801866358394, 'random_strength': 71.48538589793426, 'min_data_in_leaf': 22, 'leaf_estimation_iterations': 5, 'bagging_temperature': 0.6118528947223795}. Best is trial 2 with value: 0.7697394434074869.
# [I 2024-02-16 15:41:08,536] Trial 3 finished with value: 0.7701277360442644 and parameters: {'iterations': 15579, 'learning_rate': 0.29285250388668294, 'reg_lambda': 42.97256589643225, 'random_strength': 67.36419905302216, 'min_data_in_leaf': 40, 'leaf_estimation_iterations': 3, 'bagging_temperature': 0.5142344384136116}. Best is trial 3 with value: 0.7701277360442644.
# [I 2024-02-16 15:42:21,019] Trial 4 finished with value: 0.755702279782394 and parameters: {'iterations': 33697, 'learning_rate': 0.047403962307277725, 'reg_lambda': 64.67903667112945, 'random_strength': 50.23144742123749, 'min_data_in_leaf': 4, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.9656320330745594}. Best is trial 3 with value: 0.7701277360442644.
# [I 2024-02-16 15:42:52,835] Trial 5 finished with value: 0.7765727146412107 and parameters: {'iterations': 42336, 'learning_rate': 0.30530915540419734, 'reg_lambda': 18.79049026057455, 'random_strength': 81.05398159072942, 'min_data_in_leaf': 23, 'leaf_estimation_iterations': 2, 'bagging_temperature': 0.4951769101112702}. Best is trial 5 with value: 0.7765727146412107.
# [I 2024-02-16 15:43:14,774] Trial 6 finished with value: 0.7542860871965995 and parameters: {'iterations': 11375, 'learning_rate': 0.9094110816767033, 'reg_lambda': 33.290198344001524, 'random_strength': 79.75133706123893, 'min_data_in_leaf': 16, 'leaf_estimation_iterations': 8, 'bagging_temperature': 0.5467102793432796}. Best is trial 5 with value: 0.7765727146412107.
# [I 2024-02-16 15:43:39,738] Trial 7 finished with value: 0.7531718309199562 and parameters: {'iterations': 17394, 'learning_rate': 0.969615043136794, 'reg_lambda': 79.76195410250031, 'random_strength': 96.36993649385136, 'min_data_in_leaf': 45, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.9218742350231168}. Best is trial 5 with value: 0.7765727146412107.
# [I 2024-02-16 15:44:11,439] Trial 8 finished with value: 0.7703692918384247 and parameters: {'iterations': 13539, 'learning_rate': 0.19678687955672605, 'reg_lambda': 14.070456001948425, 'random_strength': 59.519819845795865, 'min_data_in_leaf': 20, 'leaf_estimation_iterations': 5, 'bagging_temperature': 0.8287375091519293}. Best is trial 5 with value: 0.7765727146412107.
# [I 2024-02-16 15:44:49,204] Trial 9 finished with value: 0.7646869017048793 and parameters: {'iterations': 24270, 'learning_rate': 0.2816535751776934, 'reg_lambda': 58.84264748424236, 'random_strength': 48.45545349848576, 'min_data_in_leaf': 41, 'leaf_estimation_iterations': 2, 'bagging_temperature': 0.9868869366005173}. Best is trial 5 with value: 0.7765727146412107.
# [I 2024-02-16 15:45:16,079] Trial 10 finished with value: 0.7701958201423854 and parameters: {'iterations': 49058, 'learning_rate': 0.55929204735921, 'reg_lambda': 97.25833997090791, 'random_strength': 92.22961838648156, 'min_data_in_leaf': 33, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.3310460817165841}. Best is trial 5 with value: 0.7765727146412107.
# [I 2024-02-16 15:45:39,902] Trial 11 finished with value: 0.7657368619123714 and parameters: {'iterations': 38143, 'learning_rate': 0.4397311483883106, 'reg_lambda': 10.37158990402015, 'random_strength': 60.21085229279542, 'min_data_in_leaf': 28, 'leaf_estimation_iterations': 6, 'bagging_temperature': 0.7466223502834903}. Best is trial 5 with value: 0.7765727146412107.
# [I 2024-02-16 15:46:53,556] Trial 12 finished with value: 0.7126981360519238 and parameters: {'iterations': 40045, 'learning_rate': 0.02262196197784938, 'reg_lambda': 10.984594110983725, 'random_strength': 86.04253203136838, 'min_data_in_leaf': 16, 'leaf_estimation_iterations': 1, 'bagging_temperature': 0.7380364464431612}. Best is trial 5 with value: 0.7765727146412107.
# [I 2024-02-16 15:47:22,586] Trial 13 finished with value: 0.7789647517804476 and parameters: {'iterations': 30659, 'learning_rate': 0.4270021432817426, 'reg_lambda': 23.85766393717657, 'random_strength': 60.858005829794955, 'min_data_in_leaf': 21, 'leaf_estimation_iterations': 5, 'bagging_temperature': 0.3427992882663162}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:47:46,902] Trial 14 finished with value: 0.7616205390420648 and parameters: {'iterations': 30569, 'learning_rate': 0.7016708969670808, 'reg_lambda': 24.855676892702718, 'random_strength': 63.679087223174804, 'min_data_in_leaf': 30, 'leaf_estimation_iterations': 7, 'bagging_temperature': 0.3744748481924885}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:48:14,373] Trial 15 finished with value: 0.773078886526144 and parameters: {'iterations': 37420, 'learning_rate': 0.41037164928929487, 'reg_lambda': 25.77273331812736, 'random_strength': 83.96583914506172, 'min_data_in_leaf': 11, 'leaf_estimation_iterations': 4, 'bagging_temperature': 0.35196730148536176}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:48:38,512] Trial 16 finished with value: 0.7612079744184964 and parameters: {'iterations': 24507, 'learning_rate': 0.7605412851207491, 'reg_lambda': 48.601258034056386, 'random_strength': 53.83828023657706, 'min_data_in_leaf': 35, 'leaf_estimation_iterations': 1, 'bagging_temperature': 0.12782432428264}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:49:07,892] Trial 17 finished with value: 0.7752926985119067 and parameters: {'iterations': 44097, 'learning_rate': 0.36300686978160496, 'reg_lambda': 24.0646823497313, 'random_strength': 72.53554527559058, 'min_data_in_leaf': 23, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.24434643042163942}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:49:35,767] Trial 18 finished with value: 0.774376850253913 and parameters: {'iterations': 31287, 'learning_rate': 0.5283320147664633, 'reg_lambda': 32.80646608066694, 'random_strength': 85.05983416075155, 'min_data_in_leaf': 1, 'leaf_estimation_iterations': 4, 'bagging_temperature': 0.45544980517752287}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:50:12,056] Trial 19 finished with value: 0.7719185683729779 and parameters: {'iterations': 48736, 'learning_rate': 0.19260711877539063, 'reg_lambda': 20.103150958478945, 'random_strength': 91.2597641419114, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 6, 'bagging_temperature': 0.631762069117553}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:50:39,806] Trial 20 finished with value: 0.7759612851461866 and parameters: {'iterations': 35067, 'learning_rate': 0.6715657303832014, 'reg_lambda': 48.37119994846845, 'random_strength': 78.6407098458151, 'min_data_in_leaf': 26, 'leaf_estimation_iterations': 2, 'bagging_temperature': 0.43057715842349087}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:51:05,546] Trial 21 finished with value: 0.771439245931398 and parameters: {'iterations': 34200, 'learning_rate': 0.6813263748945185, 'reg_lambda': 49.0521730092344, 'random_strength': 77.87047428737978, 'min_data_in_leaf': 25, 'leaf_estimation_iterations': 2, 'bagging_temperature': 0.43923031069447643}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:51:26,196] Trial 22 finished with value: 0.7607275809146967 and parameters: {'iterations': 42360, 'learning_rate': 0.8079546759717183, 'reg_lambda': 38.92640400265166, 'random_strength': 65.65688497906464, 'min_data_in_leaf': 19, 'leaf_estimation_iterations': 3, 'bagging_temperature': 0.21419854542017464}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:51:54,800] Trial 23 finished with value: 0.7706975431257188 and parameters: {'iterations': 27285, 'learning_rate': 0.4826154637598834, 'reg_lambda': 18.436601843256003, 'random_strength': 81.45041274305098, 'min_data_in_leaf': 28, 'leaf_estimation_iterations': 1, 'bagging_temperature': 0.301914107979389}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:52:18,318] Trial 24 finished with value: 0.7623062384350077 and parameters: {'iterations': 35751, 'learning_rate': 0.630224376744384, 'reg_lambda': 31.293749052488643, 'random_strength': 73.994215315079, 'min_data_in_leaf': 37, 'leaf_estimation_iterations': 4, 'bagging_temperature': 0.5805563973848682}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:52:54,524] Trial 25 finished with value: 0.7728803171531917 and parameters: {'iterations': 20834, 'learning_rate': 0.32819944172738613, 'reg_lambda': 56.39563142700655, 'random_strength': 57.227290180524975, 'min_data_in_leaf': 25, 'leaf_estimation_iterations': 2, 'bagging_temperature': 0.4303945153773592}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:53:17,921] Trial 26 finished with value: 0.77206137269976 and parameters: {'iterations': 28421, 'learning_rate': 0.8511622038219071, 'reg_lambda': 47.58311738526727, 'random_strength': 99.8481897088584, 'min_data_in_leaf': 31, 'leaf_estimation_iterations': 5, 'bagging_temperature': 0.48059430681336657}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:54:04,070] Trial 27 finished with value: 0.7647471313613691 and parameters: {'iterations': 40911, 'learning_rate': 0.1046386946124308, 'reg_lambda': 64.03570458238353, 'random_strength': 69.56040656844644, 'min_data_in_leaf': 19, 'leaf_estimation_iterations': 7, 'bagging_temperature': 0.6594170095662302}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:54:31,139] Trial 28 finished with value: 0.7718351164210305 and parameters: {'iterations': 31986, 'learning_rate': 0.4540404177600422, 'reg_lambda': 17.982414246284637, 'random_strength': 89.25600741275301, 'min_data_in_leaf': 11, 'leaf_estimation_iterations': 3, 'bagging_temperature': 0.10981345745713494}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:55:01,427] Trial 29 finished with value: 0.7712584910079276 and parameters: {'iterations': 45873, 'learning_rate': 0.3931314058048182, 'reg_lambda': 98.1263837099525, 'random_strength': 75.30254731148644, 'min_data_in_leaf': 7, 'leaf_estimation_iterations': 3, 'bagging_temperature': 0.29077667427287845}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:55:26,776] Trial 30 finished with value: 0.7700110529230519 and parameters: {'iterations': 36914, 'learning_rate': 0.5765783158662571, 'reg_lambda': 29.516594429421595, 'random_strength': 63.2805068406273, 'min_data_in_leaf': 28, 'leaf_estimation_iterations': 2, 'bagging_temperature': 0.02200433696311299}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:55:56,249] Trial 31 finished with value: 0.7705935428835893 and parameters: {'iterations': 43967, 'learning_rate': 0.35281872284367977, 'reg_lambda': 20.95422542206554, 'random_strength': 71.90108302529279, 'min_data_in_leaf': 23, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.22145337652260197}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:56:30,313] Trial 32 finished with value: 0.7784702023284145 and parameters: {'iterations': 39630, 'learning_rate': 0.2650051186652216, 'reg_lambda': 25.546868470685624, 'random_strength': 77.8816201409069, 'min_data_in_leaf': 22, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.253671247651173}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:57:02,623] Trial 33 finished with value: 0.7691549916821538 and parameters: {'iterations': 38757, 'learning_rate': 0.26401298111779486, 'reg_lambda': 39.22571737720867, 'random_strength': 78.08600225729853, 'min_data_in_leaf': 20, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.40212375553610996}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:57:42,382] Trial 34 finished with value: 0.7756022157799269 and parameters: {'iterations': 33517, 'learning_rate': 0.2381835673967856, 'reg_lambda': 81.71809109328896, 'random_strength': 81.5013407371134, 'min_data_in_leaf': 16, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.5205417462209774}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:58:22,223] Trial 35 finished with value: 0.7666967575081294 and parameters: {'iterations': 46858, 'learning_rate': 0.1352295329716269, 'reg_lambda': 43.06250385885299, 'random_strength': 40.62090633814577, 'min_data_in_leaf': 26, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.12988139079845634}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:58:44,805] Trial 36 finished with value: 0.7692436979412643 and parameters: {'iterations': 41628, 'learning_rate': 0.6493133355973562, 'reg_lambda': 27.867524692400885, 'random_strength': 69.01482878335537, 'min_data_in_leaf': 23, 'leaf_estimation_iterations': 6, 'bagging_temperature': 0.2610443578946208}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:59:12,520] Trial 37 finished with value: 0.7671846131786102 and parameters: {'iterations': 34448, 'learning_rate': 0.5066475150691359, 'reg_lambda': 36.61015043983955, 'random_strength': 76.31318620923363, 'min_data_in_leaf': 32, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.15867237191426675}. Best is trial 13 with value: 0.7789647517804476.
# [I 2024-02-16 15:59:47,393] Trial 38 finished with value: 0.785822641432165 and parameters: {'iterations': 28001, 'learning_rate': 0.3228876305312745, 'reg_lambda': 15.416289793312831, 'random_strength': 88.80386078597707, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.561395869932309}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:00:23,622] Trial 39 finished with value: 0.7857598577209269 and parameters: {'iterations': 21979, 'learning_rate': 0.3025617481719307, 'reg_lambda': 15.298933256116136, 'random_strength': 88.9240651232993, 'min_data_in_leaf': 12, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.562074723722158}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:01:05,380] Trial 40 finished with value: 0.7711137081038045 and parameters: {'iterations': 22373, 'learning_rate': 0.14951270248466256, 'reg_lambda': 14.906736546150581, 'random_strength': 94.45100245429164, 'min_data_in_leaf': 8, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.7153781556523602}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:01:37,048] Trial 41 finished with value: 0.7726713028538033 and parameters: {'iterations': 26398, 'learning_rate': 0.3157390845000727, 'reg_lambda': 15.1161278176939, 'random_strength': 88.02006999975958, 'min_data_in_leaf': 12, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.5570253110814598}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:02:09,667] Trial 42 finished with value: 0.7679365153573012 and parameters: {'iterations': 19760, 'learning_rate': 0.2330013041778193, 'reg_lambda': 22.001962405672646, 'random_strength': 83.53516469192374, 'min_data_in_leaf': 17, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.5009640301770012}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:02:42,488] Trial 43 finished with value: 0.7756210184788929 and parameters: {'iterations': 28967, 'learning_rate': 0.30326992377910134, 'reg_lambda': 10.569341902145787, 'random_strength': 47.220579872213676, 'min_data_in_leaf': 7, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.5944448522400451}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:03:11,907] Trial 44 finished with value: 0.763599563004232 and parameters: {'iterations': 16968, 'learning_rate': 0.403044609149666, 'reg_lambda': 15.5786225009222, 'random_strength': 88.82264920836806, 'min_data_in_leaf': 50, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.6739335978249624}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:03:48,346] Trial 45 finished with value: 0.7760676338626424 and parameters: {'iterations': 25914, 'learning_rate': 0.2382408252934814, 'reg_lambda': 27.668171765195382, 'random_strength': 97.23454929437897, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.5194613896214049}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:04:45,055] Trial 46 finished with value: 0.7607484347997759 and parameters: {'iterations': 23574, 'learning_rate': 0.07733650564531327, 'reg_lambda': 24.143063270326593, 'random_strength': 92.64988888745843, 'min_data_in_leaf': 21, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.8279949341141457}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:05:15,426] Trial 47 finished with value: 0.7746440290396918 and parameters: {'iterations': 19369, 'learning_rate': 0.35919516514234134, 'reg_lambda': 12.651541099834605, 'random_strength': 86.96643464484646, 'min_data_in_leaf': 13, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.37672782146918204}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:05:42,232] Trial 48 finished with value: 0.7684138496711166 and parameters: {'iterations': 10715, 'learning_rate': 0.4545297009304571, 'reg_lambda': 35.650739169186366, 'random_strength': 83.50548779527128, 'min_data_in_leaf': 4, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.3312801833108626}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:06:24,334] Trial 49 finished with value: 0.7749857112537352 and parameters: {'iterations': 29702, 'learning_rate': 0.18244234692201494, 'reg_lambda': 17.301615011524472, 'random_strength': 81.59803697797771, 'min_data_in_leaf': 17, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.6119763270267045}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:06:56,634] Trial 50 finished with value: 0.7732641592905244 and parameters: {'iterations': 13909, 'learning_rate': 0.2717625455283076, 'reg_lambda': 23.525968249772646, 'random_strength': 91.15557707227916, 'min_data_in_leaf': 10, 'leaf_estimation_iterations': 8, 'bagging_temperature': 0.5553331604138283}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:07:34,300] Trial 51 finished with value: 0.7802632279018666 and parameters: {'iterations': 25816, 'learning_rate': 0.2607044937299272, 'reg_lambda': 27.47146409181751, 'random_strength': 97.32282001885082, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.4818257915862426}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:08:06,942] Trial 52 finished with value: 0.7829237604804848 and parameters: {'iterations': 22300, 'learning_rate': 0.32579136725638047, 'reg_lambda': 19.323524528985033, 'random_strength': 95.86005470694015, 'min_data_in_leaf': 15, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.4767185469524776}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:08:34,122] Trial 53 finished with value: 0.768349101331994 and parameters: {'iterations': 21949, 'learning_rate': 0.39538214023417595, 'reg_lambda': 20.606026642894022, 'random_strength': 97.28996164664393, 'min_data_in_leaf': 15, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.46286627948987713}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:09:03,751] Trial 54 finished with value: 0.7702906859286648 and parameters: {'iterations': 23162, 'learning_rate': 0.34403511659852026, 'reg_lambda': 31.979244820727395, 'random_strength': 94.79051766141497, 'min_data_in_leaf': 18, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.3768582552740516}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:09:40,528] Trial 55 finished with value: 0.7753732708577512 and parameters: {'iterations': 24783, 'learning_rate': 0.21095352978903326, 'reg_lambda': 26.513150256153786, 'random_strength': 99.9173355184868, 'min_data_in_leaf': 21, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.420357868043724}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:10:11,226] Trial 56 finished with value: 0.7767384046436311 and parameters: {'iterations': 27270, 'learning_rate': 0.2922100791269161, 'reg_lambda': 12.281053756801628, 'random_strength': 95.21317413781088, 'min_data_in_leaf': 10, 'leaf_estimation_iterations': 7, 'bagging_temperature': 0.17225338708282353}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:10:39,467] Trial 57 finished with value: 0.7707857965477443 and parameters: {'iterations': 32272, 'learning_rate': 0.4283810210800479, 'reg_lambda': 93.09223334033548, 'random_strength': 93.23030864479892, 'min_data_in_leaf': 13, 'leaf_estimation_iterations': 8, 'bagging_temperature': 0.3032276290385823}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:11:09,162] Trial 58 finished with value: 0.7763892306914553 and parameters: {'iterations': 17851, 'learning_rate': 0.3821871441629672, 'reg_lambda': 17.584299965493358, 'random_strength': 90.57143551598219, 'min_data_in_leaf': 15, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.537421053223795}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:11:43,278] Trial 59 finished with value: 0.7713998375652006 and parameters: {'iterations': 21122, 'learning_rate': 0.2668672062374044, 'reg_lambda': 42.2168049241343, 'random_strength': 98.09520262754006, 'min_data_in_leaf': 5, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.6328718323115827}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:12:24,990] Trial 60 finished with value: 0.7805653749553372 and parameters: {'iterations': 25621, 'learning_rate': 0.17323070743136662, 'reg_lambda': 29.70785375525928, 'random_strength': 58.10436910587812, 'min_data_in_leaf': 9, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.4714943759766744}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:13:04,316] Trial 61 finished with value: 0.7722332111497677 and parameters: {'iterations': 25738, 'learning_rate': 0.15206898613557307, 'reg_lambda': 22.685383449042856, 'random_strength': 54.96937134731815, 'min_data_in_leaf': 9, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.4884141792516663}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:13:46,832] Trial 62 finished with value: 0.7798481341383369 and parameters: {'iterations': 27772, 'learning_rate': 0.18009203334800922, 'reg_lambda': 30.08068479866609, 'random_strength': 60.778602813704545, 'min_data_in_leaf': 12, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.39834162093377945}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:14:44,695] Trial 63 finished with value: 0.7583303526157261 and parameters: {'iterations': 27258, 'learning_rate': 0.052634780500528944, 'reg_lambda': 30.261656261033856, 'random_strength': 60.51898659667248, 'min_data_in_leaf': 12, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.46903348237268644}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:15:19,533] Trial 64 finished with value: 0.7716434566908733 and parameters: {'iterations': 30781, 'learning_rate': 0.1807690145036459, 'reg_lambda': 33.73671540386632, 'random_strength': 51.557536585696674, 'min_data_in_leaf': 2, 'leaf_estimation_iterations': 7, 'bagging_temperature': 0.5725287612690124}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:15:52,611] Trial 65 finished with value: 0.7821478744394621 and parameters: {'iterations': 28512, 'learning_rate': 0.3277985494980411, 'reg_lambda': 19.779090252663096, 'random_strength': 62.812173391613825, 'min_data_in_leaf': 5, 'leaf_estimation_iterations': 8, 'bagging_temperature': 0.3987565561852828}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:16:37,046] Trial 66 finished with value: 0.7739455366007537 and parameters: {'iterations': 28713, 'learning_rate': 0.11859320684971696, 'reg_lambda': 19.676745723354784, 'random_strength': 63.55838589461722, 'min_data_in_leaf': 5, 'leaf_estimation_iterations': 8, 'bagging_temperature': 0.4034588022582052}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:17:13,096] Trial 67 finished with value: 0.7768576315088646 and parameters: {'iterations': 24613, 'learning_rate': 0.2226373062944105, 'reg_lambda': 14.24331916460639, 'random_strength': 57.38072321349491, 'min_data_in_leaf': 3, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.4501067088084593}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:18:07,925] Trial 68 finished with value: 0.7687840418102685 and parameters: {'iterations': 23004, 'learning_rate': 0.0890589467527047, 'reg_lambda': 29.016161827037962, 'random_strength': 66.05664837553414, 'min_data_in_leaf': 6, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.5020587307953768}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:18:34,207] Trial 69 finished with value: 0.7691822436353157 and parameters: {'iterations': 28105, 'learning_rate': 0.3271256022780803, 'reg_lambda': 17.04944109358979, 'random_strength': 61.795120841312304, 'min_data_in_leaf': 9, 'leaf_estimation_iterations': 8, 'bagging_temperature': 0.4009371507581336}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:19:13,038] Trial 70 finished with value: 0.7774627452992668 and parameters: {'iterations': 29732, 'learning_rate': 0.17173351494555683, 'reg_lambda': 33.73684474504772, 'random_strength': 56.940606390517615, 'min_data_in_leaf': 11, 'leaf_estimation_iterations': 6, 'bagging_temperature': 0.6749741521270808}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:19:41,284] Trial 71 finished with value: 0.7700808217242083 and parameters: {'iterations': 31927, 'learning_rate': 0.3692818305899826, 'reg_lambda': 22.092807668966334, 'random_strength': 59.33590792641403, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.3644359443617527}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:20:10,518] Trial 72 finished with value: 0.7793238458003434 and parameters: {'iterations': 26695, 'learning_rate': 0.4784352086136841, 'reg_lambda': 26.001352127406776, 'random_strength': 66.40009508337226, 'min_data_in_leaf': 18, 'leaf_estimation_iterations': 7, 'bagging_temperature': 0.3378134181980822}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:21:50,651] Trial 73 finished with value: 0.7288046561235075 and parameters: {'iterations': 26426, 'learning_rate': 0.013207923653475229, 'reg_lambda': 25.41627829205077, 'random_strength': 67.68021467085725, 'min_data_in_leaf': 9, 'leaf_estimation_iterations': 8, 'bagging_temperature': 0.31345469578642393}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:22:14,160] Trial 74 finished with value: 0.7680464424233988 and parameters: {'iterations': 24051, 'learning_rate': 0.5294521809419281, 'reg_lambda': 10.169537391633911, 'random_strength': 66.68358834957321, 'min_data_in_leaf': 7, 'leaf_estimation_iterations': 7, 'bagging_temperature': 0.532294648796509}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:22:45,699] Trial 75 finished with value: 0.7772201019745281 and parameters: {'iterations': 25714, 'learning_rate': 0.3052707279356524, 'reg_lambda': 19.79869279307229, 'random_strength': 58.86114719476337, 'min_data_in_leaf': 46, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.43489615133160436}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:23:23,866] Trial 76 finished with value: 0.7743365815487528 and parameters: {'iterations': 21201, 'learning_rate': 0.25434199630079746, 'reg_lambda': 73.34134857420091, 'random_strength': 65.10526970412165, 'min_data_in_leaf': 18, 'leaf_estimation_iterations': 6, 'bagging_temperature': 0.34728766308010256}. Best is trial 38 with value: 0.785822641432165.
# [I 2024-02-16 16:24:08,947] Trial 77 finished with value: 0.7883078826223228 and parameters: {'iterations': 27823, 'learning_rate': 0.20454576828135052, 'reg_lambda': 27.154801823716518, 'random_strength': 62.12702060181847, 'min_data_in_leaf': 12, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.49467104316518706}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:24:52,096] Trial 78 finished with value: 0.7828273646583044 and parameters: {'iterations': 19843, 'learning_rate': 0.2065038319115857, 'reg_lambda': 38.63315450629254, 'random_strength': 62.15774576015244, 'min_data_in_leaf': 12, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.4750500679433702}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:25:34,433] Trial 79 finished with value: 0.7797671336497447 and parameters: {'iterations': 18909, 'learning_rate': 0.20769086906703738, 'reg_lambda': 52.93096328470424, 'random_strength': 53.62523628620902, 'min_data_in_leaf': 8, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.5935767496533516}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:26:09,033] Trial 80 finished with value: 0.776770829594678 and parameters: {'iterations': 20234, 'learning_rate': 0.28809362855247267, 'reg_lambda': 38.54142280270599, 'random_strength': 62.0344588001469, 'min_data_in_leaf': 16, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.4868370524841787}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:26:51,177] Trial 81 finished with value: 0.7727057008594911 and parameters: {'iterations': 25247, 'learning_rate': 0.16313217793383303, 'reg_lambda': 41.76840108787746, 'random_strength': 64.33201490371678, 'min_data_in_leaf': 12, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.5549325452792526}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:27:46,716] Trial 82 finished with value: 0.7730013625896227 and parameters: {'iterations': 27722, 'learning_rate': 0.11380842353560842, 'reg_lambda': 30.378592366273303, 'random_strength': 58.11570053035493, 'min_data_in_leaf': 11, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.5107255041236891}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:28:30,107] Trial 83 finished with value: 0.7828484707215906 and parameters: {'iterations': 21998, 'learning_rate': 0.20608016207897975, 'reg_lambda': 34.57252743407581, 'random_strength': 55.78333801050166, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.4105098246425691}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:29:05,888] Trial 84 finished with value: 0.7743509586740439 and parameters: {'iterations': 15821, 'learning_rate': 0.2402095057929668, 'reg_lambda': 34.949505845149304, 'random_strength': 44.53131249861786, 'min_data_in_leaf': 15, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.4622337539435287}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:29:42,876] Trial 85 finished with value: 0.774749477848214 and parameters: {'iterations': 22371, 'learning_rate': 0.20195965093801824, 'reg_lambda': 16.12901114231422, 'random_strength': 55.575139653242736, 'min_data_in_leaf': 13, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.4181018241569241}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:30:12,711] Trial 86 finished with value: 0.7745295950648485 and parameters: {'iterations': 18434, 'learning_rate': 0.33845212416564224, 'reg_lambda': 12.847514652770727, 'random_strength': 52.49966794262772, 'min_data_in_leaf': 10, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.6302379410374318}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:30:41,241] Trial 87 finished with value: 0.7710515252738447 and parameters: {'iterations': 20209, 'learning_rate': 0.31802900683255636, 'reg_lambda': 27.964367246343436, 'random_strength': 48.54452377992084, 'min_data_in_leaf': 7, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.47739400009617866}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:31:04,831] Trial 88 finished with value: 0.7547383730202817 and parameters: {'iterations': 21712, 'learning_rate': 0.9310858711619221, 'reg_lambda': 46.72263697159579, 'random_strength': 55.84516587478416, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.5347149265658392}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:31:41,145] Trial 89 finished with value: 0.783845036035684 and parameters: {'iterations': 23675, 'learning_rate': 0.2784189813911719, 'reg_lambda': 18.72795163341968, 'random_strength': 68.42214020636946, 'min_data_in_leaf': 16, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.4341208862744799}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:32:29,085] Trial 90 finished with value: 0.7746747152151955 and parameters: {'iterations': 23666, 'learning_rate': 0.13574581572722588, 'reg_lambda': 19.530982961781966, 'random_strength': 69.87538072902214, 'min_data_in_leaf': 17, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.43484981548647017}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:33:05,205] Trial 91 finished with value: 0.780133626601665 and parameters: {'iterations': 23039, 'learning_rate': 0.28404599127253677, 'reg_lambda': 22.919897849917003, 'random_strength': 68.40329861349042, 'min_data_in_leaf': 15, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.5742963739882736}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:33:40,552] Trial 92 finished with value: 0.7754001362113997 and parameters: {'iterations': 24805, 'learning_rate': 0.25317175361740446, 'reg_lambda': 32.385418818349905, 'random_strength': 62.48180151443511, 'min_data_in_leaf': 13, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.44754628198393687}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:34:19,212] Trial 93 finished with value: 0.7775170910571501 and parameters: {'iterations': 29559, 'learning_rate': 0.2182655336530567, 'reg_lambda': 24.454331366620302, 'random_strength': 98.4921138948269, 'min_data_in_leaf': 11, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.5093137468303408}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:34:51,630] Trial 94 finished with value: 0.7767422747957345 and parameters: {'iterations': 17071, 'learning_rate': 0.3000839388488956, 'reg_lambda': 21.15567082537389, 'random_strength': 73.64956109937145, 'min_data_in_leaf': 16, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.3897149668313032}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:35:25,155] Trial 95 finished with value: 0.7750605657311368 and parameters: {'iterations': 22563, 'learning_rate': 0.24031164193725402, 'reg_lambda': 18.283114632023327, 'random_strength': 95.94590018291764, 'min_data_in_leaf': 19, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.48003698547024143}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:36:02,795] Trial 96 finished with value: 0.7753821487808541 and parameters: {'iterations': 20744, 'learning_rate': 0.20173715275219056, 'reg_lambda': 27.24029602373343, 'random_strength': 90.31795743764661, 'min_data_in_leaf': 1, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.2785605158142833}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:36:33,003] Trial 97 finished with value: 0.773791525883879 and parameters: {'iterations': 23741, 'learning_rate': 0.36503352515890963, 'reg_lambda': 13.146480813274994, 'random_strength': 60.160511250574366, 'min_data_in_leaf': 10, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.4198530125632777}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:37:07,000] Trial 98 finished with value: 0.776384657953942 and parameters: {'iterations': 26687, 'learning_rate': 0.27920077689123673, 'reg_lambda': 37.1775756086703, 'random_strength': 86.01067759268714, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.45520353263246105}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:37:35,123] Trial 99 finished with value: 0.7692889150998505 and parameters: {'iterations': 32930, 'learning_rate': 0.4172412988446901, 'reg_lambda': 40.74113022322001, 'random_strength': 92.92201906133147, 'min_data_in_leaf': 6, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.523824199895354}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:38:08,610] Trial 100 finished with value: 0.7765215592735427 and parameters: {'iterations': 28852, 'learning_rate': 0.33341215572008, 'reg_lambda': 45.222152093733804, 'random_strength': 71.37679378894406, 'min_data_in_leaf': 13, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.3664047472756746}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:38:41,674] Trial 101 finished with value: 0.776250335450494 and parameters: {'iterations': 21845, 'learning_rate': 0.2853782876419756, 'reg_lambda': 23.79462242333481, 'random_strength': 68.14959342093142, 'min_data_in_leaf': 15, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.569238933414124}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:39:22,267] Trial 102 finished with value: 0.7813180232993627 and parameters: {'iterations': 25511, 'learning_rate': 0.2501816257791867, 'reg_lambda': 21.910396752819516, 'random_strength': 62.67797224476884, 'min_data_in_leaf': 17, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.6123868248377727}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:39:57,649] Trial 103 finished with value: 0.7771625325944437 and parameters: {'iterations': 25170, 'learning_rate': 0.2550649403163066, 'reg_lambda': 16.255165618949963, 'random_strength': 62.79171124520314, 'min_data_in_leaf': 20, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.601322413215835}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:40:45,012] Trial 104 finished with value: 0.7762772282726682 and parameters: {'iterations': 24394, 'learning_rate': 0.13625436148001396, 'reg_lambda': 18.833326601628716, 'random_strength': 64.5582278204513, 'min_data_in_leaf': 17, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.7112820148857626}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:41:21,363] Trial 105 finished with value: 0.7726236939559588 and parameters: {'iterations': 25768, 'learning_rate': 0.22617056098601535, 'reg_lambda': 28.59225327084268, 'random_strength': 61.15494821120793, 'min_data_in_leaf': 9, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.6156163616925353}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:41:52,330] Trial 106 finished with value: 0.773636647591817 and parameters: {'iterations': 30720, 'learning_rate': 0.31698132481144203, 'reg_lambda': 21.569190174119754, 'random_strength': 58.33354897491756, 'min_data_in_leaf': 12, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.5532650590708775}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:42:28,778] Trial 107 finished with value: 0.7724794940441744 and parameters: {'iterations': 27513, 'learning_rate': 0.19424424843255023, 'reg_lambda': 31.589648501235605, 'random_strength': 54.25091265046386, 'min_data_in_leaf': 12, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.6457594780187789}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:43:01,311] Trial 108 finished with value: 0.7804654273623484 and parameters: {'iterations': 19493, 'learning_rate': 0.3833390965250877, 'reg_lambda': 14.57029060362235, 'random_strength': 93.89314363725379, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.4969840659902093}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:43:32,488] Trial 109 finished with value: 0.7765307437061597 and parameters: {'iterations': 16319, 'learning_rate': 0.34920462675747205, 'reg_lambda': 11.334221908955609, 'random_strength': 56.506218337682945, 'min_data_in_leaf': 4, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.4966530389486087}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:44:01,863] Trial 110 finished with value: 0.7642505900314618 and parameters: {'iterations': 13238, 'learning_rate': 0.3797986102858604, 'reg_lambda': 14.458430809732755, 'random_strength': 59.7078187353013, 'min_data_in_leaf': 8, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.9180578089083132}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:44:35,836] Trial 111 finished with value: 0.7763635684675428 and parameters: {'iterations': 19137, 'learning_rate': 0.3075251558533492, 'reg_lambda': 16.479019421907083, 'random_strength': 94.24146135326095, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.47152628489667375}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:45:13,842] Trial 112 finished with value: 0.7808045224593346 and parameters: {'iterations': 18093, 'learning_rate': 0.26949454279098156, 'reg_lambda': 25.905738763076176, 'random_strength': 96.54825064389746, 'min_data_in_leaf': 17, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.522653908218594}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:45:49,605] Trial 113 finished with value: 0.7771011885090737 and parameters: {'iterations': 18291, 'learning_rate': 0.27233147599738106, 'reg_lambda': 14.110955887713718, 'random_strength': 91.91501485035207, 'min_data_in_leaf': 18, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.5403919999705576}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:46:29,143] Trial 114 finished with value: 0.7812686654374532 and parameters: {'iterations': 19886, 'learning_rate': 0.21916547735508635, 'reg_lambda': 18.491441126028324, 'random_strength': 96.18596101509532, 'min_data_in_leaf': 17, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.5128477405933722}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:47:16,293] Trial 115 finished with value: 0.7735779209192262 and parameters: {'iterations': 14452, 'learning_rate': 0.1506039279147583, 'reg_lambda': 25.684753298763987, 'random_strength': 96.2613960695136, 'min_data_in_leaf': 16, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.5793369548370325}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:47:59,480] Trial 116 finished with value: 0.7742637313916296 and parameters: {'iterations': 20156, 'learning_rate': 0.16209547592453066, 'reg_lambda': 21.61998347073435, 'random_strength': 89.01913420354197, 'min_data_in_leaf': 20, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.5222269217327465}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:48:34,661] Trial 117 finished with value: 0.770665140296583 and parameters: {'iterations': 21609, 'learning_rate': 0.230962820480078, 'reg_lambda': 18.050305556126496, 'random_strength': 99.10073961900201, 'min_data_in_leaf': 17, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.4443986669167329}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:49:13,474] Trial 118 finished with value: 0.7704170668930551 and parameters: {'iterations': 20836, 'learning_rate': 0.18314365841480396, 'reg_lambda': 61.272613895429856, 'random_strength': 79.70784149493662, 'min_data_in_leaf': 22, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.3849567485077863}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:50:08,266] Trial 119 finished with value: 0.7674582354400918 and parameters: {'iterations': 17807, 'learning_rate': 0.09003814575850864, 'reg_lambda': 20.15085037446928, 'random_strength': 63.55810148061869, 'min_data_in_leaf': 16, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.41932883286532713}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:50:44,213] Trial 120 finished with value: 0.7744668874081355 and parameters: {'iterations': 22952, 'learning_rate': 0.21668665450060628, 'reg_lambda': 24.738358040091466, 'random_strength': 87.66658794337594, 'min_data_in_leaf': 19, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.5910983153764722}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:51:19,925] Trial 121 finished with value: 0.7703941177997343 and parameters: {'iterations': 18719, 'learning_rate': 0.251253905192963, 'reg_lambda': 15.286079615514984, 'random_strength': 93.55188468025818, 'min_data_in_leaf': 13, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.5004921250864541}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:51:49,594] Trial 122 finished with value: 0.770738240311359 and parameters: {'iterations': 22112, 'learning_rate': 0.32197602897783967, 'reg_lambda': 12.191071387705467, 'random_strength': 95.67202263193707, 'min_data_in_leaf': 15, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.5576226057747298}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:52:27,726] Trial 123 finished with value: 0.7797048634955427 and parameters: {'iterations': 19715, 'learning_rate': 0.2895959998159951, 'reg_lambda': 18.59104076597491, 'random_strength': 97.06776420662113, 'min_data_in_leaf': 11, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.5197992291628383}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:53:00,971] Trial 124 finished with value: 0.7793003765266804 and parameters: {'iterations': 23889, 'learning_rate': 0.3437723125236305, 'reg_lambda': 22.12142155220503, 'random_strength': 65.48816180570454, 'min_data_in_leaf': 17, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.4934494147716145}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:53:33,832] Trial 125 finished with value: 0.7793844786701459 and parameters: {'iterations': 19435, 'learning_rate': 0.38869237652837574, 'reg_lambda': 35.34110506833213, 'random_strength': 94.47186032613926, 'min_data_in_leaf': 10, 'leaf_estimation_iterations': 15, 'bagging_temperature': 0.46990938544932276}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:54:03,223] Trial 126 finished with value: 0.7758398077259521 and parameters: {'iterations': 16504, 'learning_rate': 0.44748109064827374, 'reg_lambda': 16.44676288206403, 'random_strength': 90.34701572900208, 'min_data_in_leaf': 15, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.5396928739136043}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 16:54:32,196] Trial 127 finished with value: 0.7670524451465357 and parameters: {'iterations': 20816, 'learning_rate': 0.2665669809149938, 'reg_lambda': 10.144621941601445, 'random_strength': 57.793065524202476, 'min_data_in_leaf': 13, 'leaf_estimation_iterations': 10, 'bagging_temperature': 0.4511386444670933}. Best is trial 77 with value: 0.7883078826223228.
# ...
# [I 2024-02-16 18:55:03,934] Trial 344 finished with value: 0.7761245692095956 and parameters: {'iterations': 23054, 'learning_rate': 0.23867888575255286, 'reg_lambda': 28.87204462245574, 'random_strength': 70.22042403543806, 'min_data_in_leaf': 6, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.04104823352490028}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 18:55:36,221] Trial 345 finished with value: 0.7734032878196724 and parameters: {'iterations': 24502, 'learning_rate': 0.27784044186864154, 'reg_lambda': 28.16324165790167, 'random_strength': 69.11000474366492, 'min_data_in_leaf': 10, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.09526787777146917}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 18:56:09,006] Trial 346 finished with value: 0.7778472136166175 and parameters: {'iterations': 23886, 'learning_rate': 0.30538560379436014, 'reg_lambda': 26.095361730953563, 'random_strength': 70.1272055739881, 'min_data_in_leaf': 11, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.036202530402014765}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 18:56:44,809] Trial 347 finished with value: 0.7770358472441916 and parameters: {'iterations': 23102, 'learning_rate': 0.2686698024020737, 'reg_lambda': 32.027191613671576, 'random_strength': 60.571892754729426, 'min_data_in_leaf': 9, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.10428022387261278}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 18:57:22,680] Trial 348 finished with value: 0.7811862472096156 and parameters: {'iterations': 22682, 'learning_rate': 0.25432330680536974, 'reg_lambda': 26.90997570084912, 'random_strength': 61.94888375661954, 'min_data_in_leaf': 7, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.023793558982543095}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 18:57:55,499] Trial 349 finished with value: 0.7767992289591795 and parameters: {'iterations': 25157, 'learning_rate': 0.3092617445773019, 'reg_lambda': 25.369015917072602, 'random_strength': 84.6531097506414, 'min_data_in_leaf': 12, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.08366217506312176}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 18:58:28,076] Trial 350 finished with value: 0.771488228575247 and parameters: {'iterations': 27975, 'learning_rate': 0.29063755836066674, 'reg_lambda': 27.75113667958414, 'random_strength': 71.38109693576756, 'min_data_in_leaf': 9, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.595119435959736}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 18:59:04,765] Trial 351 finished with value: 0.7751951519692455 and parameters: {'iterations': 24110, 'learning_rate': 0.22365503387343602, 'reg_lambda': 32.78114224760768, 'random_strength': 65.79870096424062, 'min_data_in_leaf': 8, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.4636687664372759}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 18:59:33,577] Trial 352 finished with value: 0.7706905725656015 and parameters: {'iterations': 29010, 'learning_rate': 0.33350402636156584, 'reg_lambda': 23.025233592874507, 'random_strength': 67.63373818307245, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.5109472437168077}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 19:00:09,216] Trial 353 finished with value: 0.7797424702965157 and parameters: {'iterations': 20037, 'learning_rate': 0.27899003616855184, 'reg_lambda': 25.736319981225268, 'random_strength': 63.602228082702524, 'min_data_in_leaf': 11, 'leaf_estimation_iterations': 13, 'bagging_temperature': 0.059460573661901425}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 19:00:41,927] Trial 354 finished with value: 0.7719283199314382 and parameters: {'iterations': 25719, 'learning_rate': 0.31260278368647154, 'reg_lambda': 35.93556721137761, 'random_strength': 92.71439457869265, 'min_data_in_leaf': 5, 'leaf_estimation_iterations': 3, 'bagging_temperature': 0.17296394300346032}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 19:01:16,944] Trial 355 finished with value: 0.7741392040147779 and parameters: {'iterations': 21288, 'learning_rate': 0.2509895636766008, 'reg_lambda': 28.86721644405074, 'random_strength': 90.39108221448626, 'min_data_in_leaf': 16, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.1230486613968643}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 19:01:49,472] Trial 356 finished with value: 0.7724497881383009 and parameters: {'iterations': 23563, 'learning_rate': 0.2976775300974896, 'reg_lambda': 21.383963879322636, 'random_strength': 69.85811244538107, 'min_data_in_leaf': 15, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.013939238243889679}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 19:02:22,153] Trial 357 finished with value: 0.7802624291524247 and parameters: {'iterations': 22743, 'learning_rate': 0.33315311599439457, 'reg_lambda': 23.897338428333715, 'random_strength': 87.62128886488341, 'min_data_in_leaf': 12, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.15572539009043546}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 19:02:51,147] Trial 358 finished with value: 0.7663282457877614 and parameters: {'iterations': 24465, 'learning_rate': 0.35757795188315145, 'reg_lambda': 39.58880444282032, 'random_strength': 62.779692800592805, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.9238001181762702}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 19:03:22,300] Trial 359 finished with value: 0.7738400811601365 and parameters: {'iterations': 26539, 'learning_rate': 0.26900973915507465, 'reg_lambda': 19.151008411631985, 'random_strength': 49.930009904214806, 'min_data_in_leaf': 15, 'leaf_estimation_iterations': 9, 'bagging_temperature': 0.007714295771090163}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 19:03:52,349] Trial 360 finished with value: 0.7700543683117445 and parameters: {'iterations': 22251, 'learning_rate': 0.3128375018518055, 'reg_lambda': 24.937443574522817, 'random_strength': 71.88011383482498, 'min_data_in_leaf': 37, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.29762730774787993}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 19:04:27,596] Trial 361 finished with value: 0.7759048828259323 and parameters: {'iterations': 23472, 'learning_rate': 0.2346140793907389, 'reg_lambda': 22.038449464828183, 'random_strength': 64.70191274448695, 'min_data_in_leaf': 17, 'leaf_estimation_iterations': 12, 'bagging_temperature': 0.05192006414704621}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 19:05:01,860] Trial 362 finished with value: 0.7805034344170125 and parameters: {'iterations': 25340, 'learning_rate': 0.2839311496002132, 'reg_lambda': 27.374179421605245, 'random_strength': 68.19872719194322, 'min_data_in_leaf': 10, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.4998915960487884}. Best is trial 77 with value: 0.7883078826223228.
# [I 2024-02-16 19:05:34,712] Trial 363 finished with value: 0.7760970073475444 and parameters: {'iterations': 21065, 'learning_rate': 0.32680464771904727, 'reg_lambda': 30.890917388386224, 'random_strength': 94.78384713427168, 'min_data_in_leaf': 6, 'leaf_estimation_iterations': 8, 'bagging_temperature': 0.06686994499064941}. Best is trial 77 with value: 0.7883078826223228.
# [W 2024-02-16 19:06:16,268] Trial 364 failed with parameters: {'iterations': 24535, 'learning_rate': 0.06214364394042604, 'reg_lambda': 99.95227775392252, 'random_strength': 69.28816875260326, 'min_data_in_leaf': 12, 'leaf_estimation_iterations': 11, 'bagging_temperature': 0.11815419486704384} because of the following error: KeyboardInterrupt('').
# Traceback (most recent call last):
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_2475220/3306073367.py", line 26, in objective
#     clf.fit(train_pool, eval_set=val_pool)
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/catboost/core.py", line 5100, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/catboost/core.py", line 2319, in _fit
#     self._train(
#   File "/home/server4/anaconda3/envs/jy/lib/python3.11/site-packages/catboost/core.py", line 1723, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4645, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4694, in _catboost._CatBoost._train
# KeyboardInterrupt
# [W 2024-02-16 19:06:16,269] Trial 364 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 36
#      34 # Hyperparameter Tuning
#      35 study = optuna.create_study(direction='maximize', sampler=TPESampler(seed=seed), pruner=SuccessiveHalvingPruner())
# ---> 36 study.optimize(objective, n_trials=None)
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/optuna/study/_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[10], line 26, in objective(trial)
#      13 for train_pool, val_pool, y_true in zip(all_train_pool, all_val_pool, all_y_val):
#      14     clf = CatBoostClassifier(**params,
#      15                              scale_pos_weight=rate,
#      16                              loss_function='Logloss',
#    (...)
#      24                              max_ctr_complexity=15
#      25                             )
# ---> 26     clf.fit(train_pool, eval_set=val_pool)
#      28     y_pred = clf.predict(val_pool)
#      29     y_pred = [False if i=='False' else True for i in y_pred]
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/catboost/core.py:5100, in CatBoostClassifier.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5097 if 'loss_function' in params:
#    5098     CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
# -> 5100 self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    5101           eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period,
#    5102           silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5103 return self
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/catboost/core.py:2319, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2315 allow_clear_pool = train_params["allow_clear_pool"]
#    2317 with log_fixup(log_cout, log_cerr), \
#    2318     plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2319     self._train(
#    2320         train_pool,
#    2321         train_params["eval_sets"],
#    2322         params,
#    2323         allow_clear_pool,
#    2324         train_params["init_model"]
#    2325     )
#    2327 # Have property feature_importance possibly set
#    2328 loss = self._object._get_loss_function_name()
#
# File ~/anaconda3/envs/jy/lib/python3.11/site-packages/catboost/core.py:1723, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1722 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1723     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1724     self._set_trained_model_attributes()
#
# File _catboost.pyx:4645, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4694, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
best_param = study.best_params
best_param
# Out:
# {'iterations': 27823,
#  'learning_rate': 0.20454576828135052,
#  'reg_lambda': 27.154801823716518,
#  'random_strength': 62.12702060181847,
#  'min_data_in_leaf': 12,
#  'leaf_estimation_iterations': 11,
#  'bagging_temperature': 0.49467104316518706}

# %%
best_models = []
for train_pool, val_pool in zip(all_train_pool, all_val_pool):
    best_model = CatBoostClassifier(**best_param,
                                 random_state=seed,
                                 scale_pos_weight=rate, 
                                 loss_function='Logloss',
                                 eval_metric='F1',
                                 task_type="GPU",
                                 devices='0',
                                verbose=False,
                                   early_stopping_rounds=100,
                                    max_bin=254,
                                 max_ctr_complexity=15
                                   )
    
    best_model.fit(train_pool, eval_set=val_pool)
    best_models.append(best_model)

# %%
def get_clf_eval(y_test, y_pred=None):
    confusion = confusion_matrix(y_test, y_pred, labels=[True, False])
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, labels=[True, False])
    recall = recall_score(y_test, y_pred)
    F1 = f1_score(y_test, y_pred, labels=[True, False])

    print("오차행렬:\n", confusion)
    print("\n정확도: {:.4f}".format(accuracy))
    print("정밀도: {:.4f}".format(precision))
    print("재현율: {:.4f}".format(recall))
    print("F1: {:.4f}".format(F1))

# %%
train_pred = [best_model.predict_proba(df_train.drop("is_converted",axis=1)) for best_model in best_models]
y = list(df_train['is_converted'])
train_pred = np.mean(train_pred[:],axis=0)
threshold = min([num[1] if y[i] else 1 for i, num in enumerate(train_pred)])
train_y_pred = [True if i[1]>=0.5 else False for i in train_pred]
get_clf_eval(y, train_y_pred)
# Out:
# 오차행렬:
#  [[ 4609    11]
#  [  788 50372]]
#
# 정확도: 0.9857
# 정밀도: 0.8540
# 재현율: 0.9976
# F1: 0.9202

# %%
categorical_features =  [
                        "customer_country",
                        "business_subarea",
                        "business_area",
                        "business_unit",
                        "customer_type",
                        "enterprise",
                        "customer_job",
                        "inquiry_type",
                        "product_category",
                        "product_subcategory",
                        "product_modelname",
                        "customer_position",
                        "response_corporate",
                        "expected_timeline",
                        'customer_idx',
                        'lead_owner',
                    ]
# 
# 예측에 필요한 데이터 분리
x_test = df_test.drop(["is_converted", "id"], axis=1)
test_pool = Pool(data=x_test, cat_features=categorical_features)

# %%
# 예측 수행 (soft voting)
a_pred = [best_model.predict_proba(test_pool) for best_model in best_models]
pred = np.mean(a_pred[:], axis=0)
#pred = [True if i[1]>=threshold else False for i in pred]
pred = np.argmax(pred, axis=1)
sum(pred)
# Out:
# 1754

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["is_converted"] = pred

# 제출 파일 저장
df_sub.to_csv("submission_max.csv", index=False)

# %%
real = pd.read_csv(r'submission(0.767).csv')
get_clf_eval(real['is_converted'], pred)
# Out:
# 오차행렬:
#  [[1693   79]
#  [  61 3438]]
#
# 정확도: 0.9734
# 정밀도: 0.9652
# 재현율: 0.9554
# F1: 0.9603
